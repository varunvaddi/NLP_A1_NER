# %% [markdown]
# # NLP

# %% [markdown]
# importing required libraries

# %%
import spacy
import json
import pandas as pd

# %% [markdown]
# verifying the Path of file

# %%
import os
print("Current working directory:", os.getcwd())
os.chdir('/Users/varunvaddi/desktop/NLP')
# Out:
# Current working directory: /Users/varunvaddi/Desktop/NLP

# %% [markdown]
# ## PHASE 1

# %% [markdown]
# ### Opening the Manually Annotated JSON File

# %% [markdown]
# loading the spaCy's Large model

# %%
nlp=spacy.load('en_core_web_lg')

# %% [markdown]
# Opening the Manually Annotated JSON file into Jupyter Notebook

# %%
with open('NER_Tweets_300.json','r') as f:
  Manual_NER = json.load(f)

Manual_NER_list = []

for i in Manual_NER['annotations']:
  if i != None:
    Manual_NER_list.append(
        {
            'sentence': i[0],
            'entities': i[1]['entities']
        }
    )

Manual_NER_list[:2]
# Out:
# [{'sentence': 'EU Commission President Jose Manuel Barroso has said the 25-member bloc will make it clear to the Russian President that the EU is not " satisfied " with Ukraine \'s disputed election .\r',
#   'entities': [[0, 2, 'ORG'],
#    [24, 43, 'PERSON'],
#    [98, 105, 'NORP'],
#    [125, 127, 'ORG'],
#    [154, 161, 'GPE']]},
#  {'sentence': "Prime Minister Viktor Yanukovych -- who was backed by Mr. Putin -- has been declared the winner of Sunday 's voting , but the EU is rejecting the results because of allegations of widespread voting fraud .\r",
#   'entities': [[15, 32, 'PERSON'],
#    [58, 63, 'PERSON'],
#    [99, 105, 'DATE'],
#    [126, 128, 'ORG']]}]

# %% [markdown]
# loading the data onto the dataframe from CSV

# %%
df = pd.read_csv('NER_Tweets_Data.csv')
df.head()
# Out:
#                                               tweets
# 0  EU Commission President Jose Manuel Barroso ha...
# 1  Prime Minister Viktor Yanukovych -- who was ba...
# 2  On other issues , EU leaders say they will cal...
# 3  Palestinian President Mahmoud Abbas has fired ...
# 4  Mr. Abbas dismissed the men , including securi...

# %%
df.describe()
# Out:
#                                                    tweets
# count                                                 300
# unique                                                300
# top     EU Commission President Jose Manuel Barroso ha...
# freq                                                    1

# %% [markdown]
# ## PHASE 2

# %% [markdown]
# ### Separating the 7 Named Entity Tags only

# %%
spacy_output = []
tags = {"PERSON", "NORP", "ORG", "GPE", "LOC", "DATE", "MONEY"}
for sentence in df['tweets']:
    doc = nlp(sentence)
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in tags]
    spacy_output.append({"sentence": sentence, "entities": entities})

# Display the results
for result in spacy_output:
    print(f"Sentence: {result['sentence']}")
    for entity in result['entities']:
        print(f"  Entity: {entity[0]}, Label: {entity[1]}")
    print("\n")
# Out:
# Sentence: EU Commission President Jose Manuel Barroso has said the 25-member bloc will make it clear to the Russian President that the EU is not " satisfied " with Ukraine 's disputed election .
#   Entity: EU Commission, Label: ORG
#   Entity: Jose Manuel Barroso, Label: PERSON
#   Entity: Russian, Label: NORP
#   Entity: EU, Label: ORG
#   Entity: Ukraine, Label: GPE
#
#
# Sentence: Prime Minister Viktor Yanukovych -- who was backed by Mr. Putin -- has been declared the winner of Sunday 's voting , but the EU is rejecting the results because of allegations of widespread voting fraud .
#   Entity: Viktor Yanukovych, Label: PERSON
#   Entity: Putin, Label: PERSON
#   Entity: Sunday, Label: DATE
#   Entity: EU, Label: ORG
#
#
# Sentence: On other issues , EU leaders say they will call on Russia to sign and ratify border agreements with Estonia and Latvia , and urge it to seek a political settlement in war-torn Chechnya .
#   Entity: EU, Label: ORG
#   Entity: Russia, Label: GPE
#   Entity: Estonia, Label: GPE
#   Entity: Latvia, Label: GPE
#   Entity: Chechnya, Label: GPE
#
#
# Sentence: Palestinian President Mahmoud Abbas has fired three top security officials after militants broke the ceasefire he reached with Israel and fired mortars at Jewish settlements in the Gaza Strip .
#   Entity: Palestinian, Label: NORP
#   Entity: Mahmoud Abbas, Label: PERSON
#   Entity: Israel, Label: GPE
#   Entity: Jewish, Label: NORP
#   Entity: the Gaza Strip, Label: GPE
#
#
# Sentence: Mr. Abbas dismissed the men , including security chief Abdel Razek Majaidie , hours after Hamas militants fired the mortars .
#   Entity: Abbas, Label: PERSON
#   Entity: Abdel Razek Majaidie, Label: PERSON
#   Entity: Hamas, Label: ORG
#
#
# Sentence: No one was wounded in the shelling , which Hamas said was a response to Israeli gunfire that killed a Palestinian man Wednesday in Gaza .
#   Entity: Hamas, Label: ORG
#   Entity: Israeli, Label: NORP
#   Entity: Palestinian, Label: NORP
#   Entity: Wednesday, Label: DATE
#   Entity: Gaza, Label: GPE
#
#
# Sentence: Despite the violence , Israeli and Palestinian officials met late Thursday to discuss security issues .
#   Entity: Israeli, Label: NORP
#   Entity: Palestinian, Label: NORP
#   Entity: late Thursday, Label: DATE
#
#
# Sentence: Meanwhile , a deadly shootout was also reported at a Palestinian jail in Gaza City .
#   Entity: Palestinian, Label: NORP
#   Entity: Gaza City, Label: GPE
#
#
# Sentence: Palestinian sources say at least three people described as Israeli collaborators were killed when dozens of masked gunmen stormed a jailhouse and set free several prisoners .
#   Entity: Palestinian, Label: NORP
#   Entity: Israeli, Label: NORP
#
#
# Sentence: Germany , France and Lithuania are the latest European countries to congratulate Viktor Yushchenko on his victory in the Ukrainian presidential election .
#   Entity: Germany, Label: GPE
#   Entity: France, Label: GPE
#   Entity: Lithuania, Label: GPE
#   Entity: European, Label: NORP
#   Entity: Viktor Yushchenko, Label: PERSON
#   Entity: Ukrainian, Label: NORP
#
#
# Sentence: In a letter to Mr. Yushchenko Tuesday , German Chancellor Gerhard Schroeder expressed optimism that Ukraine will continue what he called its transition toward the rule of law and a market economy .
#   Entity: Yushchenko, Label: PERSON
#   Entity: Tuesday, Label: DATE
#   Entity: German, Label: NORP
#   Entity: Gerhard Schroeder, Label: PERSON
#   Entity: Ukraine, Label: GPE
#
#
# Sentence: Lithuanian President Viktor Adamkus congratulated Mr. Yushchenko in a telephone conversation .
#   Entity: Lithuanian, Label: NORP
#   Entity: Viktor Adamkus, Label: PERSON
#   Entity: Yushchenko, Label: PERSON
#
#
# Sentence: In Paris , the foreign ministry said France and its European Union partners are determined to support democracy and modernization in Ukraine .
#   Entity: Paris, Label: GPE
#   Entity: France, Label: GPE
#   Entity: European Union, Label: ORG
#   Entity: Ukraine, Label: GPE
#
#
# Sentence: Meanwhile , Russia has questioned the objectivity of monitors for the Organization for Security and Cooperation in Europe .
#   Entity: Russia, Label: GPE
#   Entity: the Organization for Security and Cooperation in Europe, Label: ORG
#
#
# Sentence: That organization characterized last month 's presidential election re-run as flawed , while saying that Sunday 's poll vastly improved upon the last vote .
#   Entity: last month 's, Label: DATE
#   Entity: Sunday, Label: DATE
#
#
# Sentence: Russia backed Mr. Yushchenko 's opponent .
#   Entity: Russia, Label: GPE
#   Entity: Yushchenko, Label: PERSON
#
#
# Sentence: U.S. weather forecasters say Tropical Storm Ernesto has formed over the Caribbean and is heading toward Jamaica and the Cayman Islands .
#   Entity: U.S., Label: GPE
#   Entity: Caribbean, Label: LOC
#   Entity: Jamaica, Label: GPE
#   Entity: the Cayman Islands, Label: GPE
#
#
# Sentence: The National Hurricane Center thinks the storm could strengthen in coming days and is on track to enter the Gulf of Mexico next week .
#   Entity: The National Hurricane Center, Label: ORG
#   Entity: coming days, Label: DATE
#   Entity: the Gulf of Mexico, Label: LOC
#   Entity: next week, Label: DATE
#
#
# Sentence: The center is urging Jamaica and the Cayman Islands to monitor the threats posed by Ernesto , the fifth named storm of the season .
#   Entity: Jamaica, Label: GPE
#   Entity: the Cayman Islands, Label: GPE
#   Entity: Ernesto, Label: PERSON
#
#
# Sentence: Earlier Friday , Tropical Storm Debby weakened over the Atlantic .
#   Entity: Earlier Friday, Label: DATE
#   Entity: Atlantic, Label: LOC
#
#
# Sentence: The National Hurricane Center in Miami says Debby is about 2,200 kilometers northwest of the Cape Verde Islands , with winds near 65 kilometers per hour .
#   Entity: The National Hurricane Center, Label: ORG
#   Entity: Miami, Label: GPE
#   Entity: Debby, Label: PERSON
#   Entity: the Cape Verde Islands, Label: LOC
#
#
# Sentence: It says no significant change in strength is expected over the next day .
#   Entity: the next day, Label: DATE
#
#
# Sentence: Ethiopian security forces say they have foiled what they describe as a terrorist plot by a group linked to the country 's main opposition party .
#   Entity: Ethiopian, Label: NORP
#
#
# Sentence: A statement released through state media says authorities arrested a group that was planning attacks in the capital , Addis Ababa .
#   Entity: Addis Ababa, Label: GPE
#
#
# Sentence: The statement says the group planned to target government officials and institutions .
#
#
# Sentence: Ethiopian authorities say they also seized bombs , explosives and small arms related to the plot .
#   Entity: Ethiopian, Label: NORP
#
#
# Sentence: The statement did not say how many people were arrested or explain how the alleged group is linked to the opposition Coalition for Unity and Democracy .
#   Entity: Coalition for Unity and Democracy, Label: ORG
#
#
# Sentence: Leaders of the party were not available for comment .
#
#
# Sentence: Ethiopian Prime Minister Meles Zenawi has repeatedly accused the opposition of conspiring to incite violence and seeking to overthrow him .
#   Entity: Ethiopian, Label: NORP
#   Entity: Meles Zenawi, Label: PERSON
#
#
# Sentence: The government has charged at least 129 opposition leaders , journalists and others with treason and planning to commit genocide .
#
#
# Sentence: United Nations Secretary-General Kofi Annan has ordered disciplinary action against senior U.N. officials who worked on the oil-for-food program in Iraq .
#   Entity: United Nations, Label: ORG
#   Entity: Kofi Annan, Label: PERSON
#   Entity: U.N., Label: ORG
#   Entity: Iraq, Label: GPE
#
#
# Sentence: Mr. Annan said in a statement Thursday a report about alleged corruption in the U.N. program has turned up " extremely troubling evidence of wrongdoing , " and he pledged that no one involved would be shielded from prosecution .
#   Entity: Annan, Label: PERSON
#   Entity: Thursday, Label: DATE
#   Entity: U.N., Label: ORG
#
#
# Sentence: The independent report , released Thursday , concluded that the head of the oil-for-food program , Benon Sevan , seriously undermined the integrity of the United Nations by his conduct .
#   Entity: Thursday, Label: DATE
#   Entity: Benon Sevan, Label: PERSON
#   Entity: the United Nations, Label: ORG
#
#
# Sentence: U.N. disciplinary proceedings have begun against Mr. Sevan and another senior official , Joseph Stephanides .
#   Entity: U.N., Label: ORG
#   Entity: Sevan, Label: PERSON
#   Entity: Joseph Stephanides, Label: PERSON
#
#
# Sentence: Both Mr. Sevan and Mr. Stephanides are Cypriot nationals .
#   Entity: Sevan, Label: PERSON
#   Entity: Stephanides, Label: PERSON
#   Entity: Cypriot, Label: NORP
#
#
# Sentence: Critics say billions of dollars were siphoned away from the oil-for-food program , which was devised after the first Gulf War in an attempt to help Iraq 's impoverished civilian population .
#   Entity: billions of dollars, Label: MONEY
#   Entity: Iraq, Label: GPE
#
#
# Sentence: Rebels and government forces in Ivory Coast began withdrawing heavy weapons from the front line Thursday , complying with a new peace deal to end tensions in the divided nation .
#   Entity: Ivory Coast, Label: GPE
#   Entity: Thursday, Label: DATE
#
#
# Sentence: The pullback , expected to last four days , includes all guns larger than 20 millimeters and short-range weaponry equal to or larger than 60 millimeters , including mortars .
#   Entity: last four days, Label: DATE
#
#
# Sentence: Anti-tank weapons will remain in place .
#
#
# Sentence: One rebel fighter told VOA he was happy to see the repeatedly postponed disarmament process begin , adding that he hopes to become a police officer once the two-year-old conflict is finally over .
#   Entity: VOA, Label: ORG
#   Entity: two-year-old, Label: DATE
#
#
# Sentence: Several peace deals have failed to take hold in Ivory Coast .
#   Entity: Ivory Coast, Label: GPE
#
#
# Sentence: Rebels still hold huge swaths of territory in northern and western Ivory Coast , with the government firmly in control of the south .
#   Entity: Ivory Coast, Label: GPE
#
#
# Sentence: News reports from Uzbekistan say sporadic gunfire has continued in areas along the Kyrgyz border , following Friday 's military crackdown against protesters in the city of Andijan .
#   Entity: Uzbekistan, Label: GPE
#   Entity: Kyrgyz, Label: NORP
#   Entity: Friday, Label: DATE
#   Entity: Andijan, Label: GPE
#
#
# Sentence: The Associated Press quoted residents as saying several soldiers and civilians were killed when clashes erupted Sunday in two border villages , Teshiktosh and Karasu .
#   Entity: The Associated Press, Label: ORG
#   Entity: Sunday, Label: DATE
#   Entity: Teshiktosh, Label: GPE
#   Entity: Karasu, Label: PERSON
#
#
# Sentence: Earlier reports said as many as 500 people were killed when security forces fired into a crowd of demonstrators in Andijan on Friday .
#   Entity: Andijan, Label: GPE
#   Entity: Friday, Label: DATE
#
#
# Sentence: But Uzbek President Islam Karimov said the death toll was much lower .
#   Entity: Uzbek, Label: NORP
#   Entity: Islam Karimov, Label: PERSON
#
#
# Sentence: He blamed the bloodshed on Islamic radicals trying to overthrow the government .
#   Entity: Islamic, Label: NORP
#
#
# Sentence: Several countries , including the United States , have called for restraint .
#   Entity: the United States, Label: GPE
#
#
# Sentence: British Foreign Secretary Jack Straw called the Andijan crackdown a clear abuse of human rights .
#   Entity: British, Label: NORP
#   Entity: Jack Straw, Label: PERSON
#   Entity: Andijan, Label: PERSON
#
#
# Sentence: Pope John Paul II has included prayers for the victims of the Asian tsunami in his New Year 's Day Mass marking the Roman Catholic Church 's annual World Day of Peace .
#   Entity: John Paul II, Label: PERSON
#   Entity: Asian, Label: NORP
#   Entity: the Roman Catholic Church 's, Label: ORG
#   Entity: annual, Label: DATE
#
#
# Sentence: Thousands of pilgrims attended the Pope 's outdoor Mass Saturday at the Vatican .
#   Entity: Saturday, Label: DATE
#
#
# Sentence: John Paul II also led a Mass for the tsunami victims in his private chapel overnight .
#   Entity: John Paul II, Label: PERSON
#
#
# Sentence: In his peace message , the pontiff called for greater cooperation among the world 's religions , and for promotion of peace through dialogue , justice and forgiveness .
#
#
# Sentence: He urged the world 's one billion Roman Catholics to , " win the fight over evil with the armies of love . "
#   Entity: one billion, Label: MONEY
#   Entity: Roman Catholics, Label: NORP
#
#
# Sentence: The European Union opened membership talks with Turkey early Tuesday , after settling last-minute objections by Austria .
#   Entity: The European Union, Label: ORG
#   Entity: Turkey, Label: GPE
#   Entity: early Tuesday, Label: DATE
#   Entity: Austria, Label: GPE
#
#
# Sentence: EU foreign ministers ended 30 hours of heated emergency meetings late Monday in Luxembourg with Austrian officials withdrawing Vienna 's demand that the EU retain the option of offering Turkey a limited partnership .
#   Entity: EU, Label: ORG
#   Entity: late Monday, Label: DATE
#   Entity: Luxembourg, Label: GPE
#   Entity: Austrian, Label: NORP
#   Entity: Vienna, Label: GPE
#   Entity: EU, Label: ORG
#   Entity: Turkey, Label: GPE
#
#
# Sentence: Turkey had rejected the option .
#   Entity: Turkey, Label: GPE
#
#
# Sentence: Austria 's cooperation paved the way for all 25 EU member-states to agree on a negotiating framework for the membership process , which is expected to take about 10 years .
#   Entity: Austria, Label: GPE
#   Entity: EU, Label: ORG
#   Entity: about 10 years, Label: DATE
#
#
# Sentence: A brief ceremony to officially open the talks took place shortly after midnight Tuesday in Luxembourg .
#   Entity: Tuesday, Label: DATE
#   Entity: Luxembourg, Label: GPE
#
#
# Sentence: Talks had been scheduled to open Monday .
#   Entity: Monday, Label: DATE
#
#
# Sentence: If accepted , Turkey would be the first country with a majority Muslim population to join the European Union .
#   Entity: Turkey, Label: GPE
#   Entity: Muslim, Label: NORP
#   Entity: the European Union, Label: ORG
#
#
# Sentence: It has been an associate member of the bloc since 1963 .
#   Entity: 1963, Label: DATE
#
#
# Sentence: Egyptian President Hosni Mubarak has called for both his supporters and opponents to work with him as he embarks on his fifth presidential term .
#   Entity: Egyptian, Label: NORP
#   Entity: Hosni Mubarak, Label: PERSON
#
#
# Sentence: He took the oath of office Tuesday before parliament and several foreign dignitaries , including Libyan leader Moammar Gadhafi .
#   Entity: Tuesday, Label: DATE
#   Entity: Libyan, Label: NORP
#   Entity: Moammar Gadhafi, Label: PERSON
#
#
# Sentence: In a nationally televised speech , the 77-year-old leader pledged to continue a nascent program of political and economic reforms , and to improve the living standard of Egypt 's majority poor during his term , which runs through 2011 .
#   Entity: 77-year-old, Label: DATE
#   Entity: Egypt, Label: GPE
#   Entity: 2011, Label: DATE
#
#
# Sentence: He also promised November 's legislative elections will be " free and fair , " after criticisms that September 's first multi-candidate presidential race was rife with voting irregularities .
#   Entity: November, Label: DATE
#   Entity: September, Label: DATE
#
#
# Sentence: Mr. Mubarak beat nine challengers , winning more than 88 percent of the vote .
#   Entity: Mubarak, Label: PERSON
#
#
# Sentence: Japan says it wants safety guarantees for its players and fans when its national soccer ( football ) team travels to North Korea for a World Cup qualifying match in June .
#   Entity: Japan, Label: GPE
#   Entity: North Korea, Label: GPE
#   Entity: June, Label: DATE
#
#
# Sentence: Japan 's Chief Cabinet Secretary Hiroyuki Hosoda says it is a necessary precondition for any international match that players can play safely and spectators can be protected .
#   Entity: Japan, Label: GPE
#   Entity: Cabinet, Label: ORG
#   Entity: Hiroyuki Hosoda, Label: PERSON
#
#
# Sentence: Japanese concerns were raised by scenes of mob violence at a match in Pyongyang between Iran and North Korea on Wednesday .
#   Entity: Japanese, Label: NORP
#   Entity: Pyongyang, Label: GPE
#   Entity: Iran, Label: GPE
#   Entity: North Korea, Label: GPE
#   Entity: Wednesday, Label: DATE
#
#
# Sentence: The game was televised and cameras showed the North Korean spectators throwing bottles , cans and seats at players and officials on the field .
#   Entity: North Korean, Label: NORP
#
#
# Sentence: Riot police had to clear a path for the victorious Iranian players to reach their team bus .
#   Entity: Iranian, Label: NORP
#
#
# Sentence: The violence at the game was a rare occurrence in the tightly controlled North Korean state .
#   Entity: North Korean, Label: NORP
#
#
# Sentence: A published report says the United States has been flying drones over Iran for almost a year , looking for evidence of nuclear weapons programs and detect weaknesses in air defenses .
#   Entity: the United States, Label: GPE
#   Entity: Iran, Label: GPE
#   Entity: almost a year, Label: DATE
#
#
# Sentence: In Sunday 's editions , The Washington Post quotes three U.S. officials as saying the U.S. military has been launching the unmanned surveillance flights from Iraq .
#   Entity: Sunday, Label: DATE
#   Entity: The Washington Post, Label: ORG
#   Entity: U.S., Label: GPE
#   Entity: U.S., Label: GPE
#   Entity: Iraq, Label: GPE
#
#
# Sentence: There has been no U.S. comment on the report .
#   Entity: U.S., Label: GPE
#
#
# Sentence: An Iranian spokesman Sunday again warned the United States not to attack its nuclear facilities .
#   Entity: Iranian, Label: NORP
#   Entity: Sunday, Label: DATE
#   Entity: the United States, Label: GPE
#
#
# Sentence: He also rejected a European proposal aimed at restricting Tehran 's development of nuclear fuel .
#   Entity: European, Label: NORP
#   Entity: Tehran, Label: GPE
#
#
# Sentence: Iran has said in the past it would stop plans to build a heavy water nuclear reactor , which can be used to make nuclear weapons-grade material as well as for nuclear energy .
#   Entity: Iran, Label: GPE
#
#
# Sentence: But Sunday in Tehran , a foreign ministry spokesman said Iran will go forward with the heavy water reactor and will not replace it under any circumstances .
#   Entity: Sunday, Label: DATE
#   Entity: Tehran, Label: GPE
#   Entity: Iran, Label: GPE
#
#
# Sentence: North Korea says its Catholic community has organized religious services in memory of Pope John Paul .
#   Entity: North Korea, Label: GPE
#   Entity: Catholic, Label: NORP
#   Entity: John Paul, Label: PERSON
#
#
# Sentence: The official news agency , KCNA , on Tuesday quotes Samuel Jang Jae On , described as head of the country 's Catholic association , as saying North Korean Catholics are deeply saddened by the pontiff 's passing .
#   Entity: KCNA, Label: ORG
#   Entity: Tuesday, Label: DATE
#   Entity: Samuel Jang Jae, Label: PERSON
#   Entity: Catholic, Label: NORP
#   Entity: North Korean Catholics, Label: NORP
#
#
# Sentence: The agency says Mr. Jang sent the Vatican a message of condolence .
#   Entity: Jang, Label: PERSON
#
#
# Sentence: North Korea is widely described as one of the world 's most repressive political regimes .
#   Entity: North Korea, Label: GPE
#
#
# Sentence: It is not clear how many Catholics live in the Communist nation and to what extent they can practice their religion .
#   Entity: Catholics, Label: NORP
#   Entity: Communist, Label: NORP
#
#
# Sentence: Thousands of protesters have demonstrated outside a Philippine army camp , where U.S. soldiers and Philippine troops have begun joint military exercises .
#   Entity: Philippine, Label: NORP
#   Entity: U.S., Label: GPE
#   Entity: Philippine, Label: NORP
#
#
# Sentence: Demonstrators in the town of Carmen on the southern island of Mindanao chanted anti-U.S. slogans Tuesday and demanded that American troops leave the area .
#   Entity: Carmen, Label: PERSON
#   Entity: Mindanao, Label: LOC
#   Entity: anti-U.S., Label: NORP
#   Entity: Tuesday, Label: DATE
#   Entity: American, Label: NORP
#
#
# Sentence: U.S. soldiers will also take part in the Philippines ' annual war games , to be held next month on Jolo island in the southern Philippines .
#   Entity: U.S., Label: GPE
#   Entity: Philippines, Label: GPE
#   Entity: annual, Label: DATE
#   Entity: next month, Label: DATE
#   Entity: Jolo island, Label: LOC
#   Entity: Philippines, Label: GPE
#
#
# Sentence: Jolo is where the al-Qaida-linked militant group Abu Sayyaf has carried out bombings , kidnappings and killings of foreigners in recent years .
#   Entity: al-Qaida, Label: ORG
#   Entity: Abu Sayyaf, Label: PERSON
#   Entity: recent years, Label: DATE
#
#
# Sentence: Philippine law prohibits American troops from joining any combat operations with Philippine forces .
#   Entity: Philippine, Label: NORP
#   Entity: American, Label: NORP
#   Entity: Philippine, Label: NORP
#
#
# Sentence: Security for the war games will be tight , to protect the soldiers from attacks by rebels .
#
#
# Sentence: In addition to military training , troops will carry out humanitarian missions to try to boost support among Jolo 's residents .
#   Entity: Jolo, Label: ORG
#
#
# Sentence: The U.N. World Food Program is giving emergency assistance to the Cuban government .
#   Entity: The U.N. World Food Program, Label: ORG
#   Entity: Cuban, Label: NORP
#
#
# Sentence: The WFP announced Tuesday that it will help feed about two million people at a cost of nearly $ 6 million .
#   Entity: WFP, Label: ORG
#   Entity: Tuesday, Label: DATE
#   Entity: nearly $ 6 million, Label: MONEY
#
#
# Sentence: The aid package is intended to help Cuba recover from last month 's devastation from Hurricanes Gustav and Ike .
#   Entity: Cuba, Label: GPE
#   Entity: last month 's, Label: DATE
#   Entity: Ike, Label: PERSON
#
#
# Sentence: During the next six months , WFP will provide food rations , including rice , beans , vegetable oil , canned fish and more .
#   Entity: the next six months, Label: DATE
#   Entity: WFP, Label: ORG
#
#
# Sentence: The WFP will also supply temporary food storage warehouses and liquid gas stoves to people who lost their cooking facilities in the storms .
#   Entity: WFP, Label: ORG
#
#
# Sentence: Sweden 's Nobel Foundation begins announcing winners of the annual Nobel Prize awards on Monday in Oslo , Norway .
#   Entity: Sweden, Label: GPE
#   Entity: Nobel Foundation, Label: ORG
#   Entity: annual, Label: DATE
#   Entity: Monday, Label: DATE
#   Entity: Oslo, Label: GPE
#   Entity: Norway, Label: GPE
#
#
# Sentence: Prizes for medicine , physics , chemistry and literature will be announced before the prestigious Peace Prize is revealed Friday .
#   Entity: Friday, Label: DATE
#
#
# Sentence: A separate prize for economics will be announced October 10 .
#   Entity: October 10, Label: DATE
#
#
# Sentence: It was instituted in 1968 by the Bank of Sweden in memory of the founder of the Nobel Prize , Swedish philanthropist Alfred Nobel .
#   Entity: 1968, Label: DATE
#   Entity: the Bank of Sweden, Label: ORG
#   Entity: Swedish, Label: NORP
#   Entity: Alfred Nobel, Label: PERSON
#
#
# Sentence: Winners receive their awards , including a check worth $ 1.3 million , at a banquet on December 10 .
#   Entity: $ 1.3 million, Label: MONEY
#   Entity: December 10, Label: DATE
#
#
# Sentence: That is the anniversary of Mr. Nobel 's death in 1896 .
#   Entity: Nobel, Label: PERSON
#   Entity: 1896, Label: DATE
#
#
# Sentence: According to his will , a five-member committee elected by the Norwegian parliament chooses the Peace Prize laureate , while Swedish scientific and literary groups choose the other winners .
#   Entity: Norwegian, Label: NORP
#   Entity: Swedish, Label: NORP
#
#
# Sentence: The first Nobel Prizes were given in 1901 .
#   Entity: 1901, Label: DATE
#
#
# Sentence: Insurgents in Iraq fired a barrage of mortar rounds into central Baghdad
#   Entity: Iraq, Label: GPE
#   Entity: Baghdad, Label: GPE
#
#
# Sentence: Thursday , killing at least one person and wounding several others .
#   Entity: Thursday, Label: DATE
#
#
# Sentence: Police say some of the mortars landed in the Green Zone -- the heavily fortified enclave that houses Iraqi government offices and several foreign embassies .
#   Entity: the Green Zone, Label: LOC
#   Entity: Iraqi, Label: NORP
#
#
# Sentence: Last week , a mortar attack on the Green Zone killed four employees of a British security company .
#   Entity: Last week, Label: DATE
#   Entity: the Green Zone, Label: LOC
#   Entity: British, Label: NORP
#
#
# Sentence: Meanwhile , the U.S. military is planning to temporarily increase the number of American troops in Iraq to bolster security ahead of Iraq 's January election .
#   Entity: U.S., Label: GPE
#   Entity: American, Label: NORP
#   Entity: Iraq, Label: GPE
#   Entity: Iraq, Label: GPE
#   Entity: January, Label: DATE
#
#
# Sentence: The Defense Department said Wednesday the size of U.S. forces in Iraq will increase to 1,50,000 from its current level of 1,38,000 .
#   Entity: The Defense Department, Label: ORG
#   Entity: Wednesday, Label: DATE
#   Entity: U.S., Label: GPE
#   Entity: Iraq, Label: GPE
#
#
# Sentence: Iraq 's interim government has rejected calls from some Sunni parties to postpone the vote because of security concerns .
#   Entity: Iraq, Label: GPE
#   Entity: Sunni, Label: NORP
#
#
# Sentence: Brazilian lawmakers have approved legislation that will give the government more control over developing offshore oil fields .
#   Entity: Brazilian, Label: NORP
#
#
# Sentence: The lower house of the Brazilian congress passed the bill Wednesday , sending it to outgoing President Luiz Inacio Lula da Silva for his signature .
#   Entity: Brazilian, Label: NORP
#   Entity: Wednesday, Label: DATE
#   Entity: Luiz Inacio Lula da Silva, Label: PERSON
#
#
# Sentence: The measure allows the state-owned oil company , known as Petrobras , to be the sole operator of unexplored offshore oil fields , as well as a 30 percent stake in any joint ventures .
#   Entity: Petrobras, Label: ORG
#
#
# Sentence: Brazil has discovered potentially large oil reserves off the country 's southeastern coast , some of them thousands of meters below the sea floor .
#   Entity: Brazil, Label: GPE
#
#
# Sentence: Some estimates say the fields may contain more than 50 billion barrels of oil .
#   Entity: more than 50 billion barrels, Label: MONEY
#
#
# Sentence: Brazilian lawmakers also approved a provision that will allow non-oil producing states to receive more oil revenues .
#   Entity: Brazilian, Label: NORP
#
#
# Sentence: A new U.S. opinion survey shows eight out of 10 Americans believe the country is going in the wrong direction .
#   Entity: U.S., Label: GPE
#   Entity: Americans, Label: NORP
#
#
# Sentence: The Washington Post-ABC News poll also indicates Democrats hold a 21 percentage point advantage over Republicans as the party better equipped to handle the country 's problems .
#   Entity: The Washington Post-ABC News, Label: ORG
#   Entity: Democrats, Label: NORP
#   Entity: Republicans, Label: NORP
#
#
# Sentence: In a hypothetical general election match-up , Democratic Party candidate Senator Barack Obama leads presumed Republican nominee John McCain by 51-to-44 percent .
#   Entity: Democratic Party, Label: ORG
#   Entity: Barack Obama, Label: PERSON
#   Entity: Republican, Label: NORP
#   Entity: John McCain, Label: PERSON
#
#
# Sentence: As the Democratic Party nears the end of its presidential primaries , the national poll shows Obama has a 12-point advantage over Senator Hillary Clinton as the party 's choice for its nomination .
#   Entity: the Democratic Party, Label: ORG
#   Entity: Obama, Label: PERSON
#   Entity: Hillary Clinton, Label: PERSON
#
#
# Sentence: The poll says Americans cite the economy and employment as their top voting issue , followed by the Iraq war , healthcare and fuel prices .
#   Entity: Americans, Label: NORP
#
#
# Sentence: The poll of more than 1,100 adults , conducted from May 8 - 11 , has a margin of error of plus or minus three percentage points .
#   Entity: May 8 - 11, Label: DATE
#
#
# Sentence: Cuban President Raul Castro is visiting Venezuela on his first international trip as leader of the communist nation .
#   Entity: Cuban, Label: NORP
#   Entity: Raul Castro, Label: PERSON
#   Entity: Venezuela, Label: GPE
#   Entity: communist, Label: NORP
#
#
# Sentence: Venezuela 's socialist president , Hugo Chavez , welcomed Mr. Castro Saturday at the Caracas airport .
#   Entity: Venezuela, Label: GPE
#   Entity: Hugo Chavez, Label: PERSON
#   Entity: Castro, Label: PERSON
#   Entity: Saturday, Label: DATE
#
#
# Sentence: This is President Castro 's first official foreign trip since February , when the 77-year-old took charge from his ailing older brother , Fidel Castro .
#   Entity: Castro, Label: PERSON
#   Entity: February, Label: DATE
#   Entity: 77-year-old, Label: DATE
#   Entity: Fidel Castro, Label: PERSON
#
#
# Sentence: The two leaders will visit the tomb of South American independence icon Simon Bolivar today and later hold talks on a variety of issues .
#   Entity: South American, Label: NORP
#   Entity: Simon Bolivar, Label: PERSON
#   Entity: today, Label: DATE
#
#
# Sentence: Venezuela and Cuba have increased cooperation on energy and oil production .
#   Entity: Venezuela, Label: GPE
#   Entity: Cuba, Label: GPE
#
#
# Sentence: Venezuela is a critical trade partner for the Caribbean island nation , which imports nearly 1,00,000 barrels of oil per day from Venezuela .
#   Entity: Venezuela, Label: GPE
#   Entity: Caribbean, Label: LOC
#   Entity: Venezuela, Label: GPE
#
#
# Sentence: Today 's visit comes ahead of a summit in Brazil next week , where Latin American and Caribbean leaders will gather for talks .
#   Entity: Today, Label: DATE
#   Entity: Brazil, Label: GPE
#   Entity: next week, Label: DATE
#   Entity: Latin American, Label: NORP
#   Entity: Caribbean, Label: NORP
#
#
# Sentence: The nuclear cooperation pact between India and the United States has sparked a mixed reaction in Washington and abroad .
#   Entity: India, Label: GPE
#   Entity: the United States, Label: GPE
#   Entity: Washington, Label: GPE
#
#
# Sentence: International Atomic Energy Agency Director General Mohamed ElBaradei praised the agreement , saying it would bring India closer as an important partner in the non-proliferation group of countries .
#   Entity: International Atomic Energy Agency, Label: ORG
#   Entity: Mohamed ElBaradei, Label: PERSON
#   Entity: India, Label: GPE
#
#
# Sentence: But some U.S. lawmakers criticized the deal , saying the agreement that could give India access to U.S. civilian nuclear technology would undermine the Nuclear Non-Proliferation Treaty .
#   Entity: U.S., Label: GPE
#   Entity: India, Label: GPE
#   Entity: U.S., Label: GPE
#
#
# Sentence: India has not signed the treaty , which restricts the sharing of some nuclear technology with non-member nations , and drew widespread international criticism for conducting nuclear weapons tests as recently as 1998 .
#   Entity: India, Label: GPE
#   Entity: 1998, Label: DATE
#
#
# Sentence: Full details of the nuclear cooperation pact have not been released , but the agreement must still be approved by Congress before taking effect .
#   Entity: Congress, Label: ORG
#
#
# Sentence: President Bush acknowledged Thursday that hard work still needs to be done to gain the necessary approval in Congress .
#   Entity: Bush, Label: PERSON
#   Entity: Thursday, Label: DATE
#   Entity: Congress, Label: ORG
#
#
# Sentence: A Sudanese analyst says the late rebel leader John Garang was a symbol of the struggle for greater federalism in the country .
#   Entity: Sudanese, Label: NORP
#   Entity: John Garang, Label: PERSON
#
#
# Sentence: Lecturer John Gai Yoh of the University of South Africa ( UNISA ) in Pretoria credits the leader of the Sudanese Liberation Movement with creating a campaign that included allies beyond his base in the south .
#   Entity: John Gai Yoh, Label: PERSON
#   Entity: the University of South Africa, Label: ORG
#   Entity: UNISA, Label: ORG
#   Entity: Pretoria, Label: GPE
#   Entity: the Sudanese Liberation Movement, Label: ORG
#
#
# Sentence: Mr. Yoh notes that his vision materialized with the comprehensive peace agreement signed last January between the former SPLA rebels and the government in Khartoum .
#   Entity: Yoh, Label: PERSON
#   Entity: last January, Label: DATE
#   Entity: SPLA, Label: ORG
#   Entity: Khartoum, Label: GPE
#
#
# Sentence: Analyst John Gai Yoh predicts that the SPLA will continue to democratize : it has created a new SPLA parliament for the south and has named a new five-man military panel to lead the movement .
#   Entity: John Gai Yoh, Label: PERSON
#   Entity: SPLA, Label: ORG
#   Entity: SPLA, Label: ORG
#
#
# Sentence: The United Nations has given its annual Franklin Delano Roosevelt International Disability Award to Poland , recognizing the country 's efforts to integrate the disabled into Polish society .
#   Entity: The United Nations, Label: ORG
#   Entity: Franklin Delano Roosevelt International Disability Award, Label: ORG
#   Entity: Poland, Label: GPE
#   Entity: Polish, Label: NORP
#
#
# Sentence: President Lech Kaczynski accepted the award at a ceremony Monday at U.N. headquarters in New York .
#   Entity: Lech Kaczynski, Label: PERSON
#   Entity: Monday, Label: DATE
#   Entity: U.N., Label: ORG
#   Entity: New York, Label: GPE
#
#
# Sentence: He said his country 's struggle for freedom includes a commitment to the rights of those with disabilities .
#
#
# Sentence: He said their rights are guaranteed by the Polish constitution .
#   Entity: Polish, Label: NORP
#
#
# Sentence: Mr. Kaczynski promised that Poland will adopt a new U.N. convention to protect the disabled .
#   Entity: Kaczynski, Label: PERSON
#   Entity: Poland, Label: GPE
#   Entity: U.N., Label: ORG
#
#
# Sentence: The award is named for U.S. President Franklin Roosevelt , whose legs were paralyzed from polio .
#   Entity: U.S., Label: GPE
#   Entity: Franklin Roosevelt, Label: PERSON
#
#
# Sentence: Mr. Roosevelt was president from 1933 until 1945 .
#   Entity: Roosevelt, Label: PERSON
#   Entity: 1933, Label: DATE
#   Entity: 1945, Label: DATE
#
#
# Sentence: An Ethiopian government spokesman denies that a reported rebel attack said to have killed 140 soldiers ever took place .
#   Entity: Ethiopian, Label: NORP
#
#
# Sentence: The spokesman , Zemedkun Tekle , issued the denial Sunday after media reports said the Ogaden National Liberation Front had claimed to have carried out the deadly attack Saturday in southeastern Ethiopia near Wardheer .
#   Entity: Zemedkun Tekle, Label: PERSON
#   Entity: Sunday, Label: DATE
#   Entity: the Ogaden National Liberation Front, Label: ORG
#   Entity: Saturday, Label: DATE
#   Entity: Ethiopia, Label: GPE
#   Entity: Wardheer, Label: ORG
#
#
# Sentence: A purported statement from the group received by some news organizations said about a thousand rebels took part in the attack and seized ammunition along with military hardware .
#
#
# Sentence: The government spokesman says there was no attack , and that the rebel group is not in a position to carry out such an attack .
#
#
# Sentence: Rebels have been fighting for more autonomy for ethnic Somalis in the eastern region of Ogaden bordering Somalia .
#   Entity: Somalis, Label: NORP
#   Entity: Ogaden, Label: GPE
#   Entity: Somalia, Label: GPE
#
#
# Sentence: Kuwaiti television reports the kidnappers in Iraq of American journalist Jill Carroll are threatening to kill her if their demands are not met by February 26 .
#   Entity: Kuwaiti, Label: NORP
#   Entity: Iraq, Label: GPE
#   Entity: American, Label: NORP
#   Entity: Jill Carroll, Label: PERSON
#   Entity: February 26, Label: DATE
#
#
# Sentence: Al-Rai television Friday quoted sources close to the kidnappers as saying the abductors have set the deadline .
#   Entity: Al-Rai, Label: PERSON
#   Entity: Friday, Label: DATE
#
#
# Sentence: The militants holding Carroll previously had demanded that all Iraqi women prisoners be freed .
#   Entity: Carroll, Label: ORG
#   Entity: Iraqi, Label: NORP
#
#
# Sentence: Earlier Friday , at least eight people died and more than 20 were wounded in a Baghdad car bombing near a Sunni Muslim mosque .
#   Entity: Earlier Friday, Label: DATE
#   Entity: Baghdad, Label: GPE
#   Entity: Sunni Muslim, Label: NORP
#
#
# Sentence: Officials in Iraq also certified results of the December 15 elections , confirming the near majority of parliament seats won by Shi'ite religious parties .
#   Entity: Iraq, Label: GPE
#   Entity: December 15, Label: DATE
#   Entity: Shi'ite, Label: NORP
#
#
# Sentence: According to the results , the dominant Shi'ite coalition , the United Iraqi Alliance , won 128 seats in the 275-member parliament .
#   Entity: Shi'ite, Label: NORP
#   Entity: the United Iraqi Alliance, Label: ORG
#
#
# Sentence: Palestinian security officials say masked Palestinian police briefly stormed a government building in the Gaza Strip in anger over not receiving their salaries from the Hamas-led government .
#   Entity: Palestinian, Label: NORP
#   Entity: Palestinian, Label: NORP
#   Entity: the Gaza Strip, Label: GPE
#   Entity: Hamas, Label: ORG
#
#
# Sentence: Security officials say about 50 police officers sealed off the main road Saturday in the central Gaza town of Khan Younis .
#   Entity: Saturday, Label: DATE
#   Entity: Gaza, Label: GPE
#   Entity: Khan Younis, Label: PERSON
#
#
# Sentence: They say the masked police surrounded a municipal government building , taking positions on the roof and firing in the air .
#
#
# Sentence: The protest is seen as a sign of discontent with the new Hamas-led government , which took office late last month .
#   Entity: Hamas, Label: ORG
#   Entity: late last month, Label: DATE
#
#
# Sentence: The cash-strapped Palestinian Authority has not been able to pay salaries to some 1,40,000 government employees since March .
#   Entity: Palestinian Authority, Label: ORG
#   Entity: March, Label: DATE
#
#
# Sentence: Western nations have cut off aid to the Palestinian government , demanding that Hamas renounce violence and recognize Israel .
#   Entity: Western, Label: NORP
#   Entity: Palestinian, Label: NORP
#   Entity: Hamas, Label: ORG
#   Entity: Israel, Label: GPE
#
#
# Sentence: The White House said President Bush has approved duty-free treatment for imports of certain types of watches that are n't produced in " significant quantities " in the U.S. , the Virgin Islands and other U.S. possessions .
#   Entity: The White House, Label: ORG
#   Entity: Bush, Label: PERSON
#   Entity: U.S., Label: GPE
#   Entity: the Virgin Islands, Label: GPE
#   Entity: U.S., Label: GPE
#
#
# Sentence: The action came in response to a petition filed by Timex Inc. for changes in the U.S. Generalized System of Preferences for imports from developing nations .
#   Entity: Timex Inc., Label: ORG
#   Entity: the U.S. Generalized System of Preferences, Label: ORG
#
#
# Sentence: Previously , watch imports were denied such duty-free treatment .
#
#
# Sentence: Timex had requested duty-free treatment for many types of watches , covered by 58 different U.S. tariff classifications .
#   Entity: Timex, Label: ORG
#   Entity: U.S., Label: GPE
#
#
# Sentence: The White House said Mr. Bush decided to grant duty-free status for 18 categories , but turned down such treatment for other types of watches " because of the potential for material injury to watch producers located in the U.S. and the Virgin Islands . "
#   Entity: The White House, Label: ORG
#   Entity: Bush, Label: PERSON
#   Entity: U.S., Label: GPE
#   Entity: the Virgin Islands, Label: GPE
#
#
# Sentence: Timex is a major U.S. producer and seller of watches , including low-priced battery-operated watches assembled in the Philippines and other developing nations covered by the U.S. tariff preferences .
#   Entity: Timex, Label: ORG
#   Entity: U.S., Label: GPE
#   Entity: Philippines, Label: GPE
#   Entity: U.S., Label: GPE
#
#
# Sentence: U.S. trade officials said the Philippines and Thailand would be the main beneficiaries of the president 's action .
#   Entity: U.S., Label: GPE
#   Entity: Philippines, Label: GPE
#   Entity: Thailand, Label: GPE
#
#
# Sentence: Imports of the types of watches that now will be eligible for duty-free treatment totaled about $ 37.3 million in 1988 , a relatively small share of the $ 1.5 billion in U.S. watch imports that year , according to an aide to U.S. Trade Representative Carla Hills .
#   Entity: about $ 37.3 million, Label: MONEY
#   Entity: 1988, Label: DATE
#   Entity: $ 1.5 billion, Label: MONEY
#   Entity: U.S., Label: GPE
#   Entity: that year, Label: DATE
#   Entity: U.S., Label: GPE
#   Entity: Carla Hills, Label: PERSON
#
#
# Sentence: Although known to Arab and Malay sailors as early as the 10th century , Mauritius was first explored by the Portuguese in the 16th century and subsequently settled by the Dutch - who named it in honor of Prince Maurits van NASSAU - in the 17th century .
#   Entity: Arab, Label: NORP
#   Entity: Malay, Label: NORP
#   Entity: the 10th century, Label: DATE
#   Entity: Mauritius, Label: GPE
#   Entity: Portuguese, Label: NORP
#   Entity: the 16th century, Label: DATE
#   Entity: Dutch, Label: NORP
#   Entity: Prince Maurits van NASSAU, Label: ORG
#   Entity: the 17th century, Label: DATE
#
#
# Sentence: The French assumed control in 1715 , developing the island into an important naval base overseeing Indian Ocean trade , and establishing a plantation economy of sugar cane .
#   Entity: French, Label: NORP
#   Entity: Indian Ocean, Label: LOC
#
#
# Sentence: The British captured the island in 1810 , during the Napoleonic Wars .
#   Entity: British, Label: NORP
#   Entity: 1810, Label: DATE
#
#
# Sentence: Mauritius remained a strategically important British naval base , and later an air station , playing an important role during World War II for anti-submarine and convoy operations , as well as the collection of signals intelligence .
#   Entity: Mauritius, Label: GPE
#   Entity: British, Label: NORP
#
#
# Sentence: Independence from the UK was attained in 1968 .
#   Entity: Independence, Label: GPE
#   Entity: UK, Label: GPE
#   Entity: 1968, Label: DATE
#
#
# Sentence: A stable democracy with regular free elections and a positive human rights record , the country has attracted considerable foreign investment and has earned one of Africa 's highest per capita incomes .
#   Entity: Africa, Label: LOC
#
#
# Sentence: Recent poor weather , declining sugar prices , and declining textile and apparel production , have slowed economic growth , leading to some protests over standards of living in the Creole community .
#   Entity: Creole, Label: NORP
#
#
# Sentence: Morocco 's market economy benefits from the country 's relatively low labor costs and proximity to Europe , which aid key areas of the economy such as agriculture , light manufacturing , tourism , and remittances .
#   Entity: Morocco, Label: GPE
#   Entity: Europe, Label: LOC
#
#
# Sentence: Morocco is also the world 's largest exporter of phosphate , which has long provided a source of export earnings and economic stability .
#   Entity: Morocco, Label: GPE
#
#
# Sentence: Economic policies pursued since 2003 by King MOHAMMED VI have brought macroeconomic stability to the country with generally low inflation , improved financial performance , and steady progress in developing the service and industrial sectors .
#   Entity: 2003, Label: DATE
#   Entity: King MOHAMMED VI, Label: ORG
#
#
# Sentence: In 2006 , Morocco entered a Free Trade Agreement ( FTA ) with the US , and in 2008 entered into an advanced status in its 2000 Association Agreement with the EU .
#   Entity: 2006, Label: DATE
#   Entity: Morocco, Label: GPE
#   Entity: US, Label: GPE
#   Entity: 2008, Label: DATE
#   Entity: 2000, Label: DATE
#   Entity: EU, Label: ORG
#
#
# Sentence: However , poverty , illiteracy , and unemployment rates remain high .
#
#
# Sentence: In response to these challenges , King MOHAMMED in 2005 launched a National Initiative for Human Development , a $ 2 billion program aimed at alleviating poverty and underdevelopment by expanding electricity to rural areas and replacing urban slums with public and subsidized housing , among other policies .
#   Entity: King MOHAMMED, Label: PERSON
#   Entity: 2005, Label: DATE
#   Entity: National Initiative for Human Development, Label: ORG
#   Entity: $ 2 billion, Label: MONEY
#
#
# Sentence: Morocco 's trade and budget deficits widened in 2010 , and reducing government spending and adapting to sluggish economic growth in Europe will be challenges in 2011 .
#   Entity: Morocco, Label: GPE
#   Entity: 2010, Label: DATE
#   Entity: Europe, Label: LOC
#   Entity: 2011, Label: DATE
#
#
# Sentence: Morocco 's long-term challenges include improving education and job prospects for young Moroccans , closing the disparity in wealth between the rich and the poor , confronting corruption , and expanding and diversifying exports beyond phosphates and low-value-added products .
#   Entity: Morocco, Label: GPE
#   Entity: Moroccans, Label: NORP
#
#
# Sentence: Albania , a formerly closed , centrally-planned state , is making the difficult transition to a more modern open-market economy .
#   Entity: Albania, Label: GPE
#
#
# Sentence: Macroeconomic growth averaged around 6 % between 2004 - 8 , but declined to about 3 % in 2009 - 10 .
#   Entity: between 2004 - 8, Label: DATE
#   Entity: 2009 - 10, Label: DATE
#
#
# Sentence: Inflation is low and stable .
#
#
# Sentence: The government has taken measures to curb violent crime , and recently adopted a fiscal reform package aimed at reducing the large gray economy and attracting foreign investment .
#
#
# Sentence: Remittances , a significant catalyst for economic growth have declined from Dec-15 % of GDP to 9 % of GDP in 2009 , mostly from Albanians residing in Greece and Italy ; this helps offset the towering trade deficit .
#   Entity: 2009, Label: DATE
#   Entity: Albanians, Label: NORP
#   Entity: Greece, Label: GPE
#   Entity: Italy, Label: GPE
#
#
# Sentence: The agricultural sector , which accounts for almost half of employment but only about one-fifth of GDP , is limited primarily to small family operations and subsistence farming because of lack of modern equipment , unclear property rights , and the prevalence of small , inefficient plots of land .
#
#
# Sentence: Energy shortages because of a reliance on hydropower , and antiquated and inadequate infrastructure contribute to Albania 's poor business environment and lack of success in attracting new foreign investment needed to expand the country 's export base .
#   Entity: Albania, Label: GPE
#
#
# Sentence: FDI is among the lowest in the region , but the government has embarked on an ambitious program to improve the business climate through fiscal and legislative reforms .
#
#
# Sentence: The completion of a new thermal power plant near Vlore has helped diversify generation capacity , and plans to upgrade transmission lines between Albania and Montenegro and Kosovo would help relieve the energy shortages .
#   Entity: Vlore, Label: GPE
#   Entity: Albania, Label: GPE
#   Entity: Montenegro, Label: GPE
#   Entity: Kosovo, Label: GPE
#
#
# Sentence: Also , with help from EU funds , the government is taking steps to improve the poor national road and rail network , a long-standing barrier to sustained economic growth .
#   Entity: EU, Label: ORG
#
#
# Sentence: Economic activity consists primarily of subsistence farming and fishing .
#
#
# Sentence: The islands have few mineral deposits worth exploiting , except for high-grade phosphate .
#
#
# Sentence: The potential for a tourist industry exists , but the remote location , a lack of adequate facilities , and limited air connections hinder development .
#
#
# Sentence: Under the original terms of the Compact of Free Association , the US provided $ 1.3 billion in grant aid during the period 1986 - 2001 ; the level of aid has been subsequently reduced .
#   Entity: the Compact of Free Association, Label: ORG
#   Entity: US, Label: GPE
#   Entity: $ 1.3 billion, Label: MONEY
#   Entity: 1986 - 2001, Label: DATE
#
#
# Sentence: The Amended Compact of Free Association with the US guarantees the Federated States of Micronesia ( FSM ) millions of dollars in annual aid through 2023 , and establishes a Trust Fund into which the US and the FSM make annual contributions in order to provide annual payouts to the FSM in perpetuity after 2023 .
#   Entity: The Amended Compact of Free Association, Label: ORG
#   Entity: US, Label: GPE
#   Entity: the Federated States of Micronesia, Label: GPE
#   Entity: FSM, Label: ORG
#   Entity: millions of dollars, Label: MONEY
#   Entity: annual, Label: DATE
#   Entity: 2023, Label: DATE
#   Entity: Trust Fund, Label: ORG
#   Entity: US, Label: GPE
#   Entity: FSM, Label: ORG
#   Entity: annual, Label: DATE
#   Entity: annual, Label: DATE
#   Entity: FSM, Label: ORG
#   Entity: 2023, Label: DATE
#
#
# Sentence: The country 's medium-term economic outlook appears fragile due not only to the reduction in US assistance but also to the current slow growth of the private sector .
# ...
#
#
# Sentence: A first launch is planned for 2018 at a launch center in Siberia .
#   Entity: 2018, Label: DATE
#   Entity: Siberia, Label: LOC
#
#
# Sentence: Under the pact , Russia will build the capsule , while European engineers build the service module and the engine block .
#   Entity: Russia, Label: GPE
#   Entity: European, Label: NORP
#
#
# Sentence: The new craft is to be phased in as the replacement for Russia 's Soyuz spacecraft , which has come under increased scrutiny this year , after two consecutive rough landings on return from the International Space Station .
#   Entity: Russia, Label: GPE
#   Entity: this year, Label: DATE
#
#
# Sentence: A human-rights group in Niger says the government is to blame for cancellation of a ceremony that was to grant 7,000 slaves their freedom .
#   Entity: Niger, Label: GPE
#
#
# Sentence: The group Timidria had planned to release the slaves in the Ates region near Niger 's western border with Mali on Saturday , but the event was called off when none of the slaves showed up .
#   Entity: Timidria, Label: PERSON
#   Entity: Ates, Label: GPE
#   Entity: Niger, Label: GPE
#   Entity: Mali, Label: GPE
#   Entity: Saturday, Label: DATE
#
#
# Sentence: The rights group says the government intimidated slaves to keep them from attending the ceremony - a charge the government denies .
#
#
# Sentence: Niger officially banned slavery in 2003 , but human-rights groups say 43,000 people are still in bondage in the West African nation .
#   Entity: Niger, Label: GPE
#   Entity: 2003, Label: DATE
#   Entity: West African, Label: NORP
#
#
# Sentence: They are among the 2,00,000 people enslaved along centuries-old Arab-African Saharan trade routes .
#   Entity: centuries-old, Label: DATE
#   Entity: Arab-African, Label: NORP
#
#
# Sentence: Generations of Africans have been born in slavery , many under the ownership of one family .
#   Entity: Africans, Label: NORP
#
#
# Sentence: Embattled Ivory Coast President Laurent Gbagbo has said he wants to talk with his rival , Alassane Ouattara .
#   Entity: Ivory Coast, Label: GPE
#   Entity: Laurent Gbagbo, Label: PERSON
#   Entity: Alassane Ouattara, Label: PERSON
#
#
# Sentence: Mr. Gbagbo has been isolated by the international community , including the United States , after refusing to yield the presidency although he had fewer votes than Mr. Ouattara in last month 's poll .
#   Entity: Gbagbo, Label: PERSON
#   Entity: the United States, Label: GPE
#   Entity: Ouattara, Label: PERSON
#   Entity: last month 's, Label: DATE
#
#
# Sentence: Both men have taken the oath of office and begun organizing competing governments .
#
#
# Sentence: Earlier this week , the African Union dispatched former South African president Thabo Mbeki to seek a solution , but after two days of talks , the situation was not resolved .
#   Entity: Earlier this week, Label: DATE
#   Entity: the African Union, Label: ORG
#   Entity: South African, Label: NORP
#   Entity: Thabo Mbeki, Label: PERSON
#   Entity: two days, Label: DATE
#
#
# Sentence: The Ivory Coast 's presidential election , its first in 10 years , was meant to restore stability to the West African country , which was split into rebel- and government-controlled areas during a 2002 civil war .
#   Entity: The Ivory Coast 's, Label: GPE
#   Entity: 10 years, Label: DATE
#   Entity: West African, Label: NORP
#   Entity: 2002, Label: DATE
#
#
# Sentence: Officials in Afghanistan say a suicide bomber has killed four Afghan employees of a U.S.-owned private security firm and wounded one other in southern Kandahar province .
#   Entity: Afghanistan, Label: GPE
#   Entity: Afghan, Label: NORP
#   Entity: U.S.-owned, Label: NORP
#   Entity: Kandahar, Label: GPE
#
#
# Sentence: Authorities said Sunday the bomber rode a motorbike next to a vehicle owned by the company , U.S. Protection and Investigations , and detonated his explosives .
#   Entity: Sunday, Label: DATE
#   Entity: U.S. Protection and Investigations, Label: ORG
#
#
# Sentence: Three guards and the vehicle 's driver were killed , and another guard was wounded .
#
#
# Sentence: On Saturday , a suicide bomber killed seven police officers and a civilian in eastern Afghanistan 's Khost province , near the Pakistan border .
#   Entity: Saturday, Label: DATE
#   Entity: Afghanistan, Label: GPE
#   Entity: Khost, Label: GPE
#   Entity: Pakistan, Label: GPE
#
#
# Sentence: The Taleban is reported to have taken responsibility for the blast .
#
#
# Sentence: NATO forces in Afghanistan are preparing for another upsurge in violence this year , having already launched an operation in the south to preempt an anticipated offensive by Taleban fighters .
#   Entity: NATO, Label: ORG
#   Entity: Afghanistan, Label: GPE
#   Entity: this year, Label: DATE
#
#
# Sentence: Turkish police have detained more than 80 people and used tear gas to prevent thousands of leftist protesters from marching to Istanbul 's Taksim square to hold a May Day rally .
#   Entity: Turkish, Label: NORP
#   Entity: Istanbul, Label: GPE
#   Entity: May Day, Label: DATE
#
#
# Sentence: Authorities declared the square off-limits to protesters , but allowed a small number of trade union leaders to lay flowers at the square to mark the day .
#   Entity: the day, Label: DATE
#
#
# Sentence: Officials had shut down schools in the area for the day for fear of violence .
#   Entity: the day, Label: DATE
#
#
# Sentence: Members of leftist groups often clash with police during May Day observances in Turkey .
#   Entity: May Day, Label: DATE
#   Entity: Turkey, Label: GPE
#
#
# Sentence: In 1977 , a May Day rally at Taksim square turned violent when unidentified gunmen opened fire on a crowd of demonstrators .
#   Entity: 1977, Label: DATE
#   Entity: May Day, Label: DATE
#
#
# Sentence: Thirty-seven people were killed in that incident .
#
#
# Sentence: The race for Iraq 's new prime minister narrowed Tuesday , when one of two top Shi'ite parties withdrew its candidate from consideration .
#   Entity: Iraq, Label: GPE
#   Entity: Tuesday, Label: DATE
#   Entity: Shi'ite, Label: NORP
#
#
# Sentence: Interim Finance Minister Adel Abdul-Mahdi , who had been the candidate of the Supreme Council for the Islamic Revolution in Iraq , withdrew his name from contention .
#   Entity: Adel Abdul-Mahdi, Label: PERSON
#   Entity: the Supreme Council for the Islamic Revolution in Iraq, Label: ORG
#
#
# Sentence: This leaves the head of the Islamic Dawa Party , Ibrahim al-Jaafari , as the likely front-runner .
#   Entity: the Islamic, Label: ORG
#   Entity: Ibrahim al-Jaafari, Label: PERSON
#
#
# Sentence: Both parties belong to the United Iraqi Alliance , which won about 48 percent of the vote for the National Assembly .
#   Entity: the United Iraqi Alliance, Label: ORG
#   Entity: the National Assembly, Label: ORG
#
#
# Sentence: Meanwhile , Iraq 's Electoral Commission says it has received at least three complaints from political groups challenging the election results .
#   Entity: Iraq, Label: GPE
#   Entity: Electoral Commission, Label: ORG
#
#
# Sentence: A final , certified vote tally is expected Wednesday .
#   Entity: Wednesday, Label: DATE
#
#
# Sentence: And Turkish shipping magnate Kahraman Sadikoglu , who was abducted in southern Iraq in December , has been freed after reports said his family paid a ransom to his kidnappers .
#   Entity: Turkish, Label: NORP
#   Entity: Kahraman Sadikoglu, Label: PERSON
#   Entity: Iraq, Label: GPE
#   Entity: December, Label: DATE
#
#
# Sentence: A Council of Europe panel says Turkey has passed important legislation protecting minority rights , but has not adequately enforced the new laws .
#   Entity: Council of Europe, Label: ORG
#   Entity: Turkey, Label: GPE
#
#
# Sentence: In a report , the European Commission against Racism and Intolerance says that despite the new legislation , Turkey 's constitution and its civil , criminal and administrative laws continue to have gaps in addressing racism .
#   Entity: the European Commission, Label: ORG
#   Entity: Turkey, Label: GPE
#
#
# Sentence: The report , issued Tuesday in Strasbourg , says Kurds and other minorities still face adversity in Turkey , particularly from ongoing violence in the southeast where Kurdish separatists have been active in recent decades .
#   Entity: Tuesday, Label: DATE
#   Entity: Strasbourg, Label: GPE
#   Entity: Kurds, Label: NORP
#   Entity: Turkey, Label: GPE
#   Entity: Kurdish, Label: NORP
#   Entity: recent decades, Label: DATE
#
#
# Sentence: Turkey 's move to push through legal and economic reforms is considered an essential part of its bid to join the European Union .
#   Entity: Turkey, Label: GPE
#   Entity: the European Union, Label: ORG
#
#
# Sentence: The Council of Europe is a 46-nation group that brings together lawmakers from democratic European countries to review major issues facing the continent .
#   Entity: The Council of Europe, Label: ORG
#   Entity: European, Label: NORP
#
#
# Sentence: Armenia has launched an aerial tramway line that it says is the world 's longest .
#   Entity: Armenia, Label: GPE
#
#
# Sentence: President Serzh Sarkisian attended the opening of the tramway Saturday , in the country 's southern mountains near Armenia 's border with Iran .
#   Entity: Serzh Sarkisian, Label: PERSON
#   Entity: Saturday, Label: DATE
#   Entity: Armenia, Label: GPE
#   Entity: Iran, Label: GPE
#
#
# Sentence: The 5.7-kilometer engineering feat spans the Vorotan River gorge , linking a village off the main highway to the 9th century Tatev Monastery .
#   Entity: Vorotan River, Label: LOC
#   Entity: the 9th century, Label: DATE
#   Entity: Tatev Monastery, Label: PERSON
#
#
# Sentence: The monastery is one of the country 's oldest and most prominent monasteries and is a major tourist attraction .
#
#
# Sentence: The head of Cuba 's parliament has offered to support Iran in its fight to develop nuclear energy within Iranian borders .
#   Entity: Cuba, Label: GPE
#   Entity: Iran, Label: GPE
#   Entity: Iranian, Label: NORP
#
#
# Sentence: Ricardo Alarcon voiced solidarity Thursday in a meeting with the visiting speaker of Iran 's parliament , Gholam Ali Haddad Adel .
#   Entity: Ricardo Alarcon, Label: PERSON
#   Entity: Thursday, Label: DATE
#   Entity: Iran, Label: GPE
#   Entity: Gholam Ali Haddad Adel, Label: PERSON
#
#
# Sentence: Iran resumed enrichment of uranium for nuclear fuel earlier this week , despite international pressure against the move .
#   Entity: Iran, Label: GPE
#   Entity: earlier this week, Label: DATE
#
#
# Sentence: Haddad Adel is on a two-day visit to Cuba after spending Wednesday in Venezuela , where he thanked the government for its support on nuclear issues .
#   Entity: Haddad Adel, Label: PERSON
#   Entity: two-day, Label: DATE
#   Entity: Cuba, Label: GPE
#   Entity: Wednesday, Label: DATE
#   Entity: Venezuela, Label: GPE
#
#
# Sentence: Meanwhile , Indiana Representative Dan Burton , in an interview with Voice of America Thursday , expressed concern over the close ties between Iran and the two countries .
#   Entity: Indiana, Label: GPE
#   Entity: Dan Burton, Label: PERSON
#   Entity: Voice of America, Label: ORG
#   Entity: Thursday, Label: DATE
#   Entity: Iran, Label: GPE
#
#
# Sentence: He said if it appears that there is coordination between terrorist states and leftist organizations in Central America , the United States will intervene .
#   Entity: Central America, Label: LOC
#   Entity: the United States, Label: GPE
#
#
# Sentence: Representative Burton said such a relationship would endanger the United States and other countries in the hemisphere .
#   Entity: Burton, Label: PERSON
#   Entity: the United States, Label: GPE
#
#
# Sentence: European Union foreign ministers hold emergency talks in Luxembourg Sunday in efforts to break a deadlock on Turkey , which is scheduled to begin membership negotiations with the bloc one day later .
#   Entity: European Union, Label: ORG
#   Entity: Luxembourg, Label: GPE
#   Entity: Sunday, Label: DATE
#   Entity: Turkey, Label: GPE
#   Entity: one day later, Label: DATE
#
#
# Sentence: The ministers called the meeting after Austria insisted that EU talks with Turkey should include an alternative to giving the country full membership .
#   Entity: Austria, Label: GPE
#   Entity: EU, Label: ORG
#   Entity: Turkey, Label: GPE
#
#
# Sentence: Austria says most Austrians object to full EU membership for Turkey and suggested offering Turkey privileged partnership instead .
#   Entity: Austria, Label: GPE
#   Entity: Austrians, Label: NORP
#   Entity: EU, Label: ORG
#   Entity: Turkey, Label: GPE
#   Entity: Turkey, Label: GPE
#
#
# Sentence: But Turkey calls that unacceptable and says it will not take part in Monday 's talks unless it is clear that the goal is full membership .
#   Entity: Turkey, Label: GPE
#   Entity: Monday, Label: DATE
#
#
# Sentence: EU diplomats are working on proposals to soften Austrian opposition .
#   Entity: EU, Label: ORG
#   Entity: Austrian, Label: NORP
#
#
# Sentence: One would be a commitment to begin membership talks with Austria 's neighbor Croatia in the near future .
#   Entity: Austria, Label: GPE
#   Entity: Croatia, Label: GPE
#
#
# Sentence: EU ministers had delayed the talks because of Croatian failure to cooperate fully with The Hague war crimes tribunal .
#   Entity: EU, Label: ORG
#   Entity: Croatian, Label: NORP
#
#
# Sentence: Pakistani military authorities say they have arrested a key Taliban commander who is accused of slaughtering military personnel .
#   Entity: Pakistani, Label: NORP
#   Entity: Taliban, Label: ORG
#
#
# Sentence: Security forces said Wednesday they captured Taliban commander Sher Mohammad Qasab in the Swat Valley .
#   Entity: Wednesday, Label: DATE
#   Entity: Taliban, Label: ORG
#   Entity: Sher Mohammad Qasab, Label: PERSON
#   Entity: the Swat Valley, Label: LOC
#
#
# Sentence: Qasab is known for his brutality among locals in the valley .
#   Entity: Qasab, Label: PERSON
#
#
# Sentence: A military spokesman said Qasab was wounded and three of his sons died during an exchange of fire before his arrest .
#   Entity: Qasab, Label: PERSON
#
#
# Sentence: Pakistani forces have arrested key Taliban commanders recently in the valley , including Muslim Khan , the central spokesman for the militants .
#   Entity: Pakistani, Label: NORP
#   Entity: Taliban, Label: ORG
#   Entity: Muslim, Label: NORP
#
#
# Sentence: Authorities say the arrests have weakened the Taliban and are helping security forces conduct successful raids against other militants in the area .
#   Entity: Taliban, Label: ORG
#
#
# Sentence: The top U.S. diplomat says China should make significant economic reforms so it does not continue to be a " problem for the international economy . "
#   Entity: U.S., Label: GPE
#   Entity: China, Label: GPE
#
#
# Sentence: In a New York Times newspaper interview , published Friday , Secretary of State Condoleezza Rice says Washington also worries about China 's military buildup , human rights practices and religious restrictions .
#   Entity: New York Times, Label: ORG
#   Entity: Friday, Label: DATE
#   Entity: State, Label: ORG
#   Entity: Condoleezza Rice, Label: PERSON
#   Entity: Washington, Label: GPE
#   Entity: China, Label: GPE
#
#
# Sentence: It is a change of tone for Ms. Rice , who generally casts Sino-American relations in a positive light .
#   Entity: Rice, Label: PERSON
#   Entity: Sino-American, Label: NORP
#
#
# Sentence: Her comments come just a month before Chinese President Hu Jintao makes his first visit to Washington since taking office in 2003 .
#   Entity: just a month, Label: DATE
#   Entity: Chinese, Label: NORP
#   Entity: Hu Jintao, Label: PERSON
#   Entity: Washington, Label: GPE
#   Entity: 2003, Label: DATE
#
#
# Sentence: He will arrive amid Washington 's complaints that China manipulates the value of its currency to make its products unfairly cheap on world markets .
#   Entity: Washington, Label: GPE
#   Entity: China, Label: GPE
#
#
# Sentence: Beijing recently changed the value of its currency slightly , but U.S. critics say the change is not large enough to make trade fair .
#   Entity: Beijing, Label: GPE
#   Entity: U.S., Label: GPE
#
#
# Sentence: Chad 's national assembly has authorized President Idriss Deby to renew a state of emergency imposed after a rebel attack on the capital , N'Djamena , early this month .
#   Entity: Chad, Label: GPE
#   Entity: Idriss Deby, Label: PERSON
#   Entity: N'Djamena, Label: GPE
#   Entity: early this month, Label: DATE

# %% [markdown]
# ## PHASE 3

# %%
# Named Entities tagged by the SpaCy model
spacy_output[:300]
# Out:
# [{'sentence': 'EU Commission President Jose Manuel Barroso has said the 25-member bloc will make it clear to the Russian President that the EU is not " satisfied " with Ukraine \'s disputed election .',
#   'entities': [('EU Commission', 'ORG'),
#    ('Jose Manuel Barroso', 'PERSON'),
#    ('Russian', 'NORP'),
#    ('EU', 'ORG'),
#    ('Ukraine', 'GPE')]},
#  {'sentence': "Prime Minister Viktor Yanukovych -- who was backed by Mr. Putin -- has been declared the winner of Sunday 's voting , but the EU is rejecting the results because of allegations of widespread voting fraud .",
#   'entities': [('Viktor Yanukovych', 'PERSON'),
#    ('Putin', 'PERSON'),
#    ('Sunday', 'DATE'),
#    ('EU', 'ORG')]},
#  {'sentence': 'On other issues , EU leaders say they will call on Russia to sign and ratify border agreements with Estonia and Latvia , and urge it to seek a political settlement in war-torn Chechnya .',
#   'entities': [('EU', 'ORG'),
#    ('Russia', 'GPE'),
#    ('Estonia', 'GPE'),
#    ('Latvia', 'GPE'),
#    ('Chechnya', 'GPE')]},
#  {'sentence': 'Palestinian President Mahmoud Abbas has fired three top security officials after militants broke the ceasefire he reached with Israel and fired mortars at Jewish settlements in the Gaza Strip .',
#   'entities': [('Palestinian', 'NORP'),
#    ('Mahmoud Abbas', 'PERSON'),
#    ('Israel', 'GPE'),
#    ('Jewish', 'NORP'),
#    ('the Gaza Strip', 'GPE')]},
#  {'sentence': 'Mr. Abbas dismissed the men , including security chief Abdel Razek Majaidie , hours after Hamas militants fired the mortars .',
#   'entities': [('Abbas', 'PERSON'),
#    ('Abdel Razek Majaidie', 'PERSON'),
#    ('Hamas', 'ORG')]},
#  {'sentence': 'No one was wounded in the shelling , which Hamas said was a response to Israeli gunfire that killed a Palestinian man Wednesday in Gaza .',
#   'entities': [('Hamas', 'ORG'),
#    ('Israeli', 'NORP'),
#    ('Palestinian', 'NORP'),
#    ('Wednesday', 'DATE'),
#    ('Gaza', 'GPE')]},
#  {'sentence': 'Despite the violence , Israeli and Palestinian officials met late Thursday to discuss security issues .',
#   'entities': [('Israeli', 'NORP'),
#    ('Palestinian', 'NORP'),
#    ('late Thursday', 'DATE')]},
#  {'sentence': 'Meanwhile , a deadly shootout was also reported at a Palestinian jail in Gaza City .',
#   'entities': [('Palestinian', 'NORP'), ('Gaza City', 'GPE')]},
#  {'sentence': 'Palestinian sources say at least three people described as Israeli collaborators were killed when dozens of masked gunmen stormed a jailhouse and set free several prisoners .',
#   'entities': [('Palestinian', 'NORP'), ('Israeli', 'NORP')]},
#  {'sentence': 'Germany , France and Lithuania are the latest European countries to congratulate Viktor Yushchenko on his victory in the Ukrainian presidential election .',
#   'entities': [('Germany', 'GPE'),
#    ('France', 'GPE'),
#    ('Lithuania', 'GPE'),
#    ('European', 'NORP'),
#    ('Viktor Yushchenko', 'PERSON'),
#    ('Ukrainian', 'NORP')]},
#  {'sentence': 'In a letter to Mr. Yushchenko Tuesday , German Chancellor Gerhard Schroeder expressed optimism that Ukraine will continue what he called its transition toward the rule of law and a market economy .',
#   'entities': [('Yushchenko', 'PERSON'),
#    ('Tuesday', 'DATE'),
#    ('German', 'NORP'),
#    ('Gerhard Schroeder', 'PERSON'),
#    ('Ukraine', 'GPE')]},
#  {'sentence': 'Lithuanian President Viktor Adamkus congratulated Mr. Yushchenko in a telephone conversation .',
#   'entities': [('Lithuanian', 'NORP'),
#    ('Viktor Adamkus', 'PERSON'),
#    ('Yushchenko', 'PERSON')]},
#  {'sentence': 'In Paris , the foreign ministry said France and its European Union partners are determined to support democracy and modernization in Ukraine .',
#   'entities': [('Paris', 'GPE'),
#    ('France', 'GPE'),
#    ('European Union', 'ORG'),
#    ('Ukraine', 'GPE')]},
#  {'sentence': 'Meanwhile , Russia has questioned the objectivity of monitors for the Organization for Security and Cooperation in Europe .',
#   'entities': [('Russia', 'GPE'),
#    ('the Organization for Security and Cooperation in Europe', 'ORG')]},
#  {'sentence': "That organization characterized last month 's presidential election re-run as flawed , while saying that Sunday 's poll vastly improved upon the last vote .",
#   'entities': [("last month 's", 'DATE'), ('Sunday', 'DATE')]},
#  {'sentence': "Russia backed Mr. Yushchenko 's opponent .",
#   'entities': [('Russia', 'GPE'), ('Yushchenko', 'PERSON')]},
#  {'sentence': 'U.S. weather forecasters say Tropical Storm Ernesto has formed over the Caribbean and is heading toward Jamaica and the Cayman Islands .',
#   'entities': [('U.S.', 'GPE'),
#    ('Caribbean', 'LOC'),
#    ('Jamaica', 'GPE'),
#    ('the Cayman Islands', 'GPE')]},
#  {'sentence': 'The National Hurricane Center thinks the storm could strengthen in coming days and is on track to enter the Gulf of Mexico next week .',
#   'entities': [('The National Hurricane Center', 'ORG'),
#    ('coming days', 'DATE'),
#    ('the Gulf of Mexico', 'LOC'),
#    ('next week', 'DATE')]},
#  {'sentence': 'The center is urging Jamaica and the Cayman Islands to monitor the threats posed by Ernesto , the fifth named storm of the season .',
#   'entities': [('Jamaica', 'GPE'),
#    ('the Cayman Islands', 'GPE'),
#    ('Ernesto', 'PERSON')]},
#  {'sentence': 'Earlier Friday , Tropical Storm Debby weakened over the Atlantic .',
#   'entities': [('Earlier Friday', 'DATE'), ('Atlantic', 'LOC')]},
#  {'sentence': 'The National Hurricane Center in Miami says Debby is about 2,200 kilometers northwest of the Cape Verde Islands , with winds near 65 kilometers per hour .',
#   'entities': [('The National Hurricane Center', 'ORG'),
#    ('Miami', 'GPE'),
#    ('Debby', 'PERSON'),
#    ('the Cape Verde Islands', 'LOC')]},
#  {'sentence': 'It says no significant change in strength is expected over the next day .',
#   'entities': [('the next day', 'DATE')]},
#  {'sentence': "Ethiopian security forces say they have foiled what they describe as a terrorist plot by a group linked to the country 's main opposition party .",
#   'entities': [('Ethiopian', 'NORP')]},
#  {'sentence': 'A statement released through state media says authorities arrested a group that was planning attacks in the capital , Addis Ababa .',
#   'entities': [('Addis Ababa', 'GPE')]},
#  {'sentence': 'The statement says the group planned to target government officials and institutions .',
#   'entities': []},
#  {'sentence': 'Ethiopian authorities say they also seized bombs , explosives and small arms related to the plot .',
#   'entities': [('Ethiopian', 'NORP')]},
#  {'sentence': 'The statement did not say how many people were arrested or explain how the alleged group is linked to the opposition Coalition for Unity and Democracy .',
#   'entities': [('Coalition for Unity and Democracy', 'ORG')]},
#  {'sentence': 'Leaders of the party were not available for comment .',
#   'entities': []},
#  {'sentence': 'Ethiopian Prime Minister Meles Zenawi has repeatedly accused the opposition of conspiring to incite violence and seeking to overthrow him .',
#   'entities': [('Ethiopian', 'NORP'), ('Meles Zenawi', 'PERSON')]},
#  {'sentence': 'The government has charged at least 129 opposition leaders , journalists and others with treason and planning to commit genocide .',
#   'entities': []},
#  {'sentence': 'United Nations Secretary-General Kofi Annan has ordered disciplinary action against senior U.N. officials who worked on the oil-for-food program in Iraq .',
#   'entities': [('United Nations', 'ORG'),
#    ('Kofi Annan', 'PERSON'),
#    ('U.N.', 'ORG'),
#    ('Iraq', 'GPE')]},
#  {'sentence': 'Mr. Annan said in a statement Thursday a report about alleged corruption in the U.N. program has turned up " extremely troubling evidence of wrongdoing , " and he pledged that no one involved would be shielded from prosecution .',
#   'entities': [('Annan', 'PERSON'), ('Thursday', 'DATE'), ('U.N.', 'ORG')]},
#  {'sentence': 'The independent report , released Thursday , concluded that the head of the oil-for-food program , Benon Sevan , seriously undermined the integrity of the United Nations by his conduct .',
#   'entities': [('Thursday', 'DATE'),
#    ('Benon Sevan', 'PERSON'),
#    ('the United Nations', 'ORG')]},
#  {'sentence': 'U.N. disciplinary proceedings have begun against Mr. Sevan and another senior official , Joseph Stephanides .',
#   'entities': [('U.N.', 'ORG'),
#    ('Sevan', 'PERSON'),
#    ('Joseph Stephanides', 'PERSON')]},
#  {'sentence': 'Both Mr. Sevan and Mr. Stephanides are Cypriot nationals .',
#   'entities': [('Sevan', 'PERSON'),
#    ('Stephanides', 'PERSON'),
#    ('Cypriot', 'NORP')]},
#  {'sentence': "Critics say billions of dollars were siphoned away from the oil-for-food program , which was devised after the first Gulf War in an attempt to help Iraq 's impoverished civilian population .",
#   'entities': [('billions of dollars', 'MONEY'), ('Iraq', 'GPE')]},
#  {'sentence': 'Rebels and government forces in Ivory Coast began withdrawing heavy weapons from the front line Thursday , complying with a new peace deal to end tensions in the divided nation .',
#   'entities': [('Ivory Coast', 'GPE'), ('Thursday', 'DATE')]},
#  {'sentence': 'The pullback , expected to last four days , includes all guns larger than 20 millimeters and short-range weaponry equal to or larger than 60 millimeters , including mortars .',
#   'entities': [('last four days', 'DATE')]},
#  {'sentence': 'Anti-tank weapons will remain in place .', 'entities': []},
#  {'sentence': 'One rebel fighter told VOA he was happy to see the repeatedly postponed disarmament process begin , adding that he hopes to become a police officer once the two-year-old conflict is finally over .',
#   'entities': [('VOA', 'ORG'), ('two-year-old', 'DATE')]},
#  {'sentence': 'Several peace deals have failed to take hold in Ivory Coast .',
#   'entities': [('Ivory Coast', 'GPE')]},
#  {'sentence': 'Rebels still hold huge swaths of territory in northern and western Ivory Coast , with the government firmly in control of the south .',
#   'entities': [('Ivory Coast', 'GPE')]},
#  {'sentence': "News reports from Uzbekistan say sporadic gunfire has continued in areas along the Kyrgyz border , following Friday 's military crackdown against protesters in the city of Andijan .",
#   'entities': [('Uzbekistan', 'GPE'),
#    ('Kyrgyz', 'NORP'),
#    ('Friday', 'DATE'),
#    ('Andijan', 'GPE')]},
#  {'sentence': 'The Associated Press quoted residents as saying several soldiers and civilians were killed when clashes erupted Sunday in two border villages , Teshiktosh and Karasu .',
#   'entities': [('The Associated Press', 'ORG'),
#    ('Sunday', 'DATE'),
#    ('Teshiktosh', 'GPE'),
#    ('Karasu', 'PERSON')]},
#  {'sentence': 'Earlier reports said as many as 500 people were killed when security forces fired into a crowd of demonstrators in Andijan on Friday .',
#   'entities': [('Andijan', 'GPE'), ('Friday', 'DATE')]},
#  {'sentence': 'But Uzbek President Islam Karimov said the death toll was much lower .',
#   'entities': [('Uzbek', 'NORP'), ('Islam Karimov', 'PERSON')]},
#  {'sentence': 'He blamed the bloodshed on Islamic radicals trying to overthrow the government .',
#   'entities': [('Islamic', 'NORP')]},
#  {'sentence': 'Several countries , including the United States , have called for restraint .',
#   'entities': [('the United States', 'GPE')]},
#  {'sentence': 'British Foreign Secretary Jack Straw called the Andijan crackdown a clear abuse of human rights .',
#   'entities': [('British', 'NORP'),
#    ('Jack Straw', 'PERSON'),
#    ('Andijan', 'PERSON')]},
#  {'sentence': "Pope John Paul II has included prayers for the victims of the Asian tsunami in his New Year 's Day Mass marking the Roman Catholic Church 's annual World Day of Peace .",
#   'entities': [('John Paul II', 'PERSON'),
#    ('Asian', 'NORP'),
#    ("the Roman Catholic Church 's", 'ORG'),
#    ('annual', 'DATE')]},
#  {'sentence': "Thousands of pilgrims attended the Pope 's outdoor Mass Saturday at the Vatican .",
#   'entities': [('Saturday', 'DATE')]},
#  {'sentence': 'John Paul II also led a Mass for the tsunami victims in his private chapel overnight .',
#   'entities': [('John Paul II', 'PERSON')]},
#  {'sentence': "In his peace message , the pontiff called for greater cooperation among the world 's religions , and for promotion of peace through dialogue , justice and forgiveness .",
#   'entities': []},
#  {'sentence': 'He urged the world \'s one billion Roman Catholics to , " win the fight over evil with the armies of love . "',
#   'entities': [('one billion', 'MONEY'), ('Roman Catholics', 'NORP')]},
#  {'sentence': 'The European Union opened membership talks with Turkey early Tuesday , after settling last-minute objections by Austria .',
#   'entities': [('The European Union', 'ORG'),
#    ('Turkey', 'GPE'),
#    ('early Tuesday', 'DATE'),
#    ('Austria', 'GPE')]},
#  {'sentence': "EU foreign ministers ended 30 hours of heated emergency meetings late Monday in Luxembourg with Austrian officials withdrawing Vienna 's demand that the EU retain the option of offering Turkey a limited partnership .",
#   'entities': [('EU', 'ORG'),
#    ('late Monday', 'DATE'),
#    ('Luxembourg', 'GPE'),
#    ('Austrian', 'NORP'),
#    ('Vienna', 'GPE'),
#    ('EU', 'ORG'),
#    ('Turkey', 'GPE')]},
#  {'sentence': 'Turkey had rejected the option .',
#   'entities': [('Turkey', 'GPE')]},
#  {'sentence': "Austria 's cooperation paved the way for all 25 EU member-states to agree on a negotiating framework for the membership process , which is expected to take about 10 years .",
#   'entities': [('Austria', 'GPE'), ('EU', 'ORG'), ('about 10 years', 'DATE')]},
#  {'sentence': 'A brief ceremony to officially open the talks took place shortly after midnight Tuesday in Luxembourg .',
#   'entities': [('Tuesday', 'DATE'), ('Luxembourg', 'GPE')]},
#  {'sentence': 'Talks had been scheduled to open Monday .',
#   'entities': [('Monday', 'DATE')]},
#  {'sentence': 'If accepted , Turkey would be the first country with a majority Muslim population to join the European Union .',
#   'entities': [('Turkey', 'GPE'),
#    ('Muslim', 'NORP'),
#    ('the European Union', 'ORG')]},
#  {'sentence': 'It has been an associate member of the bloc since 1963 .',
#   'entities': [('1963', 'DATE')]},
#  {'sentence': 'Egyptian President Hosni Mubarak has called for both his supporters and opponents to work with him as he embarks on his fifth presidential term .',
#   'entities': [('Egyptian', 'NORP'), ('Hosni Mubarak', 'PERSON')]},
#  {'sentence': 'He took the oath of office Tuesday before parliament and several foreign dignitaries , including Libyan leader Moammar Gadhafi .',
#   'entities': [('Tuesday', 'DATE'),
#    ('Libyan', 'NORP'),
#    ('Moammar Gadhafi', 'PERSON')]},
#  {'sentence': "In a nationally televised speech , the 77-year-old leader pledged to continue a nascent program of political and economic reforms , and to improve the living standard of Egypt 's majority poor during his term , which runs through 2011 .",
#   'entities': [('77-year-old', 'DATE'), ('Egypt', 'GPE'), ('2011', 'DATE')]},
#  {'sentence': 'He also promised November \'s legislative elections will be " free and fair , " after criticisms that September \'s first multi-candidate presidential race was rife with voting irregularities .',
#   'entities': [('November', 'DATE'), ('September', 'DATE')]},
#  {'sentence': 'Mr. Mubarak beat nine challengers , winning more than 88 percent of the vote .',
#   'entities': [('Mubarak', 'PERSON')]},
#  {'sentence': 'Japan says it wants safety guarantees for its players and fans when its national soccer ( football ) team travels to North Korea for a World Cup qualifying match in June .',
#   'entities': [('Japan', 'GPE'), ('North Korea', 'GPE'), ('June', 'DATE')]},
#  {'sentence': "Japan 's Chief Cabinet Secretary Hiroyuki Hosoda says it is a necessary precondition for any international match that players can play safely and spectators can be protected .",
#   'entities': [('Japan', 'GPE'),
#    ('Cabinet', 'ORG'),
#    ('Hiroyuki Hosoda', 'PERSON')]},
#  {'sentence': 'Japanese concerns were raised by scenes of mob violence at a match in Pyongyang between Iran and North Korea on Wednesday .',
#   'entities': [('Japanese', 'NORP'),
#    ('Pyongyang', 'GPE'),
#    ('Iran', 'GPE'),
#    ('North Korea', 'GPE'),
#    ('Wednesday', 'DATE')]},
#  {'sentence': 'The game was televised and cameras showed the North Korean spectators throwing bottles , cans and seats at players and officials on the field .',
#   'entities': [('North Korean', 'NORP')]},
#  {'sentence': 'Riot police had to clear a path for the victorious Iranian players to reach their team bus .',
#   'entities': [('Iranian', 'NORP')]},
#  {'sentence': 'The violence at the game was a rare occurrence in the tightly controlled North Korean state .',
#   'entities': [('North Korean', 'NORP')]},
#  {'sentence': 'A published report says the United States has been flying drones over Iran for almost a year , looking for evidence of nuclear weapons programs and detect weaknesses in air defenses .',
#   'entities': [('the United States', 'GPE'),
#    ('Iran', 'GPE'),
#    ('almost a year', 'DATE')]},
#  {'sentence': "In Sunday 's editions , The Washington Post quotes three U.S. officials as saying the U.S. military has been launching the unmanned surveillance flights from Iraq .",
#   'entities': [('Sunday', 'DATE'),
#    ('The Washington Post', 'ORG'),
#    ('U.S.', 'GPE'),
#    ('U.S.', 'GPE'),
#    ('Iraq', 'GPE')]},
#  {'sentence': 'There has been no U.S. comment on the report .',
#   'entities': [('U.S.', 'GPE')]},
#  {'sentence': 'An Iranian spokesman Sunday again warned the United States not to attack its nuclear facilities .',
#   'entities': [('Iranian', 'NORP'),
#    ('Sunday', 'DATE'),
#    ('the United States', 'GPE')]},
#  {'sentence': "He also rejected a European proposal aimed at restricting Tehran 's development of nuclear fuel .",
#   'entities': [('European', 'NORP'), ('Tehran', 'GPE')]},
#  {'sentence': 'Iran has said in the past it would stop plans to build a heavy water nuclear reactor , which can be used to make nuclear weapons-grade material as well as for nuclear energy .',
#   'entities': [('Iran', 'GPE')]},
#  {'sentence': 'But Sunday in Tehran , a foreign ministry spokesman said Iran will go forward with the heavy water reactor and will not replace it under any circumstances .',
#   'entities': [('Sunday', 'DATE'), ('Tehran', 'GPE'), ('Iran', 'GPE')]},
#  {'sentence': 'North Korea says its Catholic community has organized religious services in memory of Pope John Paul .',
#   'entities': [('North Korea', 'GPE'),
#    ('Catholic', 'NORP'),
#    ('John Paul', 'PERSON')]},
#  {'sentence': "The official news agency , KCNA , on Tuesday quotes Samuel Jang Jae On , described as head of the country 's Catholic association , as saying North Korean Catholics are deeply saddened by the pontiff 's passing .",
#   'entities': [('KCNA', 'ORG'),
#    ('Tuesday', 'DATE'),
#    ('Samuel Jang Jae', 'PERSON'),
#    ('Catholic', 'NORP'),
#    ('North Korean Catholics', 'NORP')]},
#  {'sentence': 'The agency says Mr. Jang sent the Vatican a message of condolence .',
#   'entities': [('Jang', 'PERSON')]},
#  {'sentence': "North Korea is widely described as one of the world 's most repressive political regimes .",
#   'entities': [('North Korea', 'GPE')]},
#  {'sentence': 'It is not clear how many Catholics live in the Communist nation and to what extent they can practice their religion .',
#   'entities': [('Catholics', 'NORP'), ('Communist', 'NORP')]},
#  {'sentence': 'Thousands of protesters have demonstrated outside a Philippine army camp , where U.S. soldiers and Philippine troops have begun joint military exercises .',
#   'entities': [('Philippine', 'NORP'),
#    ('U.S.', 'GPE'),
#    ('Philippine', 'NORP')]},
#  {'sentence': 'Demonstrators in the town of Carmen on the southern island of Mindanao chanted anti-U.S. slogans Tuesday and demanded that American troops leave the area .',
#   'entities': [('Carmen', 'PERSON'),
#    ('Mindanao', 'LOC'),
#    ('anti-U.S.', 'NORP'),
#    ('Tuesday', 'DATE'),
#    ('American', 'NORP')]},
#  {'sentence': "U.S. soldiers will also take part in the Philippines ' annual war games , to be held next month on Jolo island in the southern Philippines .",
#   'entities': [('U.S.', 'GPE'),
#    ('Philippines', 'GPE'),
#    ('annual', 'DATE'),
#    ('next month', 'DATE'),
#    ('Jolo island', 'LOC'),
#    ('Philippines', 'GPE')]},
#  {'sentence': 'Jolo is where the al-Qaida-linked militant group Abu Sayyaf has carried out bombings , kidnappings and killings of foreigners in recent years .',
#   'entities': [('al-Qaida', 'ORG'),
#    ('Abu Sayyaf', 'PERSON'),
#    ('recent years', 'DATE')]},
#  {'sentence': 'Philippine law prohibits American troops from joining any combat operations with Philippine forces .',
#   'entities': [('Philippine', 'NORP'),
#    ('American', 'NORP'),
#    ('Philippine', 'NORP')]},
#  {'sentence': 'Security for the war games will be tight , to protect the soldiers from attacks by rebels .',
#   'entities': []},
#  {'sentence': "In addition to military training , troops will carry out humanitarian missions to try to boost support among Jolo 's residents .",
#   'entities': [('Jolo', 'ORG')]},
#  {'sentence': 'The U.N. World Food Program is giving emergency assistance to the Cuban government .',
#   'entities': [('The U.N. World Food Program', 'ORG'), ('Cuban', 'NORP')]},
#  {'sentence': 'The WFP announced Tuesday that it will help feed about two million people at a cost of nearly $ 6 million .',
#   'entities': [('WFP', 'ORG'),
#    ('Tuesday', 'DATE'),
#    ('nearly $ 6 million', 'MONEY')]},
#  {'sentence': "The aid package is intended to help Cuba recover from last month 's devastation from Hurricanes Gustav and Ike .",
#   'entities': [('Cuba', 'GPE'), ("last month 's", 'DATE'), ('Ike', 'PERSON')]},
#  {'sentence': 'During the next six months , WFP will provide food rations , including rice , beans , vegetable oil , canned fish and more .',
#   'entities': [('the next six months', 'DATE'), ('WFP', 'ORG')]},
#  {'sentence': 'The WFP will also supply temporary food storage warehouses and liquid gas stoves to people who lost their cooking facilities in the storms .',
#   'entities': [('WFP', 'ORG')]},
#  {'sentence': "Sweden 's Nobel Foundation begins announcing winners of the annual Nobel Prize awards on Monday in Oslo , Norway .",
#   'entities': [('Sweden', 'GPE'),
#    ('Nobel Foundation', 'ORG'),
#    ('annual', 'DATE'),
#    ('Monday', 'DATE'),
#    ('Oslo', 'GPE'),
#    ('Norway', 'GPE')]},
#  {'sentence': 'Prizes for medicine , physics , chemistry and literature will be announced before the prestigious Peace Prize is revealed Friday .',
#   'entities': [('Friday', 'DATE')]},
#  {'sentence': 'A separate prize for economics will be announced October 10 .',
#   'entities': [('October 10', 'DATE')]},
#  {'sentence': 'It was instituted in 1968 by the Bank of Sweden in memory of the founder of the Nobel Prize , Swedish philanthropist Alfred Nobel .',
#   'entities': [('1968', 'DATE'),
#    ('the Bank of Sweden', 'ORG'),
#    ('Swedish', 'NORP'),
#    ('Alfred Nobel', 'PERSON')]},
#  {'sentence': 'Winners receive their awards , including a check worth $ 1.3 million , at a banquet on December 10 .',
#   'entities': [('$ 1.3 million', 'MONEY'), ('December 10', 'DATE')]},
#  {'sentence': "That is the anniversary of Mr. Nobel 's death in 1896 .",
#   'entities': [('Nobel', 'PERSON'), ('1896', 'DATE')]},
#  {'sentence': 'According to his will , a five-member committee elected by the Norwegian parliament chooses the Peace Prize laureate , while Swedish scientific and literary groups choose the other winners .',
#   'entities': [('Norwegian', 'NORP'), ('Swedish', 'NORP')]},
#  {'sentence': 'The first Nobel Prizes were given in 1901 .',
#   'entities': [('1901', 'DATE')]},
#  {'sentence': 'Insurgents in Iraq fired a barrage of mortar rounds into central Baghdad',
#   'entities': [('Iraq', 'GPE'), ('Baghdad', 'GPE')]},
#  {'sentence': 'Thursday , killing at least one person and wounding several others .',
#   'entities': [('Thursday', 'DATE')]},
#  {'sentence': 'Police say some of the mortars landed in the Green Zone -- the heavily fortified enclave that houses Iraqi government offices and several foreign embassies .',
#   'entities': [('the Green Zone', 'LOC'), ('Iraqi', 'NORP')]},
#  {'sentence': 'Last week , a mortar attack on the Green Zone killed four employees of a British security company .',
#   'entities': [('Last week', 'DATE'),
#    ('the Green Zone', 'LOC'),
#    ('British', 'NORP')]},
#  {'sentence': "Meanwhile , the U.S. military is planning to temporarily increase the number of American troops in Iraq to bolster security ahead of Iraq 's January election .",
#   'entities': [('U.S.', 'GPE'),
#    ('American', 'NORP'),
#    ('Iraq', 'GPE'),
#    ('Iraq', 'GPE'),
#    ('January', 'DATE')]},
#  {'sentence': 'The Defense Department said Wednesday the size of U.S. forces in Iraq will increase to 1,50,000 from its current level of 1,38,000 .',
#   'entities': [('The Defense Department', 'ORG'),
#    ('Wednesday', 'DATE'),
#    ('U.S.', 'GPE'),
#    ('Iraq', 'GPE')]},
#  {'sentence': "Iraq 's interim government has rejected calls from some Sunni parties to postpone the vote because of security concerns .",
#   'entities': [('Iraq', 'GPE'), ('Sunni', 'NORP')]},
#  {'sentence': 'Brazilian lawmakers have approved legislation that will give the government more control over developing offshore oil fields .',
#   'entities': [('Brazilian', 'NORP')]},
#  {'sentence': 'The lower house of the Brazilian congress passed the bill Wednesday , sending it to outgoing President Luiz Inacio Lula da Silva for his signature .',
#   'entities': [('Brazilian', 'NORP'),
#    ('Wednesday', 'DATE'),
#    ('Luiz Inacio Lula da Silva', 'PERSON')]},
#  {'sentence': 'The measure allows the state-owned oil company , known as Petrobras , to be the sole operator of unexplored offshore oil fields , as well as a 30 percent stake in any joint ventures .',
#   'entities': [('Petrobras', 'ORG')]},
#  {'sentence': "Brazil has discovered potentially large oil reserves off the country 's southeastern coast , some of them thousands of meters below the sea floor .",
#   'entities': [('Brazil', 'GPE')]},
#  {'sentence': 'Some estimates say the fields may contain more than 50 billion barrels of oil .',
#   'entities': [('more than 50 billion barrels', 'MONEY')]},
#  {'sentence': 'Brazilian lawmakers also approved a provision that will allow non-oil producing states to receive more oil revenues .',
#   'entities': [('Brazilian', 'NORP')]},
#  {'sentence': 'A new U.S. opinion survey shows eight out of 10 Americans believe the country is going in the wrong direction .',
#   'entities': [('U.S.', 'GPE'), ('Americans', 'NORP')]},
#  {'sentence': "The Washington Post-ABC News poll also indicates Democrats hold a 21 percentage point advantage over Republicans as the party better equipped to handle the country 's problems .",
#   'entities': [('The Washington Post-ABC News', 'ORG'),
#    ('Democrats', 'NORP'),
#    ('Republicans', 'NORP')]},
#  {'sentence': 'In a hypothetical general election match-up , Democratic Party candidate Senator Barack Obama leads presumed Republican nominee John McCain by 51-to-44 percent .',
#   'entities': [('Democratic Party', 'ORG'),
#    ('Barack Obama', 'PERSON'),
#    ('Republican', 'NORP'),
#    ('John McCain', 'PERSON')]},
#  {'sentence': "As the Democratic Party nears the end of its presidential primaries , the national poll shows Obama has a 12-point advantage over Senator Hillary Clinton as the party 's choice for its nomination .",
#   'entities': [('the Democratic Party', 'ORG'),
#    ('Obama', 'PERSON'),
#    ('Hillary Clinton', 'PERSON')]},
#  {'sentence': 'The poll says Americans cite the economy and employment as their top voting issue , followed by the Iraq war , healthcare and fuel prices .',
#   'entities': [('Americans', 'NORP')]},
#  {'sentence': 'The poll of more than 1,100 adults , conducted from May 8 - 11 , has a margin of error of plus or minus three percentage points .',
#   'entities': [('May 8 - 11', 'DATE')]},
#  {'sentence': 'Cuban President Raul Castro is visiting Venezuela on his first international trip as leader of the communist nation .',
#   'entities': [('Cuban', 'NORP'),
#    ('Raul Castro', 'PERSON'),
#    ('Venezuela', 'GPE'),
#    ('communist', 'NORP')]},
#  {'sentence': "Venezuela 's socialist president , Hugo Chavez , welcomed Mr. Castro Saturday at the Caracas airport .",
#   'entities': [('Venezuela', 'GPE'),
#    ('Hugo Chavez', 'PERSON'),
#    ('Castro', 'PERSON'),
#    ('Saturday', 'DATE')]},
#  {'sentence': "This is President Castro 's first official foreign trip since February , when the 77-year-old took charge from his ailing older brother , Fidel Castro .",
#   'entities': [('Castro', 'PERSON'),
#    ('February', 'DATE'),
#    ('77-year-old', 'DATE'),
#    ('Fidel Castro', 'PERSON')]},
#  {'sentence': 'The two leaders will visit the tomb of South American independence icon Simon Bolivar today and later hold talks on a variety of issues .',
#   'entities': [('South American', 'NORP'),
#    ('Simon Bolivar', 'PERSON'),
#    ('today', 'DATE')]},
#  {'sentence': 'Venezuela and Cuba have increased cooperation on energy and oil production .',
#   'entities': [('Venezuela', 'GPE'), ('Cuba', 'GPE')]},
#  {'sentence': 'Venezuela is a critical trade partner for the Caribbean island nation , which imports nearly 1,00,000 barrels of oil per day from Venezuela .',
#   'entities': [('Venezuela', 'GPE'),
#    ('Caribbean', 'LOC'),
#    ('Venezuela', 'GPE')]},
#  {'sentence': "Today 's visit comes ahead of a summit in Brazil next week , where Latin American and Caribbean leaders will gather for talks .",
#   'entities': [('Today', 'DATE'),
#    ('Brazil', 'GPE'),
#    ('next week', 'DATE'),
#    ('Latin American', 'NORP'),
#    ('Caribbean', 'NORP')]},
#  {'sentence': 'The nuclear cooperation pact between India and the United States has sparked a mixed reaction in Washington and abroad .',
#   'entities': [('India', 'GPE'),
#    ('the United States', 'GPE'),
#    ('Washington', 'GPE')]},
#  {'sentence': 'International Atomic Energy Agency Director General Mohamed ElBaradei praised the agreement , saying it would bring India closer as an important partner in the non-proliferation group of countries .',
#   'entities': [('International Atomic Energy Agency', 'ORG'),
#    ('Mohamed ElBaradei', 'PERSON'),
#    ('India', 'GPE')]},
#  {'sentence': 'But some U.S. lawmakers criticized the deal , saying the agreement that could give India access to U.S. civilian nuclear technology would undermine the Nuclear Non-Proliferation Treaty .',
#   'entities': [('U.S.', 'GPE'), ('India', 'GPE'), ('U.S.', 'GPE')]},
#  {'sentence': 'India has not signed the treaty , which restricts the sharing of some nuclear technology with non-member nations , and drew widespread international criticism for conducting nuclear weapons tests as recently as 1998 .',
#   'entities': [('India', 'GPE'), ('1998', 'DATE')]},
#  {'sentence': 'Full details of the nuclear cooperation pact have not been released , but the agreement must still be approved by Congress before taking effect .',
#   'entities': [('Congress', 'ORG')]},
#  {'sentence': 'President Bush acknowledged Thursday that hard work still needs to be done to gain the necessary approval in Congress .',
#   'entities': [('Bush', 'PERSON'), ('Thursday', 'DATE'), ('Congress', 'ORG')]},
#  {'sentence': 'A Sudanese analyst says the late rebel leader John Garang was a symbol of the struggle for greater federalism in the country .',
#   'entities': [('Sudanese', 'NORP'), ('John Garang', 'PERSON')]},
#  {'sentence': 'Lecturer John Gai Yoh of the University of South Africa ( UNISA ) in Pretoria credits the leader of the Sudanese Liberation Movement with creating a campaign that included allies beyond his base in the south .',
#   'entities': [('John Gai Yoh', 'PERSON'),
#    ('the University of South Africa', 'ORG'),
#    ('UNISA', 'ORG'),
#    ('Pretoria', 'GPE'),
#    ('the Sudanese Liberation Movement', 'ORG')]},
#  {'sentence': 'Mr. Yoh notes that his vision materialized with the comprehensive peace agreement signed last January between the former SPLA rebels and the government in Khartoum .',
#   'entities': [('Yoh', 'PERSON'),
#    ('last January', 'DATE'),
#    ('SPLA', 'ORG'),
#    ('Khartoum', 'GPE')]},
#  {'sentence': 'Analyst John Gai Yoh predicts that the SPLA will continue to democratize : it has created a new SPLA parliament for the south and has named a new five-man military panel to lead the movement .',
#   'entities': [('John Gai Yoh', 'PERSON'), ('SPLA', 'ORG'), ('SPLA', 'ORG')]},
#  {'sentence': "The United Nations has given its annual Franklin Delano Roosevelt International Disability Award to Poland , recognizing the country 's efforts to integrate the disabled into Polish society .",
#   'entities': [('The United Nations', 'ORG'),
#    ('Franklin Delano Roosevelt International Disability Award', 'ORG'),
#    ('Poland', 'GPE'),
#    ('Polish', 'NORP')]},
#  {'sentence': 'President Lech Kaczynski accepted the award at a ceremony Monday at U.N. headquarters in New York .',
#   'entities': [('Lech Kaczynski', 'PERSON'),
#    ('Monday', 'DATE'),
#    ('U.N.', 'ORG'),
#    ('New York', 'GPE')]},
#  {'sentence': "He said his country 's struggle for freedom includes a commitment to the rights of those with disabilities .",
#   'entities': []},
#  {'sentence': 'He said their rights are guaranteed by the Polish constitution .',
#   'entities': [('Polish', 'NORP')]},
#  {'sentence': 'Mr. Kaczynski promised that Poland will adopt a new U.N. convention to protect the disabled .',
#   'entities': [('Kaczynski', 'PERSON'), ('Poland', 'GPE'), ('U.N.', 'ORG')]},
#  {'sentence': 'The award is named for U.S. President Franklin Roosevelt , whose legs were paralyzed from polio .',
#   'entities': [('U.S.', 'GPE'), ('Franklin Roosevelt', 'PERSON')]},
#  {'sentence': 'Mr. Roosevelt was president from 1933 until 1945 .',
#   'entities': [('Roosevelt', 'PERSON'), ('1933', 'DATE'), ('1945', 'DATE')]},
#  {'sentence': 'An Ethiopian government spokesman denies that a reported rebel attack said to have killed 140 soldiers ever took place .',
#   'entities': [('Ethiopian', 'NORP')]},
#  {'sentence': 'The spokesman , Zemedkun Tekle , issued the denial Sunday after media reports said the Ogaden National Liberation Front had claimed to have carried out the deadly attack Saturday in southeastern Ethiopia near Wardheer .',
#   'entities': [('Zemedkun Tekle', 'PERSON'),
#    ('Sunday', 'DATE'),
#    ('the Ogaden National Liberation Front', 'ORG'),
#    ('Saturday', 'DATE'),
#    ('Ethiopia', 'GPE'),
#    ('Wardheer', 'ORG')]},
#  {'sentence': 'A purported statement from the group received by some news organizations said about a thousand rebels took part in the attack and seized ammunition along with military hardware .',
#   'entities': []},
#  {'sentence': 'The government spokesman says there was no attack , and that the rebel group is not in a position to carry out such an attack .',
#   'entities': []},
#  {'sentence': 'Rebels have been fighting for more autonomy for ethnic Somalis in the eastern region of Ogaden bordering Somalia .',
#   'entities': [('Somalis', 'NORP'), ('Ogaden', 'GPE'), ('Somalia', 'GPE')]},
#  {'sentence': 'Kuwaiti television reports the kidnappers in Iraq of American journalist Jill Carroll are threatening to kill her if their demands are not met by February 26 .',
#   'entities': [('Kuwaiti', 'NORP'),
#    ('Iraq', 'GPE'),
#    ('American', 'NORP'),
#    ('Jill Carroll', 'PERSON'),
#    ('February 26', 'DATE')]},
#  {'sentence': 'Al-Rai television Friday quoted sources close to the kidnappers as saying the abductors have set the deadline .',
#   'entities': [('Al-Rai', 'PERSON'), ('Friday', 'DATE')]},
#  {'sentence': 'The militants holding Carroll previously had demanded that all Iraqi women prisoners be freed .',
#   'entities': [('Carroll', 'ORG'), ('Iraqi', 'NORP')]},
#  {'sentence': 'Earlier Friday , at least eight people died and more than 20 were wounded in a Baghdad car bombing near a Sunni Muslim mosque .',
#   'entities': [('Earlier Friday', 'DATE'),
#    ('Baghdad', 'GPE'),
#    ('Sunni Muslim', 'NORP')]},
#  {'sentence': "Officials in Iraq also certified results of the December 15 elections , confirming the near majority of parliament seats won by Shi'ite religious parties .",
#   'entities': [('Iraq', 'GPE'), ('December 15', 'DATE'), ("Shi'ite", 'NORP')]},
#  {'sentence': "According to the results , the dominant Shi'ite coalition , the United Iraqi Alliance , won 128 seats in the 275-member parliament .",
#   'entities': [("Shi'ite", 'NORP'), ('the United Iraqi Alliance', 'ORG')]},
#  {'sentence': 'Palestinian security officials say masked Palestinian police briefly stormed a government building in the Gaza Strip in anger over not receiving their salaries from the Hamas-led government .',
#   'entities': [('Palestinian', 'NORP'),
#    ('Palestinian', 'NORP'),
#    ('the Gaza Strip', 'GPE'),
#    ('Hamas', 'ORG')]},
#  {'sentence': 'Security officials say about 50 police officers sealed off the main road Saturday in the central Gaza town of Khan Younis .',
#   'entities': [('Saturday', 'DATE'),
#    ('Gaza', 'GPE'),
#    ('Khan Younis', 'PERSON')]},
#  {'sentence': 'They say the masked police surrounded a municipal government building , taking positions on the roof and firing in the air .',
#   'entities': []},
#  {'sentence': 'The protest is seen as a sign of discontent with the new Hamas-led government , which took office late last month .',
#   'entities': [('Hamas', 'ORG'), ('late last month', 'DATE')]},
#  {'sentence': 'The cash-strapped Palestinian Authority has not been able to pay salaries to some 1,40,000 government employees since March .',
#   'entities': [('Palestinian Authority', 'ORG'), ('March', 'DATE')]},
#  {'sentence': 'Western nations have cut off aid to the Palestinian government , demanding that Hamas renounce violence and recognize Israel .',
#   'entities': [('Western', 'NORP'),
#    ('Palestinian', 'NORP'),
#    ('Hamas', 'ORG'),
#    ('Israel', 'GPE')]},
#  {'sentence': 'The White House said President Bush has approved duty-free treatment for imports of certain types of watches that are n\'t produced in " significant quantities " in the U.S. , the Virgin Islands and other U.S. possessions .',
#   'entities': [('The White House', 'ORG'),
#    ('Bush', 'PERSON'),
#    ('U.S.', 'GPE'),
#    ('the Virgin Islands', 'GPE'),
#    ('U.S.', 'GPE')]},
#  {'sentence': 'The action came in response to a petition filed by Timex Inc. for changes in the U.S. Generalized System of Preferences for imports from developing nations .',
#   'entities': [('Timex Inc.', 'ORG'),
#    ('the U.S. Generalized System of Preferences', 'ORG')]},
#  {'sentence': 'Previously , watch imports were denied such duty-free treatment .',
#   'entities': []},
#  {'sentence': 'Timex had requested duty-free treatment for many types of watches , covered by 58 different U.S. tariff classifications .',
#   'entities': [('Timex', 'ORG'), ('U.S.', 'GPE')]},
#  {'sentence': 'The White House said Mr. Bush decided to grant duty-free status for 18 categories , but turned down such treatment for other types of watches " because of the potential for material injury to watch producers located in the U.S. and the Virgin Islands . "',
#   'entities': [('The White House', 'ORG'),
#    ('Bush', 'PERSON'),
#    ('U.S.', 'GPE'),
#    ('the Virgin Islands', 'GPE')]},
#  {'sentence': 'Timex is a major U.S. producer and seller of watches , including low-priced battery-operated watches assembled in the Philippines and other developing nations covered by the U.S. tariff preferences .',
#   'entities': [('Timex', 'ORG'),
#    ('U.S.', 'GPE'),
#    ('Philippines', 'GPE'),
#    ('U.S.', 'GPE')]},
#  {'sentence': "U.S. trade officials said the Philippines and Thailand would be the main beneficiaries of the president 's action .",
#   'entities': [('U.S.', 'GPE'), ('Philippines', 'GPE'), ('Thailand', 'GPE')]},
#  {'sentence': 'Imports of the types of watches that now will be eligible for duty-free treatment totaled about $ 37.3 million in 1988 , a relatively small share of the $ 1.5 billion in U.S. watch imports that year , according to an aide to U.S. Trade Representative Carla Hills .',
#   'entities': [('about $ 37.3 million', 'MONEY'),
#    ('1988', 'DATE'),
#    ('$ 1.5 billion', 'MONEY'),
#    ('U.S.', 'GPE'),
#    ('that year', 'DATE'),
#    ('U.S.', 'GPE'),
#    ('Carla Hills', 'PERSON')]},
#  {'sentence': 'Although known to Arab and Malay sailors as early as the 10th century , Mauritius was first explored by the Portuguese in the 16th century and subsequently settled by the Dutch - who named it in honor of Prince Maurits van NASSAU - in the 17th century .',
#   'entities': [('Arab', 'NORP'),
#    ('Malay', 'NORP'),
#    ('the 10th century', 'DATE'),
#    ('Mauritius', 'GPE'),
#    ('Portuguese', 'NORP'),
#    ('the 16th century', 'DATE'),
#    ('Dutch', 'NORP'),
#    ('Prince Maurits van NASSAU', 'ORG'),
#    ('the 17th century', 'DATE')]},
#  {'sentence': 'The French assumed control in 1715 , developing the island into an important naval base overseeing Indian Ocean trade , and establishing a plantation economy of sugar cane .',
#   'entities': [('French', 'NORP'), ('Indian Ocean', 'LOC')]},
#  {'sentence': 'The British captured the island in 1810 , during the Napoleonic Wars .',
#   'entities': [('British', 'NORP'), ('1810', 'DATE')]},
#  {'sentence': 'Mauritius remained a strategically important British naval base , and later an air station , playing an important role during World War II for anti-submarine and convoy operations , as well as the collection of signals intelligence .',
#   'entities': [('Mauritius', 'GPE'), ('British', 'NORP')]},
#  {'sentence': 'Independence from the UK was attained in 1968 .',
#   'entities': [('Independence', 'GPE'), ('UK', 'GPE'), ('1968', 'DATE')]},
#  {'sentence': "A stable democracy with regular free elections and a positive human rights record , the country has attracted considerable foreign investment and has earned one of Africa 's highest per capita incomes .",
#   'entities': [('Africa', 'LOC')]},
#  {'sentence': 'Recent poor weather , declining sugar prices , and declining textile and apparel production , have slowed economic growth , leading to some protests over standards of living in the Creole community .',
#   'entities': [('Creole', 'NORP')]},
#  {'sentence': "Morocco 's market economy benefits from the country 's relatively low labor costs and proximity to Europe , which aid key areas of the economy such as agriculture , light manufacturing , tourism , and remittances .",
#   'entities': [('Morocco', 'GPE'), ('Europe', 'LOC')]},
#  {'sentence': "Morocco is also the world 's largest exporter of phosphate , which has long provided a source of export earnings and economic stability .",
#   'entities': [('Morocco', 'GPE')]},
#  {'sentence': 'Economic policies pursued since 2003 by King MOHAMMED VI have brought macroeconomic stability to the country with generally low inflation , improved financial performance , and steady progress in developing the service and industrial sectors .',
#   'entities': [('2003', 'DATE'), ('King MOHAMMED VI', 'ORG')]},
#  {'sentence': 'In 2006 , Morocco entered a Free Trade Agreement ( FTA ) with the US , and in 2008 entered into an advanced status in its 2000 Association Agreement with the EU .',
#   'entities': [('2006', 'DATE'),
#    ('Morocco', 'GPE'),
#    ('US', 'GPE'),
#    ('2008', 'DATE'),
#    ('2000', 'DATE'),
#    ('EU', 'ORG')]},
#  {'sentence': 'However , poverty , illiteracy , and unemployment rates remain high .',
#   'entities': []},
#  {'sentence': 'In response to these challenges , King MOHAMMED in 2005 launched a National Initiative for Human Development , a $ 2 billion program aimed at alleviating poverty and underdevelopment by expanding electricity to rural areas and replacing urban slums with public and subsidized housing , among other policies .',
#   'entities': [('King MOHAMMED', 'PERSON'),
#    ('2005', 'DATE'),
#    ('National Initiative for Human Development', 'ORG'),
#    ('$ 2 billion', 'MONEY')]},
#  {'sentence': "Morocco 's trade and budget deficits widened in 2010 , and reducing government spending and adapting to sluggish economic growth in Europe will be challenges in 2011 .",
#   'entities': [('Morocco', 'GPE'),
#    ('2010', 'DATE'),
#    ('Europe', 'LOC'),
#    ('2011', 'DATE')]},
#  {'sentence': "Morocco 's long-term challenges include improving education and job prospects for young Moroccans , closing the disparity in wealth between the rich and the poor , confronting corruption , and expanding and diversifying exports beyond phosphates and low-value-added products .",
#   'entities': [('Morocco', 'GPE'), ('Moroccans', 'NORP')]},
#  {'sentence': 'Albania , a formerly closed , centrally-planned state , is making the difficult transition to a more modern open-market economy .',
#   'entities': [('Albania', 'GPE')]},
#  {'sentence': 'Macroeconomic growth averaged around 6 % between 2004 - 8 , but declined to about 3 % in 2009 - 10 .',
#   'entities': [('between 2004 - 8', 'DATE'), ('2009 - 10', 'DATE')]},
#  {'sentence': 'Inflation is low and stable .', 'entities': []},
#  {'sentence': 'The government has taken measures to curb violent crime , and recently adopted a fiscal reform package aimed at reducing the large gray economy and attracting foreign investment .',
#   'entities': []},
#  {'sentence': 'Remittances , a significant catalyst for economic growth have declined from Dec-15 % of GDP to 9 % of GDP in 2009 , mostly from Albanians residing in Greece and Italy ; this helps offset the towering trade deficit .',
#   'entities': [('2009', 'DATE'),
#    ('Albanians', 'NORP'),
#    ('Greece', 'GPE'),
#    ('Italy', 'GPE')]},
#  {'sentence': 'The agricultural sector , which accounts for almost half of employment but only about one-fifth of GDP , is limited primarily to small family operations and subsistence farming because of lack of modern equipment , unclear property rights , and the prevalence of small , inefficient plots of land .',
#   'entities': []},
#  {'sentence': "Energy shortages because of a reliance on hydropower , and antiquated and inadequate infrastructure contribute to Albania 's poor business environment and lack of success in attracting new foreign investment needed to expand the country 's export base .",
#   'entities': [('Albania', 'GPE')]},
#  {'sentence': 'FDI is among the lowest in the region , but the government has embarked on an ambitious program to improve the business climate through fiscal and legislative reforms .',
#   'entities': []},
#  {'sentence': 'The completion of a new thermal power plant near Vlore has helped diversify generation capacity , and plans to upgrade transmission lines between Albania and Montenegro and Kosovo would help relieve the energy shortages .',
#   'entities': [('Vlore', 'GPE'),
#    ('Albania', 'GPE'),
#    ('Montenegro', 'GPE'),
#    ('Kosovo', 'GPE')]},
#  {'sentence': 'Also , with help from EU funds , the government is taking steps to improve the poor national road and rail network , a long-standing barrier to sustained economic growth .',
#   'entities': [('EU', 'ORG')]},
#  {'sentence': 'Economic activity consists primarily of subsistence farming and fishing .',
#   'entities': []},
#  {'sentence': 'The islands have few mineral deposits worth exploiting , except for high-grade phosphate .',
#   'entities': []},
#  {'sentence': 'The potential for a tourist industry exists , but the remote location , a lack of adequate facilities , and limited air connections hinder development .',
#   'entities': []},
#  {'sentence': 'Under the original terms of the Compact of Free Association , the US provided $ 1.3 billion in grant aid during the period 1986 - 2001 ; the level of aid has been subsequently reduced .',
#   'entities': [('the Compact of Free Association', 'ORG'),
#    ('US', 'GPE'),
#    ('$ 1.3 billion', 'MONEY'),
#    ('1986 - 2001', 'DATE')]},
#  {'sentence': 'The Amended Compact of Free Association with the US guarantees the Federated States of Micronesia ( FSM ) millions of dollars in annual aid through 2023 , and establishes a Trust Fund into which the US and the FSM make annual contributions in order to provide annual payouts to the FSM in perpetuity after 2023 .',
#   'entities': [('The Amended Compact of Free Association', 'ORG'),
#    ('US', 'GPE'),
#    ('the Federated States of Micronesia', 'GPE'),
#    ('FSM', 'ORG'),
#    ('millions of dollars', 'MONEY'),
#    ('annual', 'DATE'),
#    ('2023', 'DATE'),
#    ('Trust Fund', 'ORG'),
#    ('US', 'GPE'),
#    ('FSM', 'ORG'),
#    ('annual', 'DATE'),
#    ('annual', 'DATE'),
#    ('FSM', 'ORG'),
#    ('2023', 'DATE')]},
# ...
#   'entities': [('2018', 'DATE'), ('Siberia', 'LOC')]},
#  {'sentence': 'Under the pact , Russia will build the capsule , while European engineers build the service module and the engine block .',
#   'entities': [('Russia', 'GPE'), ('European', 'NORP')]},
#  {'sentence': "The new craft is to be phased in as the replacement for Russia 's Soyuz spacecraft , which has come under increased scrutiny this year , after two consecutive rough landings on return from the International Space Station .",
#   'entities': [('Russia', 'GPE'), ('this year', 'DATE')]},
#  {'sentence': 'A human-rights group in Niger says the government is to blame for cancellation of a ceremony that was to grant 7,000 slaves their freedom .',
#   'entities': [('Niger', 'GPE')]},
#  {'sentence': "The group Timidria had planned to release the slaves in the Ates region near Niger 's western border with Mali on Saturday , but the event was called off when none of the slaves showed up .",
#   'entities': [('Timidria', 'PERSON'),
#    ('Ates', 'GPE'),
#    ('Niger', 'GPE'),
#    ('Mali', 'GPE'),
#    ('Saturday', 'DATE')]},
#  {'sentence': 'The rights group says the government intimidated slaves to keep them from attending the ceremony - a charge the government denies .',
#   'entities': []},
#  {'sentence': 'Niger officially banned slavery in 2003 , but human-rights groups say 43,000 people are still in bondage in the West African nation .',
#   'entities': [('Niger', 'GPE'), ('2003', 'DATE'), ('West African', 'NORP')]},
#  {'sentence': 'They are among the 2,00,000 people enslaved along centuries-old Arab-African Saharan trade routes .',
#   'entities': [('centuries-old', 'DATE'), ('Arab-African', 'NORP')]},
#  {'sentence': 'Generations of Africans have been born in slavery , many under the ownership of one family .',
#   'entities': [('Africans', 'NORP')]},
#  {'sentence': 'Embattled Ivory Coast President Laurent Gbagbo has said he wants to talk with his rival , Alassane Ouattara .',
#   'entities': [('Ivory Coast', 'GPE'),
#    ('Laurent Gbagbo', 'PERSON'),
#    ('Alassane Ouattara', 'PERSON')]},
#  {'sentence': "Mr. Gbagbo has been isolated by the international community , including the United States , after refusing to yield the presidency although he had fewer votes than Mr. Ouattara in last month 's poll .",
#   'entities': [('Gbagbo', 'PERSON'),
#    ('the United States', 'GPE'),
#    ('Ouattara', 'PERSON'),
#    ("last month 's", 'DATE')]},
#  {'sentence': 'Both men have taken the oath of office and begun organizing competing governments .',
#   'entities': []},
#  {'sentence': 'Earlier this week , the African Union dispatched former South African president Thabo Mbeki to seek a solution , but after two days of talks , the situation was not resolved .',
#   'entities': [('Earlier this week', 'DATE'),
#    ('the African Union', 'ORG'),
#    ('South African', 'NORP'),
#    ('Thabo Mbeki', 'PERSON'),
#    ('two days', 'DATE')]},
#  {'sentence': "The Ivory Coast 's presidential election , its first in 10 years , was meant to restore stability to the West African country , which was split into rebel- and government-controlled areas during a 2002 civil war .",
#   'entities': [("The Ivory Coast 's", 'GPE'),
#    ('10 years', 'DATE'),
#    ('West African', 'NORP'),
#    ('2002', 'DATE')]},
#  {'sentence': 'Officials in Afghanistan say a suicide bomber has killed four Afghan employees of a U.S.-owned private security firm and wounded one other in southern Kandahar province .',
#   'entities': [('Afghanistan', 'GPE'),
#    ('Afghan', 'NORP'),
#    ('U.S.-owned', 'NORP'),
#    ('Kandahar', 'GPE')]},
#  {'sentence': 'Authorities said Sunday the bomber rode a motorbike next to a vehicle owned by the company , U.S. Protection and Investigations , and detonated his explosives .',
#   'entities': [('Sunday', 'DATE'),
#    ('U.S. Protection and Investigations', 'ORG')]},
#  {'sentence': "Three guards and the vehicle 's driver were killed , and another guard was wounded .",
#   'entities': []},
#  {'sentence': "On Saturday , a suicide bomber killed seven police officers and a civilian in eastern Afghanistan 's Khost province , near the Pakistan border .",
#   'entities': [('Saturday', 'DATE'),
#    ('Afghanistan', 'GPE'),
#    ('Khost', 'GPE'),
#    ('Pakistan', 'GPE')]},
#  {'sentence': 'The Taleban is reported to have taken responsibility for the blast .',
#   'entities': []},
#  {'sentence': 'NATO forces in Afghanistan are preparing for another upsurge in violence this year , having already launched an operation in the south to preempt an anticipated offensive by Taleban fighters .',
#   'entities': [('NATO', 'ORG'),
#    ('Afghanistan', 'GPE'),
#    ('this year', 'DATE')]},
#  {'sentence': "Turkish police have detained more than 80 people and used tear gas to prevent thousands of leftist protesters from marching to Istanbul 's Taksim square to hold a May Day rally .",
#   'entities': [('Turkish', 'NORP'), ('Istanbul', 'GPE'), ('May Day', 'DATE')]},
#  {'sentence': 'Authorities declared the square off-limits to protesters , but allowed a small number of trade union leaders to lay flowers at the square to mark the day .',
#   'entities': [('the day', 'DATE')]},
#  {'sentence': 'Officials had shut down schools in the area for the day for fear of violence .',
#   'entities': [('the day', 'DATE')]},
#  {'sentence': 'Members of leftist groups often clash with police during May Day observances in Turkey .',
#   'entities': [('May Day', 'DATE'), ('Turkey', 'GPE')]},
#  {'sentence': 'In 1977 , a May Day rally at Taksim square turned violent when unidentified gunmen opened fire on a crowd of demonstrators .',
#   'entities': [('1977', 'DATE'), ('May Day', 'DATE')]},
#  {'sentence': 'Thirty-seven people were killed in that incident .',
#   'entities': []},
#  {'sentence': "The race for Iraq 's new prime minister narrowed Tuesday , when one of two top Shi'ite parties withdrew its candidate from consideration .",
#   'entities': [('Iraq', 'GPE'), ('Tuesday', 'DATE'), ("Shi'ite", 'NORP')]},
#  {'sentence': 'Interim Finance Minister Adel Abdul-Mahdi , who had been the candidate of the Supreme Council for the Islamic Revolution in Iraq , withdrew his name from contention .',
#   'entities': [('Adel Abdul-Mahdi', 'PERSON'),
#    ('the Supreme Council for the Islamic Revolution in Iraq', 'ORG')]},
#  {'sentence': 'This leaves the head of the Islamic Dawa Party , Ibrahim al-Jaafari , as the likely front-runner .',
#   'entities': [('the Islamic', 'ORG'), ('Ibrahim al-Jaafari', 'PERSON')]},
#  {'sentence': 'Both parties belong to the United Iraqi Alliance , which won about 48 percent of the vote for the National Assembly .',
#   'entities': [('the United Iraqi Alliance', 'ORG'),
#    ('the National Assembly', 'ORG')]},
#  {'sentence': "Meanwhile , Iraq 's Electoral Commission says it has received at least three complaints from political groups challenging the election results .",
#   'entities': [('Iraq', 'GPE'), ('Electoral Commission', 'ORG')]},
#  {'sentence': 'A final , certified vote tally is expected Wednesday .',
#   'entities': [('Wednesday', 'DATE')]},
#  {'sentence': 'And Turkish shipping magnate Kahraman Sadikoglu , who was abducted in southern Iraq in December , has been freed after reports said his family paid a ransom to his kidnappers .',
#   'entities': [('Turkish', 'NORP'),
#    ('Kahraman Sadikoglu', 'PERSON'),
#    ('Iraq', 'GPE'),
#    ('December', 'DATE')]},
#  {'sentence': 'A Council of Europe panel says Turkey has passed important legislation protecting minority rights , but has not adequately enforced the new laws .',
#   'entities': [('Council of Europe', 'ORG'), ('Turkey', 'GPE')]},
#  {'sentence': "In a report , the European Commission against Racism and Intolerance says that despite the new legislation , Turkey 's constitution and its civil , criminal and administrative laws continue to have gaps in addressing racism .",
#   'entities': [('the European Commission', 'ORG'), ('Turkey', 'GPE')]},
#  {'sentence': 'The report , issued Tuesday in Strasbourg , says Kurds and other minorities still face adversity in Turkey , particularly from ongoing violence in the southeast where Kurdish separatists have been active in recent decades .',
#   'entities': [('Tuesday', 'DATE'),
#    ('Strasbourg', 'GPE'),
#    ('Kurds', 'NORP'),
#    ('Turkey', 'GPE'),
#    ('Kurdish', 'NORP'),
#    ('recent decades', 'DATE')]},
#  {'sentence': "Turkey 's move to push through legal and economic reforms is considered an essential part of its bid to join the European Union .",
#   'entities': [('Turkey', 'GPE'), ('the European Union', 'ORG')]},
#  {'sentence': 'The Council of Europe is a 46-nation group that brings together lawmakers from democratic European countries to review major issues facing the continent .',
#   'entities': [('The Council of Europe', 'ORG'), ('European', 'NORP')]},
#  {'sentence': "Armenia has launched an aerial tramway line that it says is the world 's longest .",
#   'entities': [('Armenia', 'GPE')]},
#  {'sentence': "President Serzh Sarkisian attended the opening of the tramway Saturday , in the country 's southern mountains near Armenia 's border with Iran .",
#   'entities': [('Serzh Sarkisian', 'PERSON'),
#    ('Saturday', 'DATE'),
#    ('Armenia', 'GPE'),
#    ('Iran', 'GPE')]},
#  {'sentence': 'The 5.7-kilometer engineering feat spans the Vorotan River gorge , linking a village off the main highway to the 9th century Tatev Monastery .',
#   'entities': [('Vorotan River', 'LOC'),
#    ('the 9th century', 'DATE'),
#    ('Tatev Monastery', 'PERSON')]},
#  {'sentence': "The monastery is one of the country 's oldest and most prominent monasteries and is a major tourist attraction .",
#   'entities': []},
#  {'sentence': "The head of Cuba 's parliament has offered to support Iran in its fight to develop nuclear energy within Iranian borders .",
#   'entities': [('Cuba', 'GPE'), ('Iran', 'GPE'), ('Iranian', 'NORP')]},
#  {'sentence': "Ricardo Alarcon voiced solidarity Thursday in a meeting with the visiting speaker of Iran 's parliament , Gholam Ali Haddad Adel .",
#   'entities': [('Ricardo Alarcon', 'PERSON'),
#    ('Thursday', 'DATE'),
#    ('Iran', 'GPE'),
#    ('Gholam Ali Haddad Adel', 'PERSON')]},
#  {'sentence': 'Iran resumed enrichment of uranium for nuclear fuel earlier this week , despite international pressure against the move .',
#   'entities': [('Iran', 'GPE'), ('earlier this week', 'DATE')]},
#  {'sentence': 'Haddad Adel is on a two-day visit to Cuba after spending Wednesday in Venezuela , where he thanked the government for its support on nuclear issues .',
#   'entities': [('Haddad Adel', 'PERSON'),
#    ('two-day', 'DATE'),
#    ('Cuba', 'GPE'),
#    ('Wednesday', 'DATE'),
#    ('Venezuela', 'GPE')]},
#  {'sentence': 'Meanwhile , Indiana Representative Dan Burton , in an interview with Voice of America Thursday , expressed concern over the close ties between Iran and the two countries .',
#   'entities': [('Indiana', 'GPE'),
#    ('Dan Burton', 'PERSON'),
#    ('Voice of America', 'ORG'),
#    ('Thursday', 'DATE'),
#    ('Iran', 'GPE')]},
#  {'sentence': 'He said if it appears that there is coordination between terrorist states and leftist organizations in Central America , the United States will intervene .',
#   'entities': [('Central America', 'LOC'), ('the United States', 'GPE')]},
#  {'sentence': 'Representative Burton said such a relationship would endanger the United States and other countries in the hemisphere .',
#   'entities': [('Burton', 'PERSON'), ('the United States', 'GPE')]},
#  {'sentence': 'European Union foreign ministers hold emergency talks in Luxembourg Sunday in efforts to break a deadlock on Turkey , which is scheduled to begin membership negotiations with the bloc one day later .',
#   'entities': [('European Union', 'ORG'),
#    ('Luxembourg', 'GPE'),
#    ('Sunday', 'DATE'),
#    ('Turkey', 'GPE'),
#    ('one day later', 'DATE')]},
#  {'sentence': 'The ministers called the meeting after Austria insisted that EU talks with Turkey should include an alternative to giving the country full membership .',
#   'entities': [('Austria', 'GPE'), ('EU', 'ORG'), ('Turkey', 'GPE')]},
#  {'sentence': 'Austria says most Austrians object to full EU membership for Turkey and suggested offering Turkey privileged partnership instead .',
#   'entities': [('Austria', 'GPE'),
#    ('Austrians', 'NORP'),
#    ('EU', 'ORG'),
#    ('Turkey', 'GPE'),
#    ('Turkey', 'GPE')]},
#  {'sentence': "But Turkey calls that unacceptable and says it will not take part in Monday 's talks unless it is clear that the goal is full membership .",
#   'entities': [('Turkey', 'GPE'), ('Monday', 'DATE')]},
#  {'sentence': 'EU diplomats are working on proposals to soften Austrian opposition .',
#   'entities': [('EU', 'ORG'), ('Austrian', 'NORP')]},
#  {'sentence': "One would be a commitment to begin membership talks with Austria 's neighbor Croatia in the near future .",
#   'entities': [('Austria', 'GPE'), ('Croatia', 'GPE')]},
#  {'sentence': 'EU ministers had delayed the talks because of Croatian failure to cooperate fully with The Hague war crimes tribunal .',
#   'entities': [('EU', 'ORG'), ('Croatian', 'NORP')]},
#  {'sentence': 'Pakistani military authorities say they have arrested a key Taliban commander who is accused of slaughtering military personnel .',
#   'entities': [('Pakistani', 'NORP'), ('Taliban', 'ORG')]},
#  {'sentence': 'Security forces said Wednesday they captured Taliban commander Sher Mohammad Qasab in the Swat Valley .',
#   'entities': [('Wednesday', 'DATE'),
#    ('Taliban', 'ORG'),
#    ('Sher Mohammad Qasab', 'PERSON'),
#    ('the Swat Valley', 'LOC')]},
#  {'sentence': 'Qasab is known for his brutality among locals in the valley .',
#   'entities': [('Qasab', 'PERSON')]},
#  {'sentence': 'A military spokesman said Qasab was wounded and three of his sons died during an exchange of fire before his arrest .',
#   'entities': [('Qasab', 'PERSON')]},
#  {'sentence': 'Pakistani forces have arrested key Taliban commanders recently in the valley , including Muslim Khan , the central spokesman for the militants .',
#   'entities': [('Pakistani', 'NORP'), ('Taliban', 'ORG'), ('Muslim', 'NORP')]},
#  {'sentence': 'Authorities say the arrests have weakened the Taliban and are helping security forces conduct successful raids against other militants in the area .',
#   'entities': [('Taliban', 'ORG')]},
#  {'sentence': 'The top U.S. diplomat says China should make significant economic reforms so it does not continue to be a " problem for the international economy . "',
#   'entities': [('U.S.', 'GPE'), ('China', 'GPE')]},
#  {'sentence': "In a New York Times newspaper interview , published Friday , Secretary of State Condoleezza Rice says Washington also worries about China 's military buildup , human rights practices and religious restrictions .",
#   'entities': [('New York Times', 'ORG'),
#    ('Friday', 'DATE'),
#    ('State', 'ORG'),
#    ('Condoleezza Rice', 'PERSON'),
#    ('Washington', 'GPE'),
#    ('China', 'GPE')]},
#  {'sentence': 'It is a change of tone for Ms. Rice , who generally casts Sino-American relations in a positive light .',
#   'entities': [('Rice', 'PERSON'), ('Sino-American', 'NORP')]},
#  {'sentence': 'Her comments come just a month before Chinese President Hu Jintao makes his first visit to Washington since taking office in 2003 .',
#   'entities': [('just a month', 'DATE'),
#    ('Chinese', 'NORP'),
#    ('Hu Jintao', 'PERSON'),
#    ('Washington', 'GPE'),
#    ('2003', 'DATE')]},
#  {'sentence': "He will arrive amid Washington 's complaints that China manipulates the value of its currency to make its products unfairly cheap on world markets .",
#   'entities': [('Washington', 'GPE'), ('China', 'GPE')]},
#  {'sentence': 'Beijing recently changed the value of its currency slightly , but U.S. critics say the change is not large enough to make trade fair .',
#   'entities': [('Beijing', 'GPE'), ('U.S.', 'GPE')]},
#  {'sentence': "Chad 's national assembly has authorized President Idriss Deby to renew a state of emergency imposed after a rebel attack on the capital , N'Djamena , early this month .",
#   'entities': [('Chad', 'GPE'),
#    ('Idriss Deby', 'PERSON'),
#    ("N'Djamena", 'GPE'),
#    ('early this month', 'DATE')]}]

# %%
# Manually tagged Named Entities
Manual_NER_list[:300]
# Out:
# [{'sentence': 'EU Commission President Jose Manuel Barroso has said the 25-member bloc will make it clear to the Russian President that the EU is not " satisfied " with Ukraine \'s disputed election .\r',
#   'entities': [[0, 2, 'ORG'],
#    [24, 43, 'PERSON'],
#    [98, 105, 'NORP'],
#    [125, 127, 'ORG'],
#    [154, 161, 'GPE']]},
#  {'sentence': "Prime Minister Viktor Yanukovych -- who was backed by Mr. Putin -- has been declared the winner of Sunday 's voting , but the EU is rejecting the results because of allegations of widespread voting fraud .\r",
#   'entities': [[15, 32, 'PERSON'],
#    [58, 63, 'PERSON'],
#    [99, 105, 'DATE'],
#    [126, 128, 'ORG']]},
#  {'sentence': 'On other issues , EU leaders say they will call on Russia to sign and ratify border agreements with Estonia and Latvia , and urge it to seek a political settlement in war-torn Chechnya .\r',
#   'entities': [[18, 20, 'ORG'],
#    [51, 57, 'GPE'],
#    [100, 107, 'GPE'],
#    [112, 118, 'GPE'],
#    [176, 184, 'GPE']]},
#  {'sentence': 'Palestinian President Mahmoud Abbas has fired three top security officials after militants broke the ceasefire he reached with Israel and fired mortars at Jewish settlements in the Gaza Strip .\r',
#   'entities': [[0, 11, 'NORP'],
#    [22, 35, 'PERSON'],
#    [127, 133, 'GPE'],
#    [155, 161, 'NORP'],
#    [181, 185, 'GPE']]},
#  {'sentence': 'Mr. Abbas dismissed the men , including security chief Abdel Razek Majaidie , hours after Hamas militants fired the mortars .\r',
#   'entities': [[4, 9, 'PERSON'], [55, 75, 'PERSON'], [90, 95, 'ORG']]},
#  {'sentence': 'No one was wounded in the shelling , which Hamas said was a response to Israeli gunfire that killed a Palestinian man Wednesday in Gaza .\r',
#   'entities': [[43, 48, 'ORG'],
#    [72, 79, 'NORP'],
#    [102, 113, 'NORP'],
#    [118, 127, 'DATE'],
#    [131, 135, 'GPE']]},
#  {'sentence': 'Despite the violence , Israeli and Palestinian officials met late Thursday to discuss security issues .\r',
#   'entities': [[23, 30, 'NORP'], [35, 46, 'NORP'], [66, 74, 'DATE']]},
#  {'sentence': 'Meanwhile , a deadly shootout was also reported at a Palestinian jail in Gaza City .\r',
#   'entities': [[53, 64, 'NORP'], [73, 82, 'GPE']]},
#  {'sentence': 'Palestinian sources say at least three people described as Israeli collaborators were killed when dozens of masked gunmen stormed a jailhouse and set free several prisoners .\r',
#   'entities': [[0, 11, 'NORP'], [59, 66, 'NORP']]},
#  {'sentence': 'Germany , France and Lithuania are the latest European countries to congratulate Viktor Yushchenko on his victory in the Ukrainian presidential election .\r',
#   'entities': [[0, 7, 'GPE'],
#    [10, 16, 'GPE'],
#    [21, 30, 'GPE'],
#    [46, 54, 'NORP'],
#    [81, 98, 'PERSON'],
#    [121, 130, 'NORP']]},
#  {'sentence': 'In a letter to Mr. Yushchenko Tuesday , German Chancellor Gerhard Schroeder expressed optimism that Ukraine will continue what he called its transition toward the rule of law and a market economy .\r',
#   'entities': [[19, 29, 'PERSON'],
#    [30, 37, 'DATE'],
#    [40, 46, 'NORP'],
#    [58, 75, 'PERSON'],
#    [100, 107, 'GPE']]},
#  {'sentence': 'Lithuanian President Viktor Adamkus congratulated Mr. Yushchenko in a telephone conversation .\r',
#   'entities': [[0, 10, 'NORP'], [21, 35, 'PERSON'], [54, 64, 'PERSON']]},
#  {'sentence': 'In Paris , the foreign ministry said France and its European Union partners are determined to support democracy and modernization in Ukraine .\r',
#   'entities': [[3, 8, 'GPE'],
#    [37, 43, 'GPE'],
#    [52, 66, 'ORG'],
#    [133, 140, 'GPE']]},
#  {'sentence': 'Meanwhile , Russia has questioned the objectivity of monitors for the Organization for Security and Cooperation in Europe .\r',
#   'entities': [[12, 18, 'GPE'], [115, 121, 'GPE']]},
#  {'sentence': "That organization characterized last month 's presidential election re-run as flawed , while saying that Sunday 's poll vastly improved upon the last vote .\r",
#   'entities': [[37, 42, 'DATE'], [105, 111, 'DATE']]},
#  {'sentence': "Russia backed Mr. Yushchenko 's opponent .\r",
#   'entities': [[0, 6, 'GPE'], [18, 28, 'PERSON']]},
#  {'sentence': 'U.S. weather forecasters say Tropical Storm Ernesto has formed over the Caribbean and is heading toward Jamaica and the Cayman Islands .\r',
#   'entities': [[0, 4, 'GPE'],
#    [72, 81, 'GPE'],
#    [104, 111, 'GPE'],
#    [120, 134, 'GPE']]},
#  {'sentence': 'The National Hurricane Center thinks the storm could strengthen in coming days and is on track to enter the Gulf of Mexico next week .\r',
#   'entities': [[67, 78, 'DATE'], [108, 122, 'GPE'], [123, 132, 'DATE']]},
#  {'sentence': 'The center is urging Jamaica and the Cayman Islands to monitor the threats posed by Ernesto , the fifth named storm of the season .\r',
#   'entities': [[21, 28, 'GPE'], [37, 51, 'GPE']]},
#  {'sentence': 'Earlier Friday , Tropical Storm Debby weakened over the Atlantic .\r',
#   'entities': [[0, 14, 'DATE'], [56, 64, 'LOC']]},
#  {'sentence': 'The National Hurricane Center in Miami says Debby is about 2,200 kilometers northwest of the Cape Verde Islands , with winds near 65 kilometers per hour .\r',
#   'entities': [[33, 38, 'GPE'], [93, 111, 'GPE']]},
#  {'sentence': 'It says no significant change in strength is expected over the next day .\r',
#   'entities': [[63, 71, 'DATE']]},
#  {'sentence': "Ethiopian security forces say they have foiled what they describe as a terrorist plot by a group linked to the country 's main opposition party .\r",
#   'entities': [[0, 9, 'NORP']]},
#  {'sentence': 'A statement released through state media says authorities arrested a group that was planning attacks in the capital , Addis Ababa .\r',
#   'entities': [[118, 129, 'GPE']]},
#  {'sentence': 'The statement says the group planned to target government officials and institutions .\r',
#   'entities': []},
#  {'sentence': 'Ethiopian authorities say they also seized bombs , explosives and small arms related to the plot .\r',
#   'entities': [[0, 9, 'NORP']]},
#  {'sentence': 'The statement did not say how many people were arrested or explain how the alleged group is linked to the opposition Coalition for Unity and Democracy .\r',
#   'entities': [[117, 150, 'NORP']]},
#  {'sentence': 'Leaders of the party were not available for comment .\r',
#   'entities': []},
#  {'sentence': 'Ethiopian Prime Minister Meles Zenawi has repeatedly accused the opposition of conspiring to incite violence and seeking to overthrow him .\r',
#   'entities': [[0, 9, 'NORP'], [25, 37, 'PERSON']]},
#  {'sentence': 'The government has charged at least 129 opposition leaders , journalists and others with treason and planning to commit genocide .\r',
#   'entities': []},
#  {'sentence': 'United Nations Secretary-General Kofi Annan has ordered disciplinary action against senior U.N. officials who worked on the oil-for-food program in Iraq .\r',
#   'entities': [[0, 14, 'ORG'],
#    [33, 43, 'PERSON'],
#    [91, 95, 'ORG'],
#    [148, 152, 'GPE']]},
#  {'sentence': 'Mr. Annan said in a statement Thursday a report about alleged corruption in the U.N. program has turned up " extremely troubling evidence of wrongdoing , " and he pledged that no one involved would be shielded from prosecution .\r',
#   'entities': [[4, 9, 'PERSON'], [30, 38, 'DATE'], [80, 84, 'ORG']]},
#  {'sentence': 'The independent report , released Thursday , concluded that the head of the oil-for-food program , Benon Sevan , seriously undermined the integrity of the United Nations by his conduct .\r',
#   'entities': [[34, 42, 'DATE'], [99, 110, 'PERSON'], [155, 169, 'ORG']]},
#  {'sentence': 'U.N. disciplinary proceedings have begun against Mr. Sevan and another senior official , Joseph Stephanides .\r',
#   'entities': [[0, 4, 'ORG'], [53, 58, 'PERSON'], [89, 107, 'PERSON']]},
#  {'sentence': 'Both Mr. Sevan and Mr. Stephanides are Cypriot nationals .\r',
#   'entities': [[9, 14, 'PERSON'], [23, 34, 'PERSON'], [39, 46, 'NORP']]},
#  {'sentence': "Critics say billions of dollars were siphoned away from the oil-for-food program , which was devised after the first Gulf War in an attempt to help Iraq 's impoverished civilian population .\r",
#   'entities': [[12, 31, 'MONEY'], [148, 152, 'GPE']]},
#  {'sentence': 'Rebels and government forces in Ivory Coast began withdrawing heavy weapons from the front line Thursday , complying with a new peace deal to end tensions in the divided nation .\r',
#   'entities': [[32, 43, 'GPE'], [96, 104, 'DATE']]},
#  {'sentence': 'The pullback , expected to last four days , includes all guns larger than 20 millimeters and short-range weaponry equal to or larger than 60 millimeters , including mortars .\r',
#   'entities': [[32, 41, 'DATE']]},
#  {'sentence': 'Anti-tank weapons will remain in place .\r', 'entities': []},
#  {'sentence': 'One rebel fighter told VOA he was happy to see the repeatedly postponed disarmament process begin , adding that he hopes to become a police officer once the two-year-old conflict is finally over .\r',
#   'entities': [[23, 26, 'ORG'], [157, 169, 'DATE']]},
#  {'sentence': 'Several peace deals have failed to take hold in Ivory Coast .\r',
#   'entities': [[48, 60, 'GPE']]},
#  {'sentence': 'Rebels still hold huge swaths of territory in northern and western Ivory Coast , with the government firmly in control of the south .\r',
#   'entities': [[67, 79, 'GPE']]},
#  {'sentence': "News reports from Uzbekistan say sporadic gunfire has continued in areas along the Kyrgyz border , following Friday 's military crackdown against protesters in the city of Andijan .\r",
#   'entities': [[18, 28, 'GPE'],
#    [83, 96, 'GPE'],
#    [109, 115, 'DATE'],
#    [172, 179, 'GPE']]},
#  {'sentence': 'The Associated Press quoted residents as saying several soldiers and civilians were killed when clashes erupted Sunday in two border villages , Teshiktosh and Karasu .\r',
#   'entities': [[112, 118, 'DATE'], [144, 154, 'GPE'], [159, 165, 'GPE']]},
#  {'sentence': 'Earlier reports said as many as 500 people were killed when security forces fired into a crowd of demonstrators in Andijan on Friday .\r',
#   'entities': [[115, 122, 'GPE'], [126, 132, 'DATE']]},
#  {'sentence': 'But Uzbek President Islam Karimov said the death toll was much lower .\r',
#   'entities': [[4, 9, 'NORP'], [20, 33, 'PERSON']]},
#  {'sentence': 'He blamed the bloodshed on Islamic radicals trying to overthrow the government .\r',
#   'entities': [[27, 34, 'NORP']]},
#  {'sentence': 'Several countries , including the United States , have called for restraint .\r',
#   'entities': [[34, 47, 'GPE']]},
#  {'sentence': 'British Foreign Secretary Jack Straw called the Andijan crackdown a clear abuse of human rights .\r',
#   'entities': [[0, 7, 'NORP'], [26, 36, 'PERSON'], [48, 55, 'GPE']]},
#  {'sentence': "Pope John Paul II has included prayers for the victims of the Asian tsunami in his New Year 's Day Mass marking the Roman Catholic Church 's annual World Day of Peace .\r",
#   'entities': [[0, 17, 'PERSON'],
#    [62, 68, 'NORP'],
#    [83, 91, 'DATE'],
#    [116, 130, 'NORP'],
#    [141, 148, 'DATE']]},
#  {'sentence': "Thousands of pilgrims attended the Pope 's outdoor Mass Saturday at the Vatican .\r",
#   'entities': [[56, 64, 'DATE'], [72, 79, 'GPE']]},
#  {'sentence': 'John Paul II also led a Mass for the tsunami victims in his private chapel overnight .\r',
#   'entities': [[0, 12, 'PERSON']]},
#  {'sentence': "In his peace message , the pontiff called for greater cooperation among the world 's religions , and for promotion of peace through dialogue , justice and forgiveness .\r",
#   'entities': []},
#  {'sentence': 'He urged the world \'s one billion Roman Catholics to , " win the fight over evil with the armies of love . "\r',
#   'entities': [[34, 49, 'NORP']]},
#  {'sentence': 'The European Union opened membership talks with Turkey early Tuesday , after settling last-minute objections by Austria .\r',
#   'entities': [[4, 18, 'ORG'],
#    [48, 54, 'GPE'],
#    [55, 68, 'DATE'],
#    [112, 119, 'GPE']]},
#  {'sentence': "EU foreign ministers ended 30 hours of heated emergency meetings late Monday in Luxembourg with Austrian officials withdrawing Vienna 's demand that the EU retain the option of offering Turkey a limited partnership .\r",
#   'entities': [[0, 2, 'ORG'],
#    [65, 76, 'DATE'],
#    [80, 90, 'GPE'],
#    [96, 104, 'NORP'],
#    [127, 133, 'GPE'],
#    [153, 155, 'NORP'],
#    [186, 192, 'GPE']]},
#  {'sentence': 'Turkey had rejected the option .\r',
#   'entities': [[0, 6, 'GPE']]},
#  {'sentence': "Austria 's cooperation paved the way for all 25 EU member-states to agree on a negotiating framework for the membership process , which is expected to take about 10 years .\r",
#   'entities': [[0, 7, 'GPE'], [48, 51, 'PERSON'], [162, 170, 'DATE']]},
#  {'sentence': 'A brief ceremony to officially open the talks took place shortly after midnight Tuesday in Luxembourg .\r',
#   'entities': [[80, 87, 'DATE'], [91, 101, 'GPE']]},
#  {'sentence': 'Talks had been scheduled to open Monday .\r',
#   'entities': [[33, 39, 'DATE']]},
#  {'sentence': 'If accepted , Turkey would be the first country with a majority Muslim population to join the European Union .\r',
#   'entities': [[14, 20, 'GPE'], [94, 108, 'NORP']]},
#  {'sentence': 'It has been an associate member of the bloc since 1963 .\r',
#   'entities': [[50, 54, 'DATE']]},
#  {'sentence': 'Egyptian President Hosni Mubarak has called for both his supporters and opponents to work with him as he embarks on his fifth presidential term .\r',
#   'entities': [[0, 8, 'NORP'], [19, 32, 'PERSON']]},
#  {'sentence': 'He took the oath of office Tuesday before parliament and several foreign dignitaries , including Libyan leader Moammar Gadhafi .\r',
#   'entities': [[27, 34, 'DATE'], [97, 104, 'NORP'], [111, 126, 'PERSON']]},
#  {'sentence': "In a nationally televised speech , the 77-year-old leader pledged to continue a nascent program of political and economic reforms , and to improve the living standard of Egypt 's majority poor during his term , which runs through 2011 .\r",
#   'entities': [[39, 50, 'DATE'], [170, 175, 'GPE'], [230, 234, 'DATE']]},
#  {'sentence': 'He also promised November \'s legislative elections will be " free and fair , " after criticisms that September \'s first multi-candidate presidential race was rife with voting irregularities .\r',
#   'entities': [[17, 25, 'DATE'], [101, 110, 'DATE']]},
#  {'sentence': 'Mr. Mubarak beat nine challengers , winning more than 88 percent of the vote .\r',
#   'entities': [[4, 11, 'PERSON']]},
#  {'sentence': 'Japan says it wants safety guarantees for its players and fans when its national soccer ( football ) team travels to North Korea for a World Cup qualifying match in June .\r',
#   'entities': [[0, 5, 'GPE'], [117, 128, 'GPE'], [165, 170, 'DATE']]},
#  {'sentence': "Japan 's Chief Cabinet Secretary Hiroyuki Hosoda says it is a necessary precondition for any international match that players can play safely and spectators can be protected .\r",
#   'entities': [[0, 5, 'GPE'], [33, 48, 'PERSON']]},
#  {'sentence': 'Japanese concerns were raised by scenes of mob violence at a match in Pyongyang between Iran and North Korea on Wednesday .\r',
#   'entities': [[0, 8, 'NORP'],
#    [70, 79, 'GPE'],
#    [87, 92, 'GPE'],
#    [97, 108, 'GPE'],
#    [112, 121, 'DATE']]},
#  {'sentence': 'The game was televised and cameras showed the North Korean spectators throwing bottles , cans and seats at players and officials on the field .\r',
#   'entities': [[46, 58, 'NORP']]},
#  {'sentence': 'Riot police had to clear a path for the victorious Iranian players to reach their team bus .\r',
#   'entities': [[51, 58, 'NORP']]},
#  {'sentence': 'The violence at the game was a rare occurrence in the tightly controlled North Korean state .\r',
#   'entities': [[73, 85, 'NORP']]},
#  {'sentence': 'A published report says the United States has been flying drones over Iran for almost a year , looking for evidence of nuclear weapons programs and detect weaknesses in air defenses .\r',
#   'entities': [[28, 41, 'GPE'], [70, 74, 'GPE'], [79, 92, 'DATE']]},
#  {'sentence': "In Sunday 's editions , The Washington Post quotes three U.S. officials as saying the U.S. military has been launching the unmanned surveillance flights from Iraq .\r",
#   'entities': [[3, 9, 'DATE'],
#    [28, 43, 'ORG'],
#    [57, 61, 'GPE'],
#    [86, 90, 'GPE'],
#    [158, 162, 'GPE']]},
#  {'sentence': 'There has been no U.S. comment on the report .\r',
#   'entities': [[18, 22, 'GPE']]},
#  {'sentence': 'An Iranian spokesman Sunday again warned the United States not to attack its nuclear facilities .\r',
#   'entities': [[3, 10, 'NORP'], [21, 27, 'DATE'], [45, 58, 'GPE']]},
#  {'sentence': "He also rejected a European proposal aimed at restricting Tehran 's development of nuclear fuel .\r",
#   'entities': [[19, 27, 'NORP'], [58, 65, 'GPE']]},
#  {'sentence': 'Iran has said in the past it would stop plans to build a heavy water nuclear reactor , which can be used to make nuclear weapons-grade material as well as for nuclear energy .\r',
#   'entities': [[0, 4, 'GPE']]},
#  {'sentence': 'But Sunday in Tehran , a foreign ministry spokesman said Iran will go forward with the heavy water reactor and will not replace it under any circumstances .\r',
#   'entities': [[4, 10, 'DATE'], [14, 20, 'GPE'], [57, 61, 'GPE']]},
#  {'sentence': 'North Korea says its Catholic community has organized religious services in memory of Pope John Paul .\r',
#   'entities': [[0, 11, 'GPE'], [21, 29, 'NORP'], [86, 101, 'PERSON']]},
#  {'sentence': "The official news agency , KCNA , on Tuesday quotes Samuel Jang Jae On , described as head of the country 's Catholic association , as saying North Korean Catholics are deeply saddened by the pontiff 's passing .\r",
#   'entities': [[27, 31, 'ORG'],
#    [37, 44, 'DATE'],
#    [52, 70, 'PERSON'],
#    [109, 117, 'NORP'],
#    [142, 154, 'NORP'],
#    [155, 164, 'NORP']]},
#  {'sentence': 'The agency says Mr. Jang sent the Vatican a message of condolence .\r',
#   'entities': [[20, 24, 'PERSON'], [34, 41, 'GPE']]},
#  {'sentence': "North Korea is widely described as one of the world 's most repressive political regimes .\r",
#   'entities': [[0, 11, 'GPE']]},
#  {'sentence': 'It is not clear how many Catholics live in the Communist nation and to what extent they can practice their religion .\r',
#   'entities': [[25, 34, 'NORP'], [47, 56, 'NORP']]},
#  {'sentence': 'Thousands of protesters have demonstrated outside a Philippine army camp , where U.S. soldiers and Philippine troops have begun joint military exercises .\r',
#   'entities': [[52, 62, 'NORP'], [81, 85, 'GPE'], [99, 109, 'NORP']]},
#  {'sentence': 'Demonstrators in the town of Carmen on the southern island of Mindanao chanted anti-U.S. slogans Tuesday and demanded that American troops leave the area .\r',
#   'entities': [[29, 35, 'GPE'],
#    [52, 70, 'GPE'],
#    [97, 104, 'DATE'],
#    [123, 131, 'NORP']]},
#  {'sentence': "U.S. soldiers will also take part in the Philippines ' annual war games , to be held next month on Jolo island in the southern Philippines .\r",
#   'entities': [[0, 4, 'GPE'],
#    [41, 52, 'GPE'],
#    [85, 95, 'DATE'],
#    [99, 110, 'GPE'],
#    [127, 138, 'GPE']]},
#  {'sentence': 'Jolo is where the al-Qaida-linked militant group Abu Sayyaf has carried out bombings , kidnappings and killings of foreigners in recent years .\r',
#   'entities': [[0, 4, 'GPE'],
#    [18, 26, 'ORG'],
#    [49, 59, 'PERSON'],
#    [129, 142, 'DATE']]},
#  {'sentence': 'Philippine law prohibits American troops from joining any combat operations with Philippine forces .\r',
#   'entities': [[0, 10, 'NORP'], [25, 33, 'NORP'], [81, 91, 'NORP']]},
#  {'sentence': 'Security for the war games will be tight , to protect the soldiers from attacks by rebels .\r',
#   'entities': []},
#  {'sentence': "In addition to military training , troops will carry out humanitarian missions to try to boost support among Jolo 's residents .\r",
#   'entities': [[109, 113, 'GPE']]},
#  {'sentence': 'The U.N. World Food Program is giving emergency assistance to the Cuban government .\r',
#   'entities': [[4, 8, 'ORG'], [66, 71, 'NORP']]},
#  {'sentence': 'The WFP announced Tuesday that it will help feed about two million people at a cost of nearly $ 6 million .\r',
#   'entities': [[18, 25, 'DATE'], [94, 105, 'MONEY']]},
#  {'sentence': "The aid package is intended to help Cuba recover from last month 's devastation from Hurricanes Gustav and Ike .\r",
#   'entities': [[36, 40, 'GPE'], [54, 64, 'DATE']]},
#  {'sentence': 'During the next six months , WFP will provide food rations , including rice , beans , vegetable oil , canned fish and more .\r',
#   'entities': [[11, 26, 'DATE']]},
#  {'sentence': 'The WFP will also supply temporary food storage warehouses and liquid gas stoves to people who lost their cooking facilities in the storms .\r',
#   'entities': []},
#  {'sentence': "Sweden 's Nobel Foundation begins announcing winners of the annual Nobel Prize awards on Monday in Oslo , Norway .\r",
#   'entities': [[0, 6, 'GPE'],
#    [89, 95, 'DATE'],
#    [99, 103, 'GPE'],
#    [106, 112, 'GPE']]},
#  {'sentence': 'Prizes for medicine , physics , chemistry and literature will be announced before the prestigious Peace Prize is revealed Friday .\r',
#   'entities': [[122, 128, 'DATE']]},
#  {'sentence': 'A separate prize for economics will be announced October 10 .\r',
#   'entities': [[49, 59, 'DATE']]},
#  {'sentence': 'It was instituted in 1968 by the Bank of Sweden in memory of the founder of the Nobel Prize , Swedish philanthropist Alfred Nobel .\r',
#   'entities': [[21, 25, 'DATE'],
#    [41, 47, 'GPE'],
#    [94, 101, 'NORP'],
#    [117, 129, 'PERSON']]},
#  {'sentence': 'Winners receive their awards , including a check worth $ 1.3 million , at a banquet on December 10 .\r',
#   'entities': [[55, 68, 'MONEY'], [87, 98, 'DATE']]},
#  {'sentence': "That is the anniversary of Mr. Nobel 's death in 1896 .\r",
#   'entities': [[31, 36, 'PERSON'], [49, 53, 'DATE']]},
#  {'sentence': 'According to his will , a five-member committee elected by the Norwegian parliament chooses the Peace Prize laureate , while Swedish scientific and literary groups choose the other winners .\r',
#   'entities': [[63, 72, 'NORP'], [125, 132, 'NORP']]},
#  {'sentence': 'The first Nobel Prizes were given in 1901 .\r',
#   'entities': [[37, 41, 'DATE']]},
#  {'sentence': 'Insurgents in Iraq fired a barrage of mortar rounds into central Baghdad\r',
#   'entities': [[14, 18, 'GPE'], [65, 72, 'GPE']]},
#  {'sentence': 'Thursday , killing at least one person and wounding several others .\r',
#   'entities': [[0, 8, 'DATE']]},
#  {'sentence': 'Police say some of the mortars landed in the Green Zone -- the heavily fortified enclave that houses Iraqi government offices and several foreign embassies .\r',
#   'entities': [[101, 106, 'NORP']]},
#  {'sentence': 'Last week , a mortar attack on the Green Zone killed four employees of a British security company .\r',
#   'entities': [[0, 9, 'DATE'], [73, 80, 'NORP']]},
#  {'sentence': "Meanwhile , the U.S. military is planning to temporarily increase the number of American troops in Iraq to bolster security ahead of Iraq 's January election .\r",
#   'entities': [[16, 20, 'GPE'],
#    [80, 88, 'NORP'],
#    [99, 103, 'GPE'],
#    [133, 138, 'GPE'],
#    [141, 149, 'DATE']]},
#  {'sentence': 'The Defense Department said Wednesday the size of U.S. forces in Iraq will increase to 1,50,000 from its current level of 1,38,000 .\r',
#   'entities': [[28, 37, 'DATE'], [50, 54, 'GPE'], [65, 69, 'GPE']]},
#  {'sentence': "Iraq 's interim government has rejected calls from some Sunni parties to postpone the vote because of security concerns .\r",
#   'entities': [[0, 5, 'GPE'], [56, 62, 'NORP']]},
#  {'sentence': 'Brazilian lawmakers have approved legislation that will give the government more control over developing offshore oil fields .\r',
#   'entities': [[0, 9, 'NORP']]},
#  {'sentence': 'The lower house of the Brazilian congress passed the bill Wednesday , sending it to outgoing President Luiz Inacio Lula da Silva for his signature .\r',
#   'entities': [[23, 32, 'NORP'], [58, 67, 'DATE'], [103, 128, 'PERSON']]},
#  {'sentence': 'The measure allows the state-owned oil company , known as Petrobras , to be the sole operator of unexplored offshore oil fields , as well as a 30 percent stake in any joint ventures .\r',
#   'entities': [[58, 67, 'ORG']]},
#  {'sentence': "Brazil has discovered potentially large oil reserves off the country 's southeastern coast , some of them thousands of meters below the sea floor .\r",
#   'entities': [[0, 6, 'GPE']]},
#  {'sentence': 'Some estimates say the fields may contain more than 50 billion barrels of oil .\r',
#   'entities': []},
#  {'sentence': 'Brazilian lawmakers also approved a provision that will allow non-oil producing states to receive more oil revenues .\r',
#   'entities': [[0, 9, 'NORP']]},
#  {'sentence': 'A new U.S. opinion survey shows eight out of 10 Americans believe the country is going in the wrong direction .\r',
#   'entities': [[6, 10, 'GPE'], [48, 57, 'NORP']]},
#  {'sentence': "The Washington Post-ABC News poll also indicates Democrats hold a 21 percentage point advantage over Republicans as the party better equipped to handle the country 's problems .\r",
#   'entities': [[4, 19, 'ORG'], [20, 23, 'ORG'], [101, 112, 'NORP']]},
#  {'sentence': 'In a hypothetical general election match-up , Democratic Party candidate Senator Barack Obama leads presumed Republican nominee John McCain by 51-to-44 percent .\r',
#   'entities': [[81, 93, 'PERSON'], [109, 119, 'NORP'], [128, 140, 'PERSON']]},
#  {'sentence': "As the Democratic Party nears the end of its presidential primaries , the national poll shows Obama has a 12-point advantage over Senator Hillary Clinton as the party 's choice for its nomination .\r",
#   'entities': [[94, 99, 'PERSON'], [138, 153, 'PERSON']]},
#  {'sentence': 'The poll says Americans cite the economy and employment as their top voting issue , followed by the Iraq war , healthcare and fuel prices .\r',
#   'entities': [[14, 23, 'NORP'], [100, 104, 'GPE']]},
#  {'sentence': 'The poll of more than 1,100 adults , conducted from May 8 - 11 , has a margin of error of plus or minus three percentage points .\r',
#   'entities': [[52, 62, 'DATE']]},
#  {'sentence': 'Cuban President Raul Castro is visiting Venezuela on his first international trip as leader of the communist nation .\r',
#   'entities': [[0, 5, 'NORP'],
#    [16, 27, 'PERSON'],
#    [40, 49, 'GPE'],
#    [99, 108, 'NORP']]},
#  {'sentence': "Venezuela 's socialist president , Hugo Chavez , welcomed Mr. Castro Saturday at the Caracas airport .\r",
#   'entities': [[0, 9, 'GPE'],
#    [35, 46, 'PERSON'],
#    [62, 68, 'PERSON'],
#    [69, 77, 'DATE'],
#    [85, 92, 'GPE']]},
#  {'sentence': "This is President Castro 's first official foreign trip since February , when the 77-year-old took charge from his ailing older brother , Fidel Castro .\r",
#   'entities': [[18, 24, 'PERSON'],
#    [62, 70, 'DATE'],
#    [82, 93, 'DATE'],
#    [138, 150, 'PERSON']]},
#  {'sentence': 'The two leaders will visit the tomb of South American independence icon Simon Bolivar today and later hold talks on a variety of issues .\r',
#   'entities': [[45, 53, 'NORP'], [72, 85, 'PERSON']]},
#  {'sentence': 'Venezuela and Cuba have increased cooperation on energy and oil production .\r',
#   'entities': [[0, 9, 'GPE'], [14, 18, 'GPE']]},
#  {'sentence': 'Venezuela is a critical trade partner for the Caribbean island nation , which imports nearly 1,00,000 barrels of oil per day from Venezuela .\r',
#   'entities': [[0, 9, 'GPE'], [46, 55, 'GPE'], [130, 139, 'GPE']]},
#  {'sentence': "Today 's visit comes ahead of a summit in Brazil next week , where Latin American and Caribbean leaders will gather for talks .\r",
#   'entities': [[0, 5, 'DATE'],
#    [42, 48, 'GPE'],
#    [49, 58, 'DATE'],
#    [67, 81, 'NORP'],
#    [86, 95, 'GPE']]},
#  {'sentence': 'The nuclear cooperation pact between India and the United States has sparked a mixed reaction in Washington and abroad .\r',
#   'entities': [[37, 42, 'GPE'], [51, 64, 'GPE'], [97, 107, 'GPE']]},
#  {'sentence': 'International Atomic Energy Agency Director General Mohamed ElBaradei praised the agreement , saying it would bring India closer as an important partner in the non-proliferation group of countries .\r',
#   'entities': [[0, 34, 'ORG'], [52, 69, 'PERSON'], [116, 121, 'GPE']]},
#  {'sentence': 'But some U.S. lawmakers criticized the deal , saying the agreement that could give India access to U.S. civilian nuclear technology would undermine the Nuclear Non-Proliferation Treaty .\r',
#   'entities': [[9, 13, 'GPE'], [83, 88, 'GPE'], [99, 103, 'GPE']]},
#  {'sentence': 'India has not signed the treaty , which restricts the sharing of some nuclear technology with non-member nations , and drew widespread international criticism for conducting nuclear weapons tests as recently as 1998 .\r',
#   'entities': [[0, 5, 'GPE'], [211, 215, 'DATE']]},
#  {'sentence': 'Full details of the nuclear cooperation pact have not been released , but the agreement must still be approved by Congress before taking effect .\r',
#   'entities': []},
#  {'sentence': 'A Sudanese analyst says the late rebel leader John Garang was a symbol of the struggle for greater federalism in the country .\r',
#   'entities': [[2, 10, 'NORP'], [46, 57, 'PERSON']]},
#  {'sentence': 'Lecturer John Gai Yoh of the University of South Africa ( UNISA ) in Pretoria credits the leader of the Sudanese Liberation Movement with creating a campaign that included allies beyond his base in the south .\r',
#   'entities': [[9, 21, 'PERSON'],
#    [43, 55, 'GPE'],
#    [69, 77, 'GPE'],
#    [104, 112, 'NORP']]},
#  {'sentence': 'Mr. Yoh notes that his vision materialized with the comprehensive peace agreement signed last January between the former SPLA rebels and the government in Khartoum .\r',
#   'entities': [[4, 7, 'GPE'], [94, 101, 'DATE'], [155, 163, 'GPE']]},
#  {'sentence': 'Analyst John Gai Yoh predicts that the SPLA will continue to democratize : it has created a new SPLA parliament for the south and has named a new five-man military panel to lead the movement .\r',
#   'entities': [[8, 20, 'PERSON']]},
#  {'sentence': "The United Nations has given its annual Franklin Delano Roosevelt International Disability Award to Poland , recognizing the country 's efforts to integrate the disabled into Polish society .\r",
#   'entities': [[4, 18, 'ORG'],
#    [40, 65, 'PERSON'],
#    [100, 106, 'GPE'],
#    [175, 181, 'NORP']]},
#  {'sentence': 'President Lech Kaczynski accepted the award at a ceremony Monday at U.N. headquarters in New York .\r',
#   'entities': [[10, 24, 'PERSON'],
#    [58, 64, 'DATE'],
#    [68, 72, 'ORG'],
#    [89, 97, 'GPE']]},
#  {'sentence': "He said his country 's struggle for freedom includes a commitment to the rights of those with disabilities .\r",
#   'entities': []},
#  {'sentence': 'He said their rights are guaranteed by the Polish constitution .\r',
#   'entities': [[43, 49, 'NORP']]},
#  {'sentence': 'Mr. Kaczynski promised that Poland will adopt a new U.N. convention to protect the disabled .\r',
#   'entities': [[4, 13, 'PERSON'], [28, 34, 'GPE'], [52, 56, 'ORG']]},
#  {'sentence': 'The award is named for U.S. President Franklin Roosevelt , whose legs were paralyzed from polio .\r',
#   'entities': [[23, 27, 'GPE'], [38, 56, 'PERSON']]},
#  {'sentence': 'Mr. Roosevelt was president from 1933 until 1945 .\r',
#   'entities': [[4, 13, 'PERSON'], [33, 37, 'DATE'], [44, 48, 'DATE']]},
#  {'sentence': 'An Ethiopian government spokesman denies that a reported rebel attack said to have killed 140 soldiers ever took place .\r',
#   'entities': [[3, 12, 'NORP']]},
#  {'sentence': 'The spokesman , Zemedkun Tekle , issued the denial Sunday after media reports said the Ogaden National Liberation Front had claimed to have carried out the deadly attack Saturday in southeastern Ethiopia near Wardheer .\r',
#   'entities': [[16, 30, 'PERSON'],
#    [51, 57, 'DATE'],
#    [87, 119, 'ORG'],
#    [170, 178, 'DATE'],
#    [195, 203, 'GPE'],
#    [209, 217, 'GPE']]},
#  {'sentence': 'A purported statement from the group received by some news organizations said about a thousand rebels took part in the attack and seized ammunition along with military hardware .\r',
#   'entities': []},
#  {'sentence': 'The government spokesman says there was no attack , and that the rebel group is not in a position to carry out such an attack .\r',
#   'entities': []},
#  {'sentence': 'Rebels have been fighting for more autonomy for ethnic Somalis in the eastern region of Ogaden bordering Somalia .\r',
#   'entities': [[55, 62, 'NORP'], [88, 94, 'GPE'], [105, 112, 'GPE']]},
#  {'sentence': 'Kuwaiti television reports the kidnappers in Iraq of American journalist Jill Carroll are threatening to kill her if their demands are not met by February 26 .\r',
#   'entities': [[0, 7, 'NORP'],
#    [45, 49, 'GPE'],
#    [53, 61, 'NORP'],
#    [73, 85, 'PERSON'],
#    [146, 157, 'DATE']]},
#  {'sentence': 'Al-Rai television Friday quoted sources close to the kidnappers as saying the abductors have set the deadline .\r',
#   'entities': [[18, 24, 'DATE']]},
#  {'sentence': 'The militants holding Carroll previously had demanded that all Iraqi women prisoners be freed .\r',
#   'entities': [[22, 29, 'PERSON'], [63, 68, 'NORP']]},
#  {'sentence': 'Earlier Friday , at least eight people died and more than 20 were wounded in a Baghdad car bombing near a Sunni Muslim mosque .\r',
#   'entities': [[0, 14, 'DATE'], [79, 86, 'GPE'], [106, 118, 'NORP']]},
#  {'sentence': "Officials in Iraq also certified results of the December 15 elections , confirming the near majority of parliament seats won by Shi'ite religious parties .\r",
#   'entities': [[13, 17, 'GPE'], [48, 59, 'DATE'], [128, 135, 'NORP']]},
#  {'sentence': "According to the results , the dominant Shi'ite coalition , the United Iraqi Alliance , won 128 seats in the 275-member parliament .\r",
#   'entities': [[40, 47, 'NORP'], [71, 76, 'NORP']]},
#  {'sentence': 'Palestinian security officials say masked Palestinian police briefly stormed a government building in the Gaza Strip in anger over not receiving their salaries from the Hamas-led government .\r',
#   'entities': [[0, 11, 'NORP'],
#    [42, 53, 'NORP'],
#    [106, 110, 'GPE'],
#    [169, 174, 'ORG']]},
#  {'sentence': 'Security officials say about 50 police officers sealed off the main road Saturday in the central Gaza town of Khan Younis .\r',
#   'entities': [[73, 81, 'DATE'], [97, 101, 'GPE'], [110, 121, 'GPE']]},
#  {'sentence': 'They say the masked police surrounded a municipal government building , taking positions on the roof and firing in the air .\r',
#   'entities': []},
#  {'sentence': 'The protest is seen as a sign of discontent with the new Hamas-led government , which took office late last month .\r',
#   'entities': [[57, 62, 'ORG'], [103, 113, 'DATE']]},
#  {'sentence': 'The cash-strapped Palestinian Authority has not been able to pay salaries to some 1,40,000 government employees since March .\r',
#   'entities': [[18, 29, 'NORP'], [118, 123, 'DATE']]},
#  {'sentence': 'Western nations have cut off aid to the Palestinian government , demanding that Hamas renounce violence and recognize Israel .\r',
#   'entities': [[40, 51, 'NORP'], [80, 85, 'ORG'], [118, 124, 'GPE']]},
#  {'sentence': 'The White House said President Bush has approved duty-free treatment for imports of certain types of watches that are n\'t produced in " significant quantities " in the U.S. , the Virgin Islands and other U.S. possessions .\r',
#   'entities': [[31, 35, 'PERSON'],
#    [168, 172, 'GPE'],
#    [179, 193, 'GPE'],
#    [204, 208, 'GPE']]},
#  {'sentence': 'The action came in response to a petition filed by Timex Inc. for changes in the U.S. Generalized System of Preferences for imports from developing nations .\r',
#   'entities': [[51, 61, 'ORG'], [81, 85, 'GPE']]},
#  {'sentence': 'Previously , watch imports were denied such duty-free treatment .\r',
#   'entities': []},
#  {'sentence': 'Timex had requested duty-free treatment for many types of watches , covered by 58 different U.S. tariff classifications .\r',
#   'entities': [[0, 5, 'ORG'], [92, 96, 'GPE']]},
#  {'sentence': 'The White House said Mr. Bush decided to grant duty-free status for 18 categories , but turned down such treatment for other types of watches " because of the potential for material injury to watch producers located in the U.S. and the Virgin Islands . "\r',
#   'entities': [[25, 29, 'PERSON'], [223, 227, 'GPE'], [236, 250, 'GPE']]},
#  {'sentence': 'Timex is a major U.S. producer and seller of watches , including low-priced battery-operated watches assembled in the Philippines and other developing nations covered by the U.S. tariff preferences .\r',
#   'entities': [[0, 5, 'ORG'],
#    [17, 21, 'GPE'],
#    [118, 129, 'GPE'],
#    [174, 178, 'GPE']]},
#  {'sentence': "U.S. trade officials said the Philippines and Thailand would be the main beneficiaries of the president 's action .\r",
#   'entities': [[0, 4, 'GPE'], [30, 41, 'GPE'], [46, 54, 'GPE']]},
#  {'sentence': 'Imports of the types of watches that now will be eligible for duty-free treatment totaled about $ 37.3 million in 1988 , a relatively small share of the $ 1.5 billion in U.S. watch imports that year , according to an aide to U.S. Trade Representative Carla Hills .\r',
#   'entities': [[96, 110, 'MONEY'],
#    [114, 118, 'DATE'],
#    [153, 166, 'MONEY'],
#    [170, 174, 'GPE'],
#    [225, 229, 'GPE'],
#    [251, 262, 'PERSON']]},
#  {'sentence': 'Although known to Arab and Malay sailors as early as the 10th century , Mauritius was first explored by the Portuguese in the 16th century and subsequently settled by the Dutch - who named it in honor of Prince Maurits van NASSAU - in the 17th century .\r',
#   'entities': [[18, 22, 'NORP'],
#    [27, 32, 'NORP'],
#    [57, 69, 'DATE'],
#    [72, 81, 'GPE'],
#    [108, 118, 'NORP'],
#    [126, 138, 'DATE'],
#    [171, 176, 'NORP'],
#    [211, 229, 'PERSON'],
#    [239, 251, 'DATE']]},
#  {'sentence': 'The French assumed control in 1715 , developing the island into an important naval base overseeing Indian Ocean trade , and establishing a plantation economy of sugar cane .\r',
#   'entities': [[4, 10, 'NORP'], [30, 34, 'DATE'], [99, 111, 'LOC']]},
#  {'sentence': 'The British captured the island in 1810 , during the Napoleonic Wars .\r',
#   'entities': [[4, 11, 'NORP'], [35, 39, 'DATE']]},
#  {'sentence': 'Mauritius remained a strategically important British naval base , and later an air station , playing an important role during World War II for anti-submarine and convoy operations , as well as the collection of signals intelligence .\r',
#   'entities': [[0, 9, 'GPE'], [45, 52, 'NORP']]},
#  {'sentence': 'Independence from the UK was attained in 1968 .\r',
#   'entities': [[22, 24, 'GPE'], [41, 45, 'DATE']]},
#  {'sentence': "A stable democracy with regular free elections and a positive human rights record , the country has attracted considerable foreign investment and has earned one of Africa 's highest per capita incomes .\r",
#   'entities': [[164, 170, 'GPE']]},
#  {'sentence': 'Recent poor weather , declining sugar prices , and declining textile and apparel production , have slowed economic growth , leading to some protests over standards of living in the Creole community .\r',
#   'entities': [[181, 187, 'NORP']]},
#  {'sentence': "Morocco 's market economy benefits from the country 's relatively low labor costs and proximity to Europe , which aid key areas of the economy such as agriculture , light manufacturing , tourism , and remittances .\r",
#   'entities': [[0, 7, 'GPE'], [99, 105, 'GPE']]},
#  {'sentence': "Morocco is also the world 's largest exporter of phosphate , which has long provided a source of export earnings and economic stability .\r",
#   'entities': [[0, 7, 'GPE']]},
#  {'sentence': 'Economic policies pursued since 2003 by King MOHAMMED VI have brought macroeconomic stability to the country with generally low inflation , improved financial performance , and steady progress in developing the service and industrial sectors .\r',
#   'entities': [[32, 36, 'DATE'], [45, 56, 'PERSON']]},
#  {'sentence': 'In 2006 , Morocco entered a Free Trade Agreement ( FTA ) with the US , and in 2008 entered into an advanced status in its 2000 Association Agreement with the EU .\r',
#   'entities': [[3, 7, 'DATE'],
#    [10, 17, 'GPE'],
#    [66, 68, 'GPE'],
#    [78, 82, 'DATE'],
#    [122, 126, 'DATE'],
#    [158, 160, 'ORG']]},
#  {'sentence': 'However , poverty , illiteracy , and unemployment rates remain high .\r',
#   'entities': []},
#  {'sentence': 'In response to these challenges , King MOHAMMED in 2005 launched a National Initiative for Human Development , a $ 2 billion program aimed at alleviating poverty and underdevelopment by expanding electricity to rural areas and replacing urban slums with public and subsidized housing , among other policies .\r',
#   'entities': [[39, 47, 'PERSON'], [51, 55, 'DATE'], [113, 124, 'MONEY']]},
#  {'sentence': "Morocco 's trade and budget deficits widened in 2010 , and reducing government spending and adapting to sluggish economic growth in Europe will be challenges in 2011 .\r",
#   'entities': [[0, 7, 'GPE'],
#    [48, 52, 'DATE'],
#    [132, 138, 'GPE'],
#    [161, 165, 'DATE']]},
#  {'sentence': "Morocco 's long-term challenges include improving education and job prospects for young Moroccans , closing the disparity in wealth between the rich and the poor , confronting corruption , and expanding and diversifying exports beyond phosphates and low-value-added products .\r",
#   'entities': [[0, 7, 'GPE'], [88, 97, 'NORP']]},
#  {'sentence': 'Albania , a formerly closed , centrally-planned state , is making the difficult transition to a more modern open-market economy .\r',
#   'entities': [[0, 7, 'GPE']]},
#  {'sentence': 'Macroeconomic growth averaged around 6 % between 2004 - 8 , but declined to about 3 % in 2009 - 10 .\r',
#   'entities': [[49, 57, 'DATE'], [89, 98, 'DATE']]},
#  {'sentence': 'Inflation is low and stable .\r', 'entities': []},
#  {'sentence': 'The government has taken measures to curb violent crime , and recently adopted a fiscal reform package aimed at reducing the large gray economy and attracting foreign investment .\r',
#   'entities': []},
#  {'sentence': 'Remittances , a significant catalyst for economic growth have declined from Dec-15 % of GDP to 9 % of GDP in 2009 , mostly from Albanians residing in Greece and Italy ; this helps offset the towering trade deficit .\r',
#   'entities': [[76, 79, 'DATE'],
#    [109, 113, 'DATE'],
#    [128, 137, 'NORP'],
#    [150, 156, 'GPE'],
#    [161, 166, 'GPE']]},
#  {'sentence': 'The agricultural sector , which accounts for almost half of employment but only about one-fifth of GDP , is limited primarily to small family operations and subsistence farming because of lack of modern equipment , unclear property rights , and the prevalence of small , inefficient plots of land .\r',
#   'entities': []},
#  {'sentence': "Energy shortages because of a reliance on hydropower , and antiquated and inadequate infrastructure contribute to Albania 's poor business environment and lack of success in attracting new foreign investment needed to expand the country 's export base .\r",
#   'entities': [[114, 121, 'GPE']]},
#  {'sentence': 'The completion of a new thermal power plant near Vlore has helped diversify generation capacity , and plans to upgrade transmission lines between Albania and Montenegro and Kosovo would help relieve the energy shortages .\r',
#   'entities': [[49, 54, 'GPE'],
#    [146, 153, 'GPE'],
#    [158, 168, 'GPE'],
#    [173, 179, 'GPE']]},
#  {'sentence': 'Also , with help from EU funds , the government is taking steps to improve the poor national road and rail network , a long-standing barrier to sustained economic growth .\r',
#   'entities': [[22, 24, 'ORG']]},
#  {'sentence': 'Economic activity consists primarily of subsistence farming and fishing .\r',
#   'entities': []},
#  {'sentence': 'The islands have few mineral deposits worth exploiting , except for high-grade phosphate .\r',
#   'entities': []},
#  {'sentence': 'The potential for a tourist industry exists , but the remote location , a lack of adequate facilities , and limited air connections hinder development .\r',
#   'entities': []},
#  {'sentence': 'Under the original terms of the Compact of Free Association , the US provided $ 1.3 billion in grant aid during the period 1986 - 2001 ; the level of aid has been subsequently reduced .\r',
#   'entities': [[66, 68, 'GPE'], [78, 91, 'MONEY'], [123, 134, 'DATE']]},
#  {'sentence': 'The Amended Compact of Free Association with the US guarantees the Federated States of Micronesia ( FSM ) millions of dollars in annual aid through 2023 , and establishes a Trust Fund into which the US and the FSM make annual contributions in order to provide annual payouts to the FSM in perpetuity after 2023 .\r',
#   'entities': [[49, 51, 'GPE'],
#    [67, 105, 'GPE'],
#    [106, 125, 'MONEY'],
#    [148, 152, 'DATE'],
#    [199, 201, 'GPE'],
#    [210, 213, 'GPE'],
#    [282, 285, 'GPE'],
#    [306, 310, 'DATE']]},
#  {'sentence': "The country 's medium-term economic outlook appears fragile due not only to the reduction in US assistance but also to the current slow growth of the private sector .\r",
#   'entities': [[93, 95, 'GPE']]},
#  {'sentence': 'The discovery and exploitation of large oil and gas reserves have contributed to dramatic economic growth but fluctuating oil prices have produced huge swings in GDP growth in recent years .\r',
#   'entities': [[176, 188, 'DATE']]},
#  {'sentence': 'Forestry and farming are also minor components of GDP .\r',
#   'entities': []},
#  {'sentence': 'Subsistence farming is the dominate form of livelihood .\r',
#   'entities': []},
#  {'sentence': 'Although pre-independence Equatorial Guinea counted on cocoa production for hard currency earnings , the neglect of the rural economy under successive regimes has diminished potential for agriculture-led growth ( the government has stated its intention to reinvest some oil revenue into agriculture ) .\r',
#   'entities': [[26, 43, 'GPE']]},
#  {'sentence': 'A number of aid programs sponsored by the World Bank and the IMF have been cut off since 1993 because of corruption and mismanagement .\r',
#   'entities': [[42, 52, 'ORG'], [61, 64, 'ORG'], [89, 93, 'DATE']]},
#  {'sentence': "The government has been widely criticized for its lack of transparency and misuse of oil revenues ; however , in 2010 , under Equatorial Guinea 's candidacy in the Extractive Industries Transparency Initiative , the government published oil revenue figures for the first time .\r",
#   'entities': [[113, 117, 'DATE'], [126, 143, 'GPE']]},
#  {'sentence': 'Undeveloped natural resources include gold , zinc , diamonds , columbite-tantalite , and other base metals .\r',
#   'entities': []},
#  {'sentence': 'Growth remained strong in 2008 , when oil production peaked , but slowed in 2009 - 10 , as the price of oil and the production level fell .\r',
#   'entities': [[26, 30, 'DATE'], [76, 85, 'DATE']]},
#  {'sentence': 'A BOSS who had gone to Canada was taunted by a Citizen of Montreal with having fled to avoid prosecution .\r',
#   'entities': [[23, 29, 'GPE'], [58, 66, 'GPE']]},
#  {'sentence': '" You do me a grave injustice , " said the Boss , parting with a pair of tears .\r',
#   'entities': []},
#  {'sentence': '" I came to Canada solely because of its political attractions ; its Government is the most corrupt in the world . "\r',
#   'entities': [[12, 18, 'GPE']]},
#  {'sentence': '" Pray forgive me , " said the Citizen of Montreal .\r',
#   'entities': [[42, 50, 'GPE']]},
#  {'sentence': "They fell upon each other 's neck , and at the conclusion of that touching rite the Boss had two watches .\r",
#   'entities': []},
#  {'sentence': 'There are less than three months until the election , an election that will decide the next President of the United States .\r',
#   'entities': [[20, 32, 'DATE'], [109, 122, 'GPE']]},
#  {'sentence': 'The man elected will be the president of all Americans , not just the Democrats or the Republicans .\r',
#   'entities': [[45, 54, 'NORP'], [70, 79, 'NORP'], [87, 98, 'NORP']]},
#  {'sentence': "To show our solidarity as Americans , let 's all get together and show each other our support for the candidate of our choice .\r",
#   'entities': [[26, 35, 'NORP']]},
#  {'sentence': "It 's time that we all came together , Democrats and Republicans alike .\r",
#   'entities': [[39, 48, 'NORP'], [53, 64, 'NORP']]},
#  {'sentence': 'If you support the policies and character of President George W. Bush , please drive with your headlights on during the day .\r',
# ...
#  {'sentence': 'I only had two imaginary friends ...\r', 'entities': []},
#  {'sentence': 'And they would only play with each other .\r', 'entities': []},
#  {'sentence': 'The Russian and European space agencies have announced a deal to build a manned spacecraft for near-earth orbits and trips to the moon .\r',
#   'entities': [[4, 11, 'NORP'], [16, 24, 'NORP']]},
#  {'sentence': 'Russian news agency reports quote a spokesman for the Russian agency Roskosmos as saying engineers want to test a 20-ton capsule by 2015 .\r',
#   'entities': [[0, 7, 'NORP'],
#    [54, 61, 'NORP'],
#    [69, 78, 'ORG'],
#    [132, 136, 'DATE']]},
#  {'sentence': 'A first launch is planned for 2018 at a launch center in Siberia .\r',
#   'entities': [[30, 34, 'DATE'], [57, 64, 'GPE']]},
#  {'sentence': 'Under the pact , Russia will build the capsule , while European engineers build the service module and the engine block .\r',
#   'entities': [[17, 23, 'GPE'], [55, 63, 'NORP']]},
#  {'sentence': "The new craft is to be phased in as the replacement for Russia 's Soyuz spacecraft , which has come under increased scrutiny this year , after two consecutive rough landings on return from the International Space Station .\r",
#   'entities': [[56, 62, 'GPE'], [125, 134, 'DATE'], [193, 220, 'ORG']]},
#  {'sentence': 'A human-rights group in Niger says the government is to blame for cancellation of a ceremony that was to grant 7,000 slaves their freedom .\r',
#   'entities': [[24, 29, 'GPE']]},
#  {'sentence': "The group Timidria had planned to release the slaves in the Ates region near Niger 's western border with Mali on Saturday , but the event was called off when none of the slaves showed up .\r",
#   'entities': [[10, 18, 'ORG'],
#    [77, 82, 'GPE'],
#    [106, 110, 'GPE'],
#    [114, 122, 'DATE']]},
#  {'sentence': 'The rights group says the government intimidated slaves to keep them from attending the ceremony - a charge the government denies .\r',
#   'entities': []},
#  {'sentence': 'Niger officially banned slavery in 2003 , but human-rights groups say 43,000 people are still in bondage in the West African nation .\r',
#   'entities': [[0, 5, 'GPE'], [35, 39, 'DATE'], [112, 124, 'NORP']]},
#  {'sentence': 'They are among the 2,00,000 people enslaved along centuries-old Arab-African Saharan trade routes .\r',
#   'entities': [[64, 68, 'NORP'], [69, 76, 'NORP']]},
#  {'sentence': 'Generations of Africans have been born in slavery , many under the ownership of one family .\r',
#   'entities': [[15, 23, 'NORP']]},
#  {'sentence': 'Embattled Ivory Coast President Laurent Gbagbo has said he wants to talk with his rival , Alassane Ouattara .\r',
#   'entities': [[10, 21, 'GPE'], [32, 46, 'PERSON'], [90, 107, 'PERSON']]},
#  {'sentence': "Mr. Gbagbo has been isolated by the international community , including the United States , after refusing to yield the presidency although he had fewer votes than Mr. Ouattara in last month 's poll .\r",
#   'entities': [[4, 10, 'PERSON'],
#    [76, 89, 'GPE'],
#    [168, 176, 'PERSON'],
#    [180, 190, 'DATE']]},
#  {'sentence': 'Both men have taken the oath of office and begun organizing competing governments .\r',
#   'entities': []},
#  {'sentence': 'Earlier this week , the African Union dispatched former South African president Thabo Mbeki to seek a solution , but after two days of talks , the situation was not resolved .\r',
#   'entities': [[0, 17, 'DATE'],
#    [24, 37, 'NORP'],
#    [56, 69, 'NORP'],
#    [80, 91, 'PERSON'],
#    [123, 131, 'DATE']]},
#  {'sentence': "The Ivory Coast 's presidential election , its first in 10 years , was meant to restore stability to the West African country , which was split into rebel- and government-controlled areas during a 2002 civil war .\r",
#   'entities': [[4, 15, 'GPE'],
#    [56, 64, 'DATE'],
#    [105, 117, 'NORP'],
#    [197, 201, 'DATE']]},
#  {'sentence': 'Officials in Afghanistan say a suicide bomber has killed four Afghan employees of a U.S.-owned private security firm and wounded one other in southern Kandahar province .\r',
#   'entities': [[13, 24, 'GPE'],
#    [62, 68, 'NORP'],
#    [84, 88, 'GPE'],
#    [142, 159, 'LOC']]},
#  {'sentence': 'Authorities said Sunday the bomber rode a motorbike next to a vehicle owned by the company , U.S. Protection and Investigations , and detonated his explosives .\r',
#   'entities': [[17, 23, 'DATE'], [93, 97, 'GPE']]},
#  {'sentence': "Three guards and the vehicle 's driver were killed , and another guard was wounded .\r",
#   'entities': []},
#  {'sentence': "On Saturday , a suicide bomber killed seven police officers and a civilian in eastern Afghanistan 's Khost province , near the Pakistan border .\r",
#   'entities': [[3, 11, 'DATE'],
#    [78, 97, 'NORP'],
#    [101, 106, 'GPE'],
#    [127, 135, 'GPE']]},
#  {'sentence': 'The Taleban is reported to have taken responsibility for the blast .\r',
#   'entities': [[4, 11, 'ORG']]},
#  {'sentence': 'NATO forces in Afghanistan are preparing for another upsurge in violence this year , having already launched an operation in the south to preempt an anticipated offensive by Taleban fighters .\r',
#   'entities': [[0, 4, 'ORG'],
#    [15, 26, 'GPE'],
#    [73, 82, 'DATE'],
#    [174, 181, 'ORG']]},
#  {'sentence': "Turkish police have detained more than 80 people and used tear gas to prevent thousands of leftist protesters from marching to Istanbul 's Taksim square to hold a May Day rally .\r",
#   'entities': [[0, 7, 'NORP'],
#    [91, 98, 'NORP'],
#    [127, 135, 'GPE'],
#    [139, 152, 'GPE'],
#    [163, 170, 'DATE']]},
#  {'sentence': 'Authorities declared the square off-limits to protesters , but allowed a small number of trade union leaders to lay flowers at the square to mark the day .\r',
#   'entities': [[89, 100, 'ORG'], [146, 153, 'DATE']]},
#  {'sentence': 'Officials had shut down schools in the area for the day for fear of violence .\r',
#   'entities': [[44, 55, 'DATE']]},
#  {'sentence': 'Members of leftist groups often clash with police during May Day observances in Turkey .\r',
#   'entities': [[11, 18, 'NORP'], [57, 64, 'DATE'], [80, 86, 'GPE']]},
#  {'sentence': 'In 1977 , a May Day rally at Taksim square turned violent when unidentified gunmen opened fire on a crowd of demonstrators .\r',
#   'entities': [[3, 7, 'DATE'], [12, 19, 'DATE'], [29, 42, 'GPE']]},
#  {'sentence': 'Thirty-seven people were killed in that incident .\r',
#   'entities': []},
#  {'sentence': "The race for Iraq 's new prime minister narrowed Tuesday , when one of two top Shi'ite parties withdrew its candidate from consideration .\r",
#   'entities': [[13, 17, 'GPE'], [49, 56, 'DATE'], [79, 86, 'NORP']]},
#  {'sentence': 'Interim Finance Minister Adel Abdul-Mahdi , who had been the candidate of the Supreme Council for the Islamic Revolution in Iraq , withdrew his name from contention .\r',
#   'entities': [[25, 41, 'PERSON'], [102, 109, 'NORP'], [124, 128, 'GPE']]},
#  {'sentence': 'This leaves the head of the Islamic Dawa Party , Ibrahim al-Jaafari , as the likely front-runner .\r',
#   'entities': [[28, 46, 'ORG'], [49, 67, 'PERSON']]},
#  {'sentence': 'Both parties belong to the United Iraqi Alliance , which won about 48 percent of the vote for the National Assembly .\r',
#   'entities': [[27, 48, 'ORG']]},
#  {'sentence': "Meanwhile , Iraq 's Electoral Commission says it has received at least three complaints from political groups challenging the election results .\r",
#   'entities': [[12, 16, 'GPE']]},
#  {'sentence': 'A final , certified vote tally is expected Wednesday .\r',
#   'entities': [[43, 53, 'DATE']]},
#  {'sentence': 'And Turkish shipping magnate Kahraman Sadikoglu , who was abducted in southern Iraq in December , has been freed after reports said his family paid a ransom to his kidnappers .\r',
#   'entities': [[4, 11, 'NORP'],
#    [29, 47, 'PERSON'],
#    [79, 83, 'GPE'],
#    [87, 95, 'DATE']]},
#  {'sentence': 'A Council of Europe panel says Turkey has passed important legislation protecting minority rights , but has not adequately enforced the new laws .\r',
#   'entities': [[2, 19, 'ORG'], [31, 37, 'GPE']]},
#  {'sentence': "In a report , the European Commission against Racism and Intolerance says that despite the new legislation , Turkey 's constitution and its civil , criminal and administrative laws continue to have gaps in addressing racism .\r",
#   'entities': [[18, 26, 'NORP'], [109, 115, 'GPE']]},
#  {'sentence': 'The report , issued Tuesday in Strasbourg , says Kurds and other minorities still face adversity in Turkey , particularly from ongoing violence in the southeast where Kurdish separatists have been active in recent decades .\r',
#   'entities': [[20, 27, 'DATE'],
#    [31, 41, 'GPE'],
#    [49, 54, 'NORP'],
#    [100, 106, 'GPE'],
#    [167, 174, 'NORP'],
#    [207, 221, 'DATE']]},
#  {'sentence': "Turkey 's move to push through legal and economic reforms is considered an essential part of its bid to join the European Union .\r",
#   'entities': [[0, 6, 'GPE'], [113, 127, 'ORG']]},
#  {'sentence': 'The Council of Europe is a 46-nation group that brings together lawmakers from democratic European countries to review major issues facing the continent .\r',
#   'entities': [[4, 21, 'ORG'], [90, 98, 'NORP']]},
#  {'sentence': "Armenia has launched an aerial tramway line that it says is the world 's longest .\r",
#   'entities': [[0, 7, 'GPE']]},
#  {'sentence': "President Serzh Sarkisian attended the opening of the tramway Saturday , in the country 's southern mountains near Armenia 's border with Iran .\r",
#   'entities': [[10, 25, 'PERSON'],
#    [62, 70, 'DATE'],
#    [115, 122, 'GPE'],
#    [138, 142, 'GPE']]},
#  {'sentence': 'The 5.7-kilometer engineering feat spans the Vorotan River gorge , linking a village off the main highway to the 9th century Tatev Monastery .\r',
#   'entities': [[45, 58, 'LOC'], [113, 124, 'DATE']]},
#  {'sentence': "The monastery is one of the country 's oldest and most prominent monasteries and is a major tourist attraction .\r",
#   'entities': []},
#  {'sentence': "The head of Cuba 's parliament has offered to support Iran in its fight to develop nuclear energy within Iranian borders .\r",
#   'entities': [[12, 16, 'GPE'], [54, 58, 'GPE'], [105, 112, 'NORP']]},
#  {'sentence': "Ricardo Alarcon voiced solidarity Thursday in a meeting with the visiting speaker of Iran 's parliament , Gholam Ali Haddad Adel .\r",
#   'entities': [[0, 15, 'PERSON'],
#    [34, 42, 'DATE'],
#    [85, 89, 'GPE'],
#    [106, 128, 'PERSON']]},
#  {'sentence': 'Iran resumed enrichment of uranium for nuclear fuel earlier this week , despite international pressure against the move .\r',
#   'entities': [[0, 4, 'GPE'], [52, 69, 'DATE']]},
#  {'sentence': 'Haddad Adel is on a two-day visit to Cuba after spending Wednesday in Venezuela , where he thanked the government for its support on nuclear issues .\r',
#   'entities': [[0, 11, 'PERSON'],
#    [20, 27, 'DATE'],
#    [37, 41, 'GPE'],
#    [57, 66, 'DATE'],
#    [70, 79, 'GPE']]},
#  {'sentence': 'Meanwhile , Indiana Representative Dan Burton , in an interview with Voice of America Thursday , expressed concern over the close ties between Iran and the two countries .\r',
#   'entities': [[12, 19, 'GPE'],
#    [35, 45, 'PERSON'],
#    [69, 85, 'ORG'],
#    [86, 94, 'DATE'],
#    [143, 147, 'GPE']]},
#  {'sentence': 'He said if it appears that there is coordination between terrorist states and leftist organizations in Central America , the United States will intervene .\r',
#   'entities': [[103, 118, 'LOC'], [125, 138, 'GPE']]},
#  {'sentence': 'Representative Burton said such a relationship would endanger the United States and other countries in the hemisphere .\r',
#   'entities': [[15, 21, 'PERSON'], [66, 79, 'GPE']]},
#  {'sentence': 'European Union foreign ministers hold emergency talks in Luxembourg Sunday in efforts to break a deadlock on Turkey , which is scheduled to begin membership negotiations with the bloc one day later .\r',
#   'entities': [[0, 14, 'ORG'],
#    [57, 67, 'GPE'],
#    [68, 74, 'DATE'],
#    [109, 115, 'GPE'],
#    [184, 197, 'DATE']]},
#  {'sentence': 'The ministers called the meeting after Austria insisted that EU talks with Turkey should include an alternative to giving the country full membership .\r',
#   'entities': [[39, 46, 'GPE'], [61, 63, 'ORG'], [75, 81, 'GPE']]},
#  {'sentence': 'Austria says most Austrians object to full EU membership for Turkey and suggested offering Turkey privileged partnership instead .\r',
#   'entities': [[0, 7, 'GPE'],
#    [18, 27, 'NORP'],
#    [43, 45, 'ORG'],
#    [61, 67, 'GPE'],
#    [91, 97, 'GPE']]},
#  {'sentence': "But Turkey calls that unacceptable and says it will not take part in Monday 's talks unless it is clear that the goal is full membership .\r",
#   'entities': [[4, 10, 'GPE'], [69, 75, 'DATE']]},
#  {'sentence': 'EU diplomats are working on proposals to soften Austrian opposition .\r',
#   'entities': [[0, 2, 'ORG'], [48, 56, 'NORP']]},
#  {'sentence': "One would be a commitment to begin membership talks with Austria 's neighbor Croatia in the near future .\r",
#   'entities': [[57, 64, 'GPE'], [77, 84, 'GPE'], [92, 103, 'DATE']]},
#  {'sentence': 'EU ministers had delayed the talks because of Croatian failure to cooperate fully with The Hague war crimes tribunal .\r',
#   'entities': [[0, 2, 'ORG'], [46, 54, 'NORP'], [91, 96, 'GPE']]},
#  {'sentence': 'Pakistani military authorities say they have arrested a key Taliban commander who is accused of slaughtering military personnel .\r',
#   'entities': [[0, 9, 'NORP'], [60, 67, 'ORG']]},
#  {'sentence': 'Security forces said Wednesday they captured Taliban commander Sher Mohammad Qasab in the Swat Valley .\r',
#   'entities': [[21, 30, 'DATE'],
#    [45, 52, 'ORG'],
#    [63, 82, 'PERSON'],
#    [90, 101, 'LOC']]},
#  {'sentence': 'Qasab is known for his brutality among locals in the valley .\r',
#   'entities': [[0, 5, 'PERSON']]},
#  {'sentence': 'A military spokesman said Qasab was wounded and three of his sons died during an exchange of fire before his arrest .\r',
#   'entities': [[26, 31, 'PERSON']]},
#  {'sentence': 'Pakistani forces have arrested key Taliban commanders recently in the valley , including Muslim Khan , the central spokesman for the militants .\r',
#   'entities': [[0, 9, 'NORP'], [35, 42, 'ORG'], [89, 100, 'PERSON']]},
#  {'sentence': 'Authorities say the arrests have weakened the Taliban and are helping security forces conduct successful raids against other militants in the area .\r',
#   'entities': [[46, 53, 'ORG']]},
#  {'sentence': 'The top U.S. diplomat says China should make significant economic reforms so it does not continue to be a " problem for the international economy . "\r',
#   'entities': [[8, 12, 'GPE'], [27, 32, 'GPE']]},
#  {'sentence': "In a New York Times newspaper interview , published Friday , Secretary of State Condoleezza Rice says Washington also worries about China 's military buildup , human rights practices and religious restrictions .\r",
#   'entities': [[5, 19, 'ORG'],
#    [52, 58, 'DATE'],
#    [80, 96, 'PERSON'],
#    [102, 112, 'GPE'],
#    [132, 137, 'GPE']]},
#  {'sentence': 'It is a change of tone for Ms. Rice , who generally casts Sino-American relations in a positive light .\r',
#   'entities': [[31, 35, 'PERSON'], [58, 71, 'NORP']]},
#  {'sentence': 'Her comments come just a month before Chinese President Hu Jintao makes his first visit to Washington since taking office in 2003 .\r',
#   'entities': [[18, 30, 'DATE'],
#    [38, 45, 'NORP'],
#    [56, 65, 'PERSON'],
#    [91, 101, 'GPE'],
#    [125, 129, 'DATE']]},
#  {'sentence': "He will arrive amid Washington 's complaints that China manipulates the value of its currency to make its products unfairly cheap on world markets .\r",
#   'entities': [[20, 30, 'GPE'], [50, 55, 'GPE']]},
#  {'sentence': 'Beijing recently changed the value of its currency slightly , but U.S. critics say the change is not large enough to make trade fair .\r',
#   'entities': [[0, 7, 'GPE'], [66, 70, 'GPE']]},
#  {'sentence': "Chad 's national assembly has authorized President Idriss Deby to renew a state of emergency imposed after a rebel attack on the capital , N'Djamena , early this month .",
#   'entities': [[0, 4, 'GPE'],
#    [51, 62, 'PERSON'],
#    [139, 148, 'GPE'],
#    [151, 167, 'DATE']]}]

# %% [markdown]
# function to get start and end indexes of each named entity

# %%
def retrieve_entity_positions(sentence, entity_text):
    """Find the start and end positions of the entity in the sentence."""
    start = sentence.find(entity_text)
    if start == -1:  # If the entity is not found, then return None
        return None
    end = start + len(entity_text)
    return start, end

# %% [markdown]
# Since, JSON output is having start & end indices instead of named entity, we need to convert the spaCy output from named entity to index positions, so that both of them will have same format inorder for Fair comparison

# %%
def format_conversion_from_spacy_to_manual(spacy_NER):
    """Convert spaCy format (word, tag) to manual format (start, end, tag)."""
    annotations_after_conversion = []

    for entry in spacy_NER:
        sentence = entry['sentence']
        entities = []

        for entity_text, entity_tag in entry['entities']:
            positions = retrieve_entity_positions(sentence, entity_text) #get each entity start & end index positions just like manual JSON output
            if positions:
                start, end = positions
                entities.append([start, end, entity_tag])

        annotations_after_conversion.append({'sentence': sentence, 'entities': entities})

    return annotations_after_conversion

# %% [markdown]
# function to calculate model metrics like TP, FP, FN, Precision, Recall & F1-Score

# %%
def calculate_metrics(manual_NER, spacy_NER):
    tp, fp, fn = 0, 0, 0
    tp_tweet, fn_tweet, fp_tweet = 0, 0, 0
    temp_counter = 0
    
    for manual, spacy in zip(manual_NER, spacy_NER):
        # Convert manual annotations into a set of tuples (start, end, label)
        set_manual_entities = set([tuple(entity) for entity in manual['entities']])

        # Convert spaCy annotations into a set of tuples (start, end, label)
        set_spacy_entities = set([tuple(entity) for entity in spacy['entities']])

        
        # True Positives
        tp_tweet = len(set_manual_entities & set_spacy_entities)
        tp = tp + tp_tweet
        # False Positives
        fp_tweet = len(set_spacy_entities - set_manual_entities)
        fp = fp + fp_tweet
        # False Negatives
        fn_tweet = len(set_manual_entities - set_spacy_entities)
        fn = fn + fn_tweet
        temp_counter += 1

        precision_tweet = tp_tweet / (tp_tweet + fp_tweet) if (tp_tweet + fp_tweet) > 0 else 0
        recall_tweet = tp_tweet / (tp_tweet + fn_tweet) if (tp_tweet + fn_tweet) > 0 else 0
        f1_tweet = 2 * (precision_tweet * recall_tweet)/ (precision_tweet + recall_tweet) if (precision_tweet + recall_tweet)> 0 else 0
        
        print("--------------------------------------------------------------------------------------------------------------------")
        print(f"tweet: {temp_counter}")
        print(set_manual_entities)
        print(set_spacy_entities)
        print("---------------------------")
        print(f"TP: {tp_tweet} | FP: {fp_tweet} | FN: {fn_tweet}")
        print("---------------------------")
        print(f"Precision of tweet: {precision_tweet}")
        print(f"Recall of tweet: {recall_tweet}")
        print(f"f1-score of tweet: {f1_tweet}")

    return tp, fp, fn

# %% [markdown]
# Displaying Overall model metrics

# %%
# Convert spaCy format to manual format
spacy_after_conversion = format_conversion_from_spacy_to_manual(spacy_output)

# Now calculate TP, FP, FN using the converted spaCy annotations
tp, fp, fn = calculate_metrics(Manual_NER_list, spacy_after_conversion)

precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1 = 2 * (precision * recall)/ (precision + recall) if (precision + recall)> 0 else 0
# Out:
# --------------------------------------------------------------------------------------------------------------------
# tweet: 1
# {(154, 161, 'GPE'), (0, 2, 'ORG'), (125, 127, 'ORG'), (24, 43, 'PERSON'), (98, 105, 'NORP')}
# {(154, 161, 'GPE'), (0, 2, 'ORG'), (0, 13, 'ORG'), (24, 43, 'PERSON'), (98, 105, 'NORP')}
# ---------------------------
# TP: 4 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.8
# Recall of tweet: 0.8
# f1-score of tweet: 0.8000000000000002
# --------------------------------------------------------------------------------------------------------------------
# tweet: 2
# {(126, 128, 'ORG'), (15, 32, 'PERSON'), (99, 105, 'DATE'), (58, 63, 'PERSON')}
# {(126, 128, 'ORG'), (15, 32, 'PERSON'), (99, 105, 'DATE'), (58, 63, 'PERSON')}
# ---------------------------
# TP: 4 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 3
# {(18, 20, 'ORG'), (100, 107, 'GPE'), (176, 184, 'GPE'), (112, 118, 'GPE'), (51, 57, 'GPE')}
# {(18, 20, 'ORG'), (100, 107, 'GPE'), (176, 184, 'GPE'), (112, 118, 'GPE'), (51, 57, 'GPE')}
# ---------------------------
# TP: 5 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 4
# {(155, 161, 'NORP'), (181, 185, 'GPE'), (22, 35, 'PERSON'), (0, 11, 'NORP'), (127, 133, 'GPE')}
# {(155, 161, 'NORP'), (177, 191, 'GPE'), (22, 35, 'PERSON'), (0, 11, 'NORP'), (127, 133, 'GPE')}
# ---------------------------
# TP: 4 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.8
# Recall of tweet: 0.8
# f1-score of tweet: 0.8000000000000002
# --------------------------------------------------------------------------------------------------------------------
# tweet: 5
# {(55, 75, 'PERSON'), (4, 9, 'PERSON'), (90, 95, 'ORG')}
# {(55, 75, 'PERSON'), (4, 9, 'PERSON'), (90, 95, 'ORG')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 6
# {(118, 127, 'DATE'), (131, 135, 'GPE'), (72, 79, 'NORP'), (102, 113, 'NORP'), (43, 48, 'ORG')}
# {(118, 127, 'DATE'), (131, 135, 'GPE'), (72, 79, 'NORP'), (102, 113, 'NORP'), (43, 48, 'ORG')}
# ---------------------------
# TP: 5 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 7
# {(23, 30, 'NORP'), (66, 74, 'DATE'), (35, 46, 'NORP')}
# {(23, 30, 'NORP'), (35, 46, 'NORP'), (61, 74, 'DATE')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 8
# {(53, 64, 'NORP'), (73, 82, 'GPE')}
# {(53, 64, 'NORP'), (73, 82, 'GPE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 9
# {(0, 11, 'NORP'), (59, 66, 'NORP')}
# {(0, 11, 'NORP'), (59, 66, 'NORP')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 10
# {(21, 30, 'GPE'), (0, 7, 'GPE'), (121, 130, 'NORP'), (10, 16, 'GPE'), (46, 54, 'NORP'), (81, 98, 'PERSON')}
# {(21, 30, 'GPE'), (0, 7, 'GPE'), (121, 130, 'NORP'), (10, 16, 'GPE'), (46, 54, 'NORP'), (81, 98, 'PERSON')}
# ---------------------------
# TP: 6 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 11
# {(30, 37, 'DATE'), (100, 107, 'GPE'), (40, 46, 'NORP'), (58, 75, 'PERSON'), (19, 29, 'PERSON')}
# {(30, 37, 'DATE'), (100, 107, 'GPE'), (40, 46, 'NORP'), (58, 75, 'PERSON'), (19, 29, 'PERSON')}
# ---------------------------
# TP: 5 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 12
# {(54, 64, 'PERSON'), (0, 10, 'NORP'), (21, 35, 'PERSON')}
# {(54, 64, 'PERSON'), (0, 10, 'NORP'), (21, 35, 'PERSON')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 13
# {(133, 140, 'GPE'), (52, 66, 'ORG'), (3, 8, 'GPE'), (37, 43, 'GPE')}
# {(133, 140, 'GPE'), (52, 66, 'ORG'), (3, 8, 'GPE'), (37, 43, 'GPE')}
# ---------------------------
# TP: 4 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 14
# {(115, 121, 'GPE'), (12, 18, 'GPE')}
# {(12, 18, 'GPE'), (66, 121, 'ORG')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.5
# f1-score of tweet: 0.5
# --------------------------------------------------------------------------------------------------------------------
# tweet: 15
# {(37, 42, 'DATE'), (105, 111, 'DATE')}
# {(32, 45, 'DATE'), (105, 111, 'DATE')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.5
# f1-score of tweet: 0.5
# --------------------------------------------------------------------------------------------------------------------
# tweet: 16
# {(18, 28, 'PERSON'), (0, 6, 'GPE')}
# {(18, 28, 'PERSON'), (0, 6, 'GPE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 17
# {(0, 4, 'GPE'), (104, 111, 'GPE'), (72, 81, 'GPE'), (120, 134, 'GPE')}
# {(104, 111, 'GPE'), (0, 4, 'GPE'), (72, 81, 'LOC'), (116, 134, 'GPE')}
# ---------------------------
# TP: 2 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.5
# f1-score of tweet: 0.5
# --------------------------------------------------------------------------------------------------------------------
# tweet: 18
# {(67, 78, 'DATE'), (123, 132, 'DATE'), (108, 122, 'GPE')}
# {(123, 132, 'DATE'), (67, 78, 'DATE'), (104, 122, 'LOC'), (0, 29, 'ORG')}
# ---------------------------
# TP: 2 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.5714285714285715
# --------------------------------------------------------------------------------------------------------------------
# tweet: 19
# {(21, 28, 'GPE'), (37, 51, 'GPE')}
# {(33, 51, 'GPE'), (84, 91, 'PERSON'), (21, 28, 'GPE')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.5
# f1-score of tweet: 0.4
# --------------------------------------------------------------------------------------------------------------------
# tweet: 20
# {(0, 14, 'DATE'), (56, 64, 'LOC')}
# {(0, 14, 'DATE'), (56, 64, 'LOC')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 21
# {(93, 111, 'GPE'), (33, 38, 'GPE')}
# {(33, 38, 'GPE'), (0, 29, 'ORG'), (89, 111, 'LOC'), (44, 49, 'PERSON')}
# ---------------------------
# TP: 1 | FP: 3 | FN: 1
# ---------------------------
# Precision of tweet: 0.25
# Recall of tweet: 0.5
# f1-score of tweet: 0.3333333333333333
# --------------------------------------------------------------------------------------------------------------------
# tweet: 22
# {(63, 71, 'DATE')}
# {(59, 71, 'DATE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 23
# {(0, 9, 'NORP')}
# {(0, 9, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 24
# {(118, 129, 'GPE')}
# {(118, 129, 'GPE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 25
# set()
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 26
# {(0, 9, 'NORP')}
# {(0, 9, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 27
# {(117, 150, 'NORP')}
# {(117, 150, 'ORG')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 28
# set()
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 29
# {(25, 37, 'PERSON'), (0, 9, 'NORP')}
# {(25, 37, 'PERSON'), (0, 9, 'NORP')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 30
# set()
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 31
# {(33, 43, 'PERSON'), (0, 14, 'ORG'), (148, 152, 'GPE'), (91, 95, 'ORG')}
# {(33, 43, 'PERSON'), (0, 14, 'ORG'), (148, 152, 'GPE'), (91, 95, 'ORG')}
# ---------------------------
# TP: 4 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 32
# {(30, 38, 'DATE'), (4, 9, 'PERSON'), (80, 84, 'ORG')}
# {(30, 38, 'DATE'), (4, 9, 'PERSON'), (80, 84, 'ORG')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 33
# {(34, 42, 'DATE'), (155, 169, 'ORG'), (99, 110, 'PERSON')}
# {(151, 169, 'ORG'), (34, 42, 'DATE'), (99, 110, 'PERSON')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 34
# {(89, 107, 'PERSON'), (53, 58, 'PERSON'), (0, 4, 'ORG')}
# {(89, 107, 'PERSON'), (53, 58, 'PERSON'), (0, 4, 'ORG')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 35
# {(9, 14, 'PERSON'), (39, 46, 'NORP'), (23, 34, 'PERSON')}
# {(9, 14, 'PERSON'), (39, 46, 'NORP'), (23, 34, 'PERSON')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 36
# {(12, 31, 'MONEY'), (148, 152, 'GPE')}
# {(12, 31, 'MONEY'), (148, 152, 'GPE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 37
# {(32, 43, 'GPE'), (96, 104, 'DATE')}
# {(32, 43, 'GPE'), (96, 104, 'DATE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 38
# {(32, 41, 'DATE')}
# {(27, 41, 'DATE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 39
# set()
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 40
# {(157, 169, 'DATE'), (23, 26, 'ORG')}
# {(157, 169, 'DATE'), (23, 26, 'ORG')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 41
# {(48, 60, 'GPE')}
# {(48, 59, 'GPE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 42
# {(67, 79, 'GPE')}
# {(67, 78, 'GPE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 43
# {(18, 28, 'GPE'), (83, 96, 'GPE'), (109, 115, 'DATE'), (172, 179, 'GPE')}
# {(83, 89, 'NORP'), (18, 28, 'GPE'), (109, 115, 'DATE'), (172, 179, 'GPE')}
# ---------------------------
# TP: 3 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.75
# Recall of tweet: 0.75
# f1-score of tweet: 0.75
# --------------------------------------------------------------------------------------------------------------------
# tweet: 44
# {(144, 154, 'GPE'), (159, 165, 'GPE'), (112, 118, 'DATE')}
# {(144, 154, 'GPE'), (0, 20, 'ORG'), (112, 118, 'DATE'), (159, 165, 'PERSON')}
# ---------------------------
# TP: 2 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.5714285714285715
# --------------------------------------------------------------------------------------------------------------------
# tweet: 45
# {(115, 122, 'GPE'), (126, 132, 'DATE')}
# {(115, 122, 'GPE'), (126, 132, 'DATE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 46
# {(4, 9, 'NORP'), (20, 33, 'PERSON')}
# {(4, 9, 'NORP'), (20, 33, 'PERSON')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 47
# {(27, 34, 'NORP')}
# {(27, 34, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 48
# {(34, 47, 'GPE')}
# {(30, 47, 'GPE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 49
# {(48, 55, 'GPE'), (26, 36, 'PERSON'), (0, 7, 'NORP')}
# {(48, 55, 'PERSON'), (26, 36, 'PERSON'), (0, 7, 'NORP')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 50
# {(0, 17, 'PERSON'), (83, 91, 'DATE'), (62, 68, 'NORP'), (116, 130, 'NORP'), (141, 148, 'DATE')}
# {(5, 17, 'PERSON'), (62, 67, 'NORP'), (141, 147, 'DATE'), (112, 140, 'ORG')}
# ---------------------------
# TP: 0 | FP: 4 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 51
# {(56, 64, 'DATE'), (72, 79, 'GPE')}
# {(56, 64, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.5
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 52
# {(0, 12, 'PERSON')}
# {(0, 12, 'PERSON')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 53
# set()
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 54
# {(34, 49, 'NORP')}
# {(22, 33, 'MONEY'), (34, 49, 'NORP')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 1.0
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 55
# {(4, 18, 'ORG'), (48, 54, 'GPE'), (55, 68, 'DATE'), (112, 119, 'GPE')}
# {(48, 54, 'GPE'), (0, 18, 'ORG'), (55, 68, 'DATE'), (112, 119, 'GPE')}
# ---------------------------
# TP: 3 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.75
# Recall of tweet: 0.75
# f1-score of tweet: 0.75
# --------------------------------------------------------------------------------------------------------------------
# tweet: 56
# {(0, 2, 'ORG'), (153, 155, 'NORP'), (65, 76, 'DATE'), (96, 104, 'NORP'), (186, 192, 'GPE'), (80, 90, 'GPE'), (127, 133, 'GPE')}
# {(0, 2, 'ORG'), (65, 76, 'DATE'), (96, 104, 'NORP'), (186, 192, 'GPE'), (80, 90, 'GPE'), (127, 133, 'GPE')}
# ---------------------------
# TP: 6 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.8571428571428571
# f1-score of tweet: 0.923076923076923
# --------------------------------------------------------------------------------------------------------------------
# tweet: 57
# {(0, 6, 'GPE')}
# {(0, 6, 'GPE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 58
# {(0, 7, 'GPE'), (48, 51, 'PERSON'), (162, 170, 'DATE')}
# {(48, 50, 'ORG'), (156, 170, 'DATE'), (0, 7, 'GPE')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.3333333333333333
# f1-score of tweet: 0.3333333333333333
# --------------------------------------------------------------------------------------------------------------------
# tweet: 59
# {(91, 101, 'GPE'), (80, 87, 'DATE')}
# {(91, 101, 'GPE'), (80, 87, 'DATE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 60
# {(33, 39, 'DATE')}
# {(33, 39, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 61
# {(14, 20, 'GPE'), (94, 108, 'NORP')}
# {(64, 70, 'NORP'), (90, 108, 'ORG'), (14, 20, 'GPE')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.5
# f1-score of tweet: 0.4
# --------------------------------------------------------------------------------------------------------------------
# tweet: 62
# {(50, 54, 'DATE')}
# {(50, 54, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 63
# {(0, 8, 'NORP'), (19, 32, 'PERSON')}
# {(0, 8, 'NORP'), (19, 32, 'PERSON')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 64
# {(97, 104, 'NORP'), (27, 34, 'DATE'), (111, 126, 'PERSON')}
# {(27, 34, 'DATE'), (111, 126, 'PERSON'), (97, 103, 'NORP')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 65
# {(170, 175, 'GPE'), (230, 234, 'DATE'), (39, 50, 'DATE')}
# {(170, 175, 'GPE'), (230, 234, 'DATE'), (39, 50, 'DATE')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 66
# {(101, 110, 'DATE'), (17, 25, 'DATE')}
# {(101, 110, 'DATE'), (17, 25, 'DATE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 67
# {(4, 11, 'PERSON')}
# {(4, 11, 'PERSON')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 68
# {(117, 128, 'GPE'), (165, 170, 'DATE'), (0, 5, 'GPE')}
# {(117, 128, 'GPE'), (165, 169, 'DATE'), (0, 5, 'GPE')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 69
# {(33, 48, 'PERSON'), (0, 5, 'GPE')}
# {(33, 48, 'PERSON'), (0, 5, 'GPE'), (15, 22, 'ORG')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 1.0
# f1-score of tweet: 0.8
# --------------------------------------------------------------------------------------------------------------------
# tweet: 70
# {(97, 108, 'GPE'), (112, 121, 'DATE'), (0, 8, 'NORP'), (87, 92, 'GPE'), (70, 79, 'GPE')}
# {(97, 108, 'GPE'), (112, 121, 'DATE'), (88, 92, 'GPE'), (0, 8, 'NORP'), (70, 79, 'GPE')}
# ---------------------------
# TP: 4 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.8
# Recall of tweet: 0.8
# f1-score of tweet: 0.8000000000000002
# --------------------------------------------------------------------------------------------------------------------
# tweet: 71
# {(46, 58, 'NORP')}
# {(46, 58, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 72
# {(51, 58, 'NORP')}
# {(51, 58, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 73
# {(73, 85, 'NORP')}
# {(73, 85, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 74
# {(79, 92, 'DATE'), (70, 74, 'GPE'), (28, 41, 'GPE')}
# {(24, 41, 'GPE'), (79, 92, 'DATE'), (70, 74, 'GPE')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 75
# {(28, 43, 'ORG'), (57, 61, 'GPE'), (3, 9, 'DATE'), (158, 162, 'GPE'), (86, 90, 'GPE')}
# {(24, 43, 'ORG'), (3, 9, 'DATE'), (158, 162, 'GPE'), (57, 61, 'GPE')}
# ---------------------------
# TP: 3 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.75
# Recall of tweet: 0.6
# f1-score of tweet: 0.6666666666666665
# --------------------------------------------------------------------------------------------------------------------
# tweet: 76
# {(18, 22, 'GPE')}
# {(18, 22, 'GPE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 77
# {(21, 27, 'DATE'), (3, 10, 'NORP'), (45, 58, 'GPE')}
# {(21, 27, 'DATE'), (41, 58, 'GPE'), (3, 10, 'NORP')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 78
# {(58, 65, 'GPE'), (19, 27, 'NORP')}
# {(19, 27, 'NORP'), (58, 64, 'GPE')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.5
# f1-score of tweet: 0.5
# --------------------------------------------------------------------------------------------------------------------
# tweet: 79
# {(0, 4, 'GPE')}
# {(0, 4, 'GPE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 80
# {(57, 61, 'GPE'), (4, 10, 'DATE'), (14, 20, 'GPE')}
# {(57, 61, 'GPE'), (4, 10, 'DATE'), (14, 20, 'GPE')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 81
# {(21, 29, 'NORP'), (86, 101, 'PERSON'), (0, 11, 'GPE')}
# {(21, 29, 'NORP'), (0, 11, 'GPE'), (91, 100, 'PERSON')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 82
# {(155, 164, 'NORP'), (142, 154, 'NORP'), (27, 31, 'ORG'), (109, 117, 'NORP'), (52, 70, 'PERSON'), (37, 44, 'DATE')}
# {(52, 67, 'PERSON'), (27, 31, 'ORG'), (109, 117, 'NORP'), (142, 164, 'NORP'), (37, 44, 'DATE')}
# ---------------------------
# TP: 3 | FP: 2 | FN: 3
# ---------------------------
# Precision of tweet: 0.6
# Recall of tweet: 0.5
# f1-score of tweet: 0.5454545454545454
# --------------------------------------------------------------------------------------------------------------------
# tweet: 83
# {(20, 24, 'PERSON'), (34, 41, 'GPE')}
# {(20, 24, 'PERSON')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.5
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 84
# {(0, 11, 'GPE')}
# {(0, 11, 'GPE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 85
# {(47, 56, 'NORP'), (25, 34, 'NORP')}
# {(47, 56, 'NORP'), (25, 34, 'NORP')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 86
# {(52, 62, 'NORP'), (81, 85, 'GPE'), (99, 109, 'NORP')}
# {(52, 62, 'NORP'), (81, 85, 'GPE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.8
# --------------------------------------------------------------------------------------------------------------------
# tweet: 87
# {(97, 104, 'DATE'), (123, 131, 'NORP'), (52, 70, 'GPE'), (29, 35, 'GPE')}
# {(79, 88, 'NORP'), (29, 35, 'PERSON'), (97, 104, 'DATE'), (62, 70, 'LOC'), (123, 131, 'NORP')}
# ---------------------------
# TP: 2 | FP: 3 | FN: 2
# ---------------------------
# Precision of tweet: 0.4
# Recall of tweet: 0.5
# f1-score of tweet: 0.4444444444444445
# --------------------------------------------------------------------------------------------------------------------
# tweet: 88
# {(127, 138, 'GPE'), (41, 52, 'GPE'), (99, 110, 'GPE'), (85, 95, 'DATE'), (0, 4, 'GPE')}
# {(99, 110, 'LOC'), (55, 61, 'DATE'), (41, 52, 'GPE'), (85, 95, 'DATE'), (0, 4, 'GPE')}
# ---------------------------
# TP: 3 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.6
# Recall of tweet: 0.6
# f1-score of tweet: 0.6
# --------------------------------------------------------------------------------------------------------------------
# tweet: 89
# {(0, 4, 'GPE'), (49, 59, 'PERSON'), (129, 142, 'DATE'), (18, 26, 'ORG')}
# {(129, 141, 'DATE'), (49, 59, 'PERSON'), (18, 26, 'ORG')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 0.5
# f1-score of tweet: 0.5714285714285715
# --------------------------------------------------------------------------------------------------------------------
# tweet: 90
# {(25, 33, 'NORP'), (0, 10, 'NORP'), (81, 91, 'NORP')}
# {(25, 33, 'NORP'), (0, 10, 'NORP')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.8
# --------------------------------------------------------------------------------------------------------------------
# tweet: 91
# set()
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 92
# {(109, 113, 'GPE')}
# {(109, 113, 'ORG')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 93
# {(4, 8, 'ORG'), (66, 71, 'NORP')}
# {(66, 71, 'NORP'), (0, 27, 'ORG')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.5
# f1-score of tweet: 0.5
# --------------------------------------------------------------------------------------------------------------------
# tweet: 94
# {(18, 25, 'DATE'), (94, 105, 'MONEY')}
# {(87, 105, 'MONEY'), (4, 7, 'ORG'), (18, 25, 'DATE')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.5
# f1-score of tweet: 0.4
# --------------------------------------------------------------------------------------------------------------------
# tweet: 95
# {(36, 40, 'GPE'), (54, 64, 'DATE')}
# {(36, 40, 'GPE'), (107, 110, 'PERSON'), (54, 67, 'DATE')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.5
# f1-score of tweet: 0.4
# --------------------------------------------------------------------------------------------------------------------
# tweet: 96
# {(11, 26, 'DATE')}
# {(29, 32, 'ORG'), (7, 26, 'DATE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 97
# set()
# {(4, 7, 'ORG')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 98
# {(106, 112, 'GPE'), (89, 95, 'DATE'), (99, 103, 'GPE'), (0, 6, 'GPE')}
# {(106, 112, 'GPE'), (10, 26, 'ORG'), (60, 66, 'DATE'), (89, 95, 'DATE'), (99, 103, 'GPE'), (0, 6, 'GPE')}
# ---------------------------
# TP: 4 | FP: 2 | FN: 0
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 1.0
# f1-score of tweet: 0.8
# --------------------------------------------------------------------------------------------------------------------
# tweet: 99
# {(122, 128, 'DATE')}
# {(122, 128, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 100
# {(49, 59, 'DATE')}
# {(49, 59, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 101
# {(117, 129, 'PERSON'), (41, 47, 'GPE'), (94, 101, 'NORP'), (21, 25, 'DATE')}
# {(117, 129, 'PERSON'), (29, 47, 'ORG'), (94, 101, 'NORP'), (21, 25, 'DATE')}
# ---------------------------
# TP: 3 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.75
# Recall of tweet: 0.75
# f1-score of tweet: 0.75
# --------------------------------------------------------------------------------------------------------------------
# tweet: 102
# {(55, 68, 'MONEY'), (87, 98, 'DATE')}
# {(55, 68, 'MONEY'), (87, 98, 'DATE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 103
# {(31, 36, 'PERSON'), (49, 53, 'DATE')}
# {(31, 36, 'PERSON'), (49, 53, 'DATE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 104
# {(63, 72, 'NORP'), (125, 132, 'NORP')}
# {(63, 72, 'NORP'), (125, 132, 'NORP')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 105
# {(37, 41, 'DATE')}
# {(37, 41, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 106
# {(14, 18, 'GPE'), (65, 72, 'GPE')}
# {(14, 18, 'GPE'), (65, 72, 'GPE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 107
# {(0, 8, 'DATE')}
# {(0, 8, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 108
# {(101, 106, 'NORP')}
# {(41, 55, 'LOC'), (101, 106, 'NORP')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 1.0
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 109
# {(73, 80, 'NORP'), (0, 9, 'DATE')}
# {(73, 80, 'NORP'), (0, 9, 'DATE'), (31, 45, 'LOC')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 1.0
# f1-score of tweet: 0.8
# --------------------------------------------------------------------------------------------------------------------
# tweet: 110
# {(133, 138, 'GPE'), (141, 149, 'DATE'), (80, 88, 'NORP'), (99, 103, 'GPE'), (16, 20, 'GPE')}
# {(80, 88, 'NORP'), (99, 103, 'GPE'), (16, 20, 'GPE'), (141, 148, 'DATE')}
# ---------------------------
# TP: 3 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.75
# Recall of tweet: 0.6
# f1-score of tweet: 0.6666666666666665
# --------------------------------------------------------------------------------------------------------------------
# tweet: 111
# {(50, 54, 'GPE'), (28, 37, 'DATE'), (65, 69, 'GPE')}
# {(0, 22, 'ORG'), (50, 54, 'GPE'), (28, 37, 'DATE'), (65, 69, 'GPE')}
# ---------------------------
# TP: 3 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.75
# Recall of tweet: 1.0
# f1-score of tweet: 0.8571428571428571
# --------------------------------------------------------------------------------------------------------------------
# tweet: 112
# {(56, 62, 'NORP'), (0, 5, 'GPE')}
# {(56, 61, 'NORP'), (0, 4, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 113
# {(0, 9, 'NORP')}
# {(0, 9, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 114
# {(103, 128, 'PERSON'), (58, 67, 'DATE'), (23, 32, 'NORP')}
# {(103, 128, 'PERSON'), (58, 67, 'DATE'), (23, 32, 'NORP')}
# ---------------------------
# TP: 3 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 115
# {(58, 67, 'ORG')}
# {(58, 67, 'ORG')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 116
# {(0, 6, 'GPE')}
# {(0, 6, 'GPE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 117
# set()
# {(42, 70, 'MONEY')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 118
# {(0, 9, 'NORP')}
# {(0, 9, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 119
# {(6, 10, 'GPE'), (48, 57, 'NORP')}
# {(6, 10, 'GPE'), (48, 57, 'NORP')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 120
# {(20, 23, 'ORG'), (4, 19, 'ORG'), (101, 112, 'NORP')}
# {(0, 28, 'ORG'), (49, 58, 'NORP'), (101, 112, 'NORP')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.3333333333333333
# f1-score of tweet: 0.3333333333333333
# --------------------------------------------------------------------------------------------------------------------
# tweet: 121
# {(128, 140, 'PERSON'), (109, 119, 'NORP'), (81, 93, 'PERSON')}
# {(109, 119, 'NORP'), (128, 139, 'PERSON'), (81, 93, 'PERSON'), (46, 62, 'ORG')}
# ---------------------------
# TP: 2 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.6666666666666666
# f1-score of tweet: 0.5714285714285715
# --------------------------------------------------------------------------------------------------------------------
# tweet: 122
# {(138, 153, 'PERSON'), (94, 99, 'PERSON')}
# {(138, 153, 'PERSON'), (3, 23, 'ORG'), (94, 99, 'PERSON')}
# ---------------------------
# TP: 2 | FP: 1 | FN: 0
# ---------------------------
# Precision of tweet: 0.6666666666666666
# Recall of tweet: 1.0
# f1-score of tweet: 0.8
# --------------------------------------------------------------------------------------------------------------------
# tweet: 123
# {(14, 23, 'NORP'), (100, 104, 'GPE')}
# {(14, 23, 'NORP')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.5
# f1-score of tweet: 0.6666666666666666
# --------------------------------------------------------------------------------------------------------------------
# tweet: 124
# {(52, 62, 'DATE')}
# {(52, 62, 'DATE')}
# ---------------------------
# TP: 1 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 125
# {(0, 5, 'NORP'), (16, 27, 'PERSON'), (99, 108, 'NORP'), (40, 49, 'GPE')}
# {(0, 5, 'NORP'), (16, 27, 'PERSON'), (99, 108, 'NORP'), (40, 49, 'GPE')}
# ---------------------------
# TP: 4 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 126
# {(85, 92, 'GPE'), (0, 9, 'GPE'), (69, 77, 'DATE'), (35, 46, 'PERSON'), (62, 68, 'PERSON')}
# {(0, 9, 'GPE'), (69, 77, 'DATE'), (35, 46, 'PERSON'), (62, 68, 'PERSON')}
# ---------------------------
# TP: 4 | FP: 0 | FN: 1
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 0.8
# f1-score of tweet: 0.888888888888889
# --------------------------------------------------------------------------------------------------------------------
# tweet: 127
# {(82, 93, 'DATE'), (138, 150, 'PERSON'), (18, 24, 'PERSON'), (62, 70, 'DATE')}
# {(82, 93, 'DATE'), (138, 150, 'PERSON'), (18, 24, 'PERSON'), (62, 70, 'DATE')}
# ---------------------------
# TP: 4 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 128
# {(45, 53, 'NORP'), (72, 85, 'PERSON')}
# {(86, 91, 'DATE'), (72, 85, 'PERSON'), (39, 53, 'NORP')}
# ---------------------------
# TP: 1 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.3333333333333333
# Recall of tweet: 0.5
# f1-score of tweet: 0.4
# --------------------------------------------------------------------------------------------------------------------
# tweet: 129
# {(14, 18, 'GPE'), (0, 9, 'GPE')}
# {(14, 18, 'GPE'), (0, 9, 'GPE')}
# ---------------------------
# TP: 2 | FP: 0 | FN: 0
# ---------------------------
# Precision of tweet: 1.0
# Recall of tweet: 1.0
# f1-score of tweet: 1.0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 130
# {(130, 139, 'GPE'), (46, 55, 'GPE'), (0, 9, 'GPE')}
# {(46, 55, 'LOC'), (0, 9, 'GPE')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.3333333333333333
# ...
# TP: 0 | FP: 2 | FN: 0
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 256
# {(79, 86, 'NORP'), (13, 17, 'GPE'), (49, 56, 'DATE')}
# {(12, 19, 'DATE'), (3, 7, 'DATE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 3
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 257
# {(124, 128, 'GPE'), (25, 41, 'PERSON'), (102, 109, 'NORP')}
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 3
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 258
# {(49, 67, 'PERSON'), (28, 46, 'ORG')}
# {(79, 86, 'NORP'), (13, 17, 'GPE'), (49, 56, 'DATE')}
# ---------------------------
# TP: 0 | FP: 3 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 259
# {(27, 48, 'ORG')}
# {(74, 128, 'ORG'), (25, 41, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 260
# {(12, 16, 'GPE')}
# {(24, 35, 'ORG'), (49, 67, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 261
# {(43, 53, 'DATE')}
# {(94, 115, 'ORG'), (23, 48, 'ORG')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 262
# {(79, 83, 'GPE'), (87, 95, 'DATE'), (4, 11, 'NORP'), (29, 47, 'PERSON')}
# {(20, 40, 'ORG'), (12, 16, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 4
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 263
# {(31, 37, 'GPE'), (2, 19, 'ORG')}
# {(43, 52, 'DATE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 264
# {(109, 115, 'GPE'), (18, 26, 'NORP')}
# {(79, 83, 'GPE'), (87, 95, 'DATE'), (4, 11, 'NORP'), (29, 47, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 4 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 265
# {(100, 106, 'GPE'), (20, 27, 'DATE'), (31, 41, 'GPE'), (49, 54, 'NORP'), (167, 174, 'NORP'), (207, 221, 'DATE')}
# {(31, 37, 'GPE'), (2, 19, 'ORG')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 6
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 266
# {(113, 127, 'ORG'), (0, 6, 'GPE')}
# {(14, 37, 'ORG'), (109, 115, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 267
# {(4, 21, 'ORG'), (90, 98, 'NORP')}
# {(100, 106, 'GPE'), (20, 27, 'DATE'), (31, 41, 'GPE'), (49, 54, 'NORP'), (167, 174, 'NORP'), (207, 221, 'DATE')}
# ---------------------------
# TP: 0 | FP: 6 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 268
# {(0, 7, 'GPE')}
# {(109, 127, 'ORG'), (0, 6, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 269
# {(115, 122, 'GPE'), (62, 70, 'DATE'), (138, 142, 'GPE'), (10, 25, 'PERSON')}
# {(90, 98, 'NORP'), (0, 21, 'ORG')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 4
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 270
# {(113, 124, 'DATE'), (45, 58, 'LOC')}
# {(0, 7, 'GPE')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 271
# set()
# {(115, 122, 'GPE'), (62, 70, 'DATE'), (138, 142, 'GPE'), (10, 25, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 4 | FN: 0
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 272
# {(105, 112, 'NORP'), (54, 58, 'GPE'), (12, 16, 'GPE')}
# {(109, 124, 'DATE'), (125, 140, 'PERSON'), (45, 58, 'LOC')}
# ---------------------------
# TP: 0 | FP: 3 | FN: 3
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 273
# {(34, 42, 'DATE'), (106, 128, 'PERSON'), (85, 89, 'GPE'), (0, 15, 'PERSON')}
# set()
# ---------------------------
# TP: 0 | FP: 0 | FN: 4
# ---------------------------
# Precision of tweet: 0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 274
# {(0, 4, 'GPE'), (52, 69, 'DATE')}
# {(105, 112, 'NORP'), (54, 58, 'GPE'), (12, 16, 'GPE')}
# ---------------------------
# TP: 0 | FP: 3 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 275
# {(20, 27, 'DATE'), (37, 41, 'GPE'), (57, 66, 'DATE'), (0, 11, 'PERSON'), (70, 79, 'GPE')}
# {(34, 42, 'DATE'), (106, 128, 'PERSON'), (85, 89, 'GPE'), (0, 15, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 4 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 276
# {(143, 147, 'GPE'), (12, 19, 'GPE'), (35, 45, 'PERSON'), (69, 85, 'ORG'), (86, 94, 'DATE')}
# {(0, 4, 'GPE'), (52, 69, 'DATE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 277
# {(125, 138, 'GPE'), (103, 118, 'LOC')}
# {(20, 27, 'DATE'), (37, 41, 'GPE'), (57, 66, 'DATE'), (0, 11, 'PERSON'), (70, 79, 'GPE')}
# ---------------------------
# TP: 0 | FP: 5 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 278
# {(15, 21, 'PERSON'), (66, 79, 'GPE')}
# {(143, 147, 'GPE'), (12, 19, 'GPE'), (35, 45, 'PERSON'), (69, 85, 'ORG'), (86, 94, 'DATE')}
# ---------------------------
# TP: 0 | FP: 5 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 279
# {(68, 74, 'DATE'), (57, 67, 'GPE'), (184, 197, 'DATE'), (0, 14, 'ORG'), (109, 115, 'GPE')}
# {(121, 138, 'GPE'), (103, 118, 'LOC')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 280
# {(75, 81, 'GPE'), (61, 63, 'ORG'), (39, 46, 'GPE')}
# {(15, 21, 'PERSON'), (62, 79, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 3
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 281
# {(18, 27, 'NORP'), (91, 97, 'GPE'), (43, 45, 'ORG'), (0, 7, 'GPE'), (61, 67, 'GPE')}
# {(68, 74, 'DATE'), (57, 67, 'GPE'), (184, 197, 'DATE'), (0, 14, 'ORG'), (109, 115, 'GPE')}
# ---------------------------
# TP: 0 | FP: 5 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 282
# {(69, 75, 'DATE'), (4, 10, 'GPE')}
# {(75, 81, 'GPE'), (61, 63, 'ORG'), (39, 46, 'GPE')}
# ---------------------------
# TP: 0 | FP: 3 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 283
# {(48, 56, 'NORP'), (0, 2, 'ORG')}
# {(18, 27, 'NORP'), (0, 7, 'GPE'), (43, 45, 'ORG'), (61, 67, 'GPE')}
# ---------------------------
# TP: 0 | FP: 4 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 284
# {(57, 64, 'GPE'), (92, 103, 'DATE'), (77, 84, 'GPE')}
# {(69, 75, 'DATE'), (4, 10, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 3
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 285
# {(46, 54, 'NORP'), (0, 2, 'ORG'), (91, 96, 'GPE')}
# {(48, 56, 'NORP'), (0, 2, 'ORG')}
# ---------------------------
# TP: 1 | FP: 1 | FN: 2
# ---------------------------
# Precision of tweet: 0.5
# Recall of tweet: 0.3333333333333333
# f1-score of tweet: 0.4
# --------------------------------------------------------------------------------------------------------------------
# tweet: 286
# {(60, 67, 'ORG'), (0, 9, 'NORP')}
# {(57, 64, 'GPE'), (77, 84, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 287
# {(63, 82, 'PERSON'), (21, 30, 'DATE'), (90, 101, 'LOC'), (45, 52, 'ORG')}
# {(46, 54, 'NORP'), (0, 2, 'ORG')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 4
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 288
# {(0, 5, 'PERSON')}
# {(60, 67, 'ORG'), (0, 9, 'NORP')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 289
# {(26, 31, 'PERSON')}
# {(63, 82, 'PERSON'), (86, 101, 'LOC'), (21, 30, 'DATE'), (45, 52, 'ORG')}
# ---------------------------
# TP: 0 | FP: 4 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 290
# {(0, 9, 'NORP'), (35, 42, 'ORG'), (89, 100, 'PERSON')}
# {(0, 5, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 3
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 291
# {(46, 53, 'ORG')}
# {(26, 31, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 1
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 292
# {(27, 32, 'GPE'), (8, 12, 'GPE')}
# {(89, 95, 'NORP'), (0, 9, 'NORP'), (35, 42, 'ORG')}
# ---------------------------
# TP: 0 | FP: 3 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 293
# {(132, 137, 'GPE'), (80, 96, 'PERSON'), (102, 112, 'GPE'), (5, 19, 'ORG'), (52, 58, 'DATE')}
# {(46, 53, 'ORG')}
# ---------------------------
# TP: 0 | FP: 1 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 294
# {(58, 71, 'NORP'), (31, 35, 'PERSON')}
# {(27, 32, 'GPE'), (8, 12, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 295
# {(56, 65, 'PERSON'), (125, 129, 'DATE'), (91, 101, 'GPE'), (18, 30, 'DATE'), (38, 45, 'NORP')}
# {(74, 79, 'ORG'), (132, 137, 'GPE'), (80, 96, 'PERSON'), (102, 112, 'GPE'), (5, 19, 'ORG'), (52, 58, 'DATE')}
# ---------------------------
# TP: 0 | FP: 6 | FN: 5
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 296
# {(50, 55, 'GPE'), (20, 30, 'GPE')}
# {(58, 71, 'NORP'), (31, 35, 'PERSON')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 297
# {(0, 7, 'GPE'), (66, 70, 'GPE')}
# {(56, 65, 'PERSON'), (125, 129, 'DATE'), (91, 101, 'GPE'), (18, 30, 'DATE'), (38, 45, 'NORP')}
# ---------------------------
# TP: 0 | FP: 5 | FN: 2
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0
# --------------------------------------------------------------------------------------------------------------------
# tweet: 298
# {(139, 148, 'GPE'), (0, 4, 'GPE'), (151, 167, 'DATE'), (51, 62, 'PERSON')}
# {(50, 55, 'GPE'), (20, 30, 'GPE')}
# ---------------------------
# TP: 0 | FP: 2 | FN: 4
# ---------------------------
# Precision of tweet: 0.0
# Recall of tweet: 0.0
# f1-score of tweet: 0

# %%
print("-----------------------------------------------------")
print("Manual NER vs SpaCy NER:")
print("----------------------------------------------------- \n")
print(f"Overall Precision: {precision}")
print(f"Overall Recall: {recall}")
print(f"Overall f1-score: {f1}")
print("-----------------------------------------------------")
print(f"Overall True Positives (TP): {tp}")
print(f"Overall False Positives (FP): {fp}")
print(f"Overall False Negatives (FN): {fn}")
# Out:
# -----------------------------------------------------
# Manual NER vs SpaCy NER:
# -----------------------------------------------------
#
# Overall Precision: 0.36363636363636365
# Overall Recall: 0.36681222707423583
# Overall f1-score: 0.3652173913043478
# -----------------------------------------------------
# Overall True Positives (TP): 252
# Overall False Positives (FP): 441
# Overall False Negatives (FN): 435

# %% [markdown]
# Summary:
# - Precision and recall are relatively low, indicating that spaCy's NER model is making significant number of False Positives and False Negative predictions compared to manual NER.
# - The number of false positives is slightly higher than false negatives, which implies that SpaCy is more likely to incorrectly identify entities that do not exist than to miss out on existing ones
# - The relatively low F1-score reinforces that the performance of SpaCy's NER in this case is suboptimal, and there's room for improvement.
